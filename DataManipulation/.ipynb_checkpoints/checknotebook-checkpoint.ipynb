# %% [markdown]
# # Notebook to prepare the yolo dataset creation pipeline

# %%
import geopandas as gpd
import rasterio
import os
import numpy as np
import cv2

from data_utils import generate_labels

# %% [markdown]
# ## Visualising labels and data

# %%
# Attempting printing labels on an image
from data_utils import print_labels_on_image


# Reading a labels file as an example
label_path = 'ls_data/labels/LE07_L1TP_130038_19991209_20170215_01_T1_BC56.txt'
image_path = 'ls_data/images/LE07_L1TP_130038_19991209_20170215_01_T1_BC56.jpg'

print_labels_on_image(image_path, label_path)

# %% [markdown]
# ## Trying to convert shapefiles (.shp) of each patch to YOLO labels format

# %%
#Testing the whole flow
import os

# Obtain all the 'filename's from the images folder without the extension
filenames = [os.path.splitext(filename)[0] for filename in os.listdir('./Mosaic/image_patches')]

print(filenames)
# Out:
# ['LE07_L2SP_2015_02_T1_SR_BC_M1', 'LE07_L2SP_2015_02_T1_SR_BC_M106', 'LE07_L2SP_2015_02_T1_SR_BC_M112', 'LE07_L2SP_2015_02_T1_SR_BC_M489', 'LE07_L2SP_2015_02_T1_SR_BC_M338', 'LE07_L2SP_2015_02_T1_SR_BC_M462', 'LE07_L2SP_2015_02_T1_SR_BC_M33', 'LE07_L2SP_2015_02_T1_SR_BC_M304', 'LE07_L2SP_2015_02_T1_SR_BC_M310', 'LE07_L2SP_2015_02_T1_SR_BC_M476', 'LE07_L2SP_2015_02_T1_SR_BC_M27', 'LE07_L2SP_2015_02_T1_SR_BC_M258', 'LE07_L2SP_2015_02_T1_SR_BC_M516', 'LE07_L2SP_2015_02_T1_SR_BC_M270', 'LE07_L2SP_2015_02_T1_SR_BC_M264', 'LE07_L2SP_2015_02_T1_SR_BC_M502', 'LE07_L2SP_2015_02_T1_SR_BC_M265', 'LE07_L2SP_2015_02_T1_SR_BC_M503', 'LE07_L2SP_2015_02_T1_SR_BC_M517', 'LE07_L2SP_2015_02_T1_SR_BC_M271', 'LE07_L2SP_2015_02_T1_SR_BC_M259', 'LE07_L2SP_2015_02_T1_SR_BC_M311', 'LE07_L2SP_2015_02_T1_SR_BC_M26', 'LE07_L2SP_2015_02_T1_SR_BC_M477', 'LE07_L2SP_2015_02_T1_SR_BC_M32', 'LE07_L2SP_2015_02_T1_SR_BC_M463', 'LE07_L2SP_2015_02_T1_SR_BC_M305', 'LE07_L2SP_2015_02_T1_SR_BC_M339', 'LE07_L2SP_2015_02_T1_SR_BC_M488', 'LE07_L2SP_2015_02_T1_SR_BC_M113', 'LE07_L2SP_2015_02_T1_SR_BC_M107', 'LE07_L2SP_2015_02_T1_SR_BC_M0', 'LE07_L2SP_2015_02_T1_SR_BC_M2', 'LE07_L2SP_2015_02_T1_SR_BC_M139', 'LE07_L2SP_2015_02_T1_SR_BC_M111', 'LE07_L2SP_2015_02_T1_SR_BC_M105', 'LE07_L2
_SR_BC_M511', 'LE07_L2SP_2015_02_T1_SR_BC_M277', 'LE07_L2SP_2015_02_T1_SR_BC_M263', 'LE07_L2SP_2015_02_T1_SR_BC_M505', 'LE07_L2SP_2015_02_T1_SR_BC_M288', 'LE07_L2SP_2015_02_T1_SR_BC_M459', 'LE07_L2SP_2015_02_T1_SR_BC_M34', 'LE07_L2SP_2015_02_T1_SR_BC_M465', 'LE07_L2SP_2015_02_T1_SR_BC_M303', 'LE07_L2SP_2015_02_T1_SR_BC_M317', 'LE07_L2SP_2015_02_T1_SR_BC_M20', 'LE07_L2SP_2015_02_T1_SR_BC_M471', 'LE07_L2SP_2015_02_T1_SR_BC_M6', 'LE07_L2SP_2015_02_T1_SR_BC_M129', 'LE07_L2SP_2015_02_T1_SR_BC_M101', 'LE07_L2SP_2015_02_T1_SR_BC_M115', 'LE07_L2SP_2015_02_T1_SR_BC_M103', 'LE07_L2SP_2015_02_T1_SR_BC_M117', 'LE07_L2SP_2015_02_T1_SR_BC_M4', 'LE07_L2SP_2015_02_T1_SR_BC_M498', 'LE07_L2SP_2015_02_T1_SR_BC_M301', 'LE07_L2SP_2015_02_T1_SR_BC_M467', 'LE07_L2SP_2015_02_T1_SR_BC_M36', 'LE07_L2SP_2015_02_T1_SR_BC_M473', 'LE07_L2SP_2015_02_T1_SR_BC_M22', 'LE07_L2SP_2015_02_T1_SR_BC_M315', 'LE07_L2SP_2015_02_T1_SR_BC_M329', 'LE07_L2SP_2015_02_T1_SR_BC_M275', 'LE07_L2SP_2015_02_T1_SR_BC_M513', 'LE0 ...

# %%
total_len = len(filenames)
counter = 0

for picname in filenames:
    generate_labels(picname)
    counter += 1

    print(counter, '/', total_len, 'done')
# Out:
# 1 / 580 done
# 2 / 580 done
# 3 / 580 done
# 4 / 580 done
# 5 / 580 done
# 6 / 580 done
# 7 / 580 done
# 8 / 580 done
# 9 / 580 done
# 10 / 580 done
# 11 / 580 done
# 12 / 580 done
# 13 / 580 done
# 14 / 580 done
# 15 / 580 done
# 16 / 580 done
# 17 / 580 done
# 18 / 580 done
# 19 / 580 done
# 20 / 580 done
# 21 / 580 done
# 22 / 580 done
# 23 / 580 done
# 24 / 580 done
# 25 / 580 done
# 26 / 580 done
# 27 / 580 done
# 28 / 580 done
# 29 / 580 done
# 30 / 580 done
# 31 / 580 done
# 32 / 580 done
# 33 / 580 done
# 34 / 580 done
# 35 / 580 done
# 36 / 580 done
# 37 / 580 done
# 38 / 580 done
# 39 / 580 done
# 40 / 580 done
# 41 / 580 done
# 42 / 580 done
# 43 / 580 done
# 44 / 580 done
# 45 / 580 done
# 46 / 580 done
# 47 / 580 done
# 48 / 580 done
# 49 / 580 done
# 50 / 580 done
# 51 / 580 done
# 52 / 580 done
# 53 / 580 done
# 54 / 580 done
# 55 / 580 done
# 56 / 580 done
# 57 / 580 done
# 58 / 580 done
# 59 / 580 done
# 60 / 580 done
# 61 / 580 done
# 62 / 580 done
# 63 / 580 done
# 64 / 580 done
# 65 / 580 done
# 66 / 580 done
# 67 / 580 done
# 68 / 580 done
# 69 / 580 done
# 70 / 580 done
# 71 / 580 done
# 72 / 580 done
# 73 / 580 done
# 74 / 580 done
# 75 / 580 done
# 76 / 580 done
# 77 / 580 done
# 78 / 580 done
# 79 / 580 done
# 80 / 580 done
# 81 / 580 done
# 82 / 580 done
# 83 / 580 done
# 84 / 580 done
# 85 / 580 done
# 86 / 580 done
# 87 / 580 done
# 88 / 580 done
# 89 / 580 done
# 90 / 580 done
# 91 / 580 done
# 92 / 580 done
# 93 / 580 done
# 94 / 580 done
# 95 / 580 done
# 96 / 580 done
# 97 / 580 done
# 98 / 580 done
# 99 / 580 done
# 100 / 580 done
# 101 / 580 done
# 102 / 580 done
# 103 / 580 done
# 104 / 580 done
# 105 / 580 done
# 106 / 580 done
# 107 / 580 done
# 108 / 580 done
# 109 / 580 done
# 110 / 580 done
# 111 / 580 done
# 112 / 580 done
# 113 / 580 done
# 114 / 580 done
# 115 / 580 done
# 116 / 580 done
# 117 / 580 done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/vihaan/Workspace/Local_AI_Earth/Data_Manipulation /checknotebook.ipynb Cell 7 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/vihaan/Workspace/Local_AI_Earth/Data_Manipulation%20/checknotebook.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> counter = 0
#       <a href='vscode-notebook-cell:/Users/vihaan/Workspace/Local_AI_Earth/Data_Manipulation%20/checknotebook.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> for picname in filenames:
# ----> <a href='vscode-notebook-cell:/Users/vihaan/Workspace/Local_AI_Earth/Data_Manipulation%20/checknotebook.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a>     generate_labels(picname)
#       <a href='vscode-notebook-cell:/Users/vihaan/Workspace/Local_AI_Earth/Data_Manipulation%20/checknotebook.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a>     counter += 1
#       <a href='vscode-notebook-cell:/Users/vihaan/Workspace/Local_AI_Earth/Data_Manipulation%20/checknotebook.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a>     print(counter, '/', total_len, 'done')
#
# File ~/Workspace/Local_AI_Earth/Data_Manipulation /data_utils.py:63, in generate_labels(filename)
#      60     polygon_list_latlong = [(x, y) for x, y,_ in shapefile.geometry[i].exterior.coords]
#      61     #print(polygon_list_latlong)
#      62     #print(convert_list_coordinates_to_pixel_normalised(polygon_list_latlong,raster_patch_path))
# ---> 63     master_list.append(convert_list_coordinates_to_pixel_normalised(polygon_list_latlong,raster_patch_path))
#      64 except AttributeError:
#      65     continue
#
# File ~/Workspace/Local_AI_Earth/Data_Manipulation /data_utils.py:30, in convert_list_coordinates_to_pixel_normalised(list, raster_patch_path)
#      28 x = val[0]
#      29 y = val[1]
# ---> 30 x_pixel,y_pixel = convert_coordinates_to_pixel_values(x,y,raster_patch_path)
#      31 flat_list.append(x_pixel)
#      32 flat_list.append(y_pixel)
#
# File ~/Workspace/Local_AI_Earth/Data_Manipulation /data_utils.py:10, in convert_coordinates_to_pixel_values(x, y, raster_patch_path)
#       8 def convert_coordinates_to_pixel_values(x,y, raster_patch_path):
# ---> 10     raster_patch = rasterio.open(raster_patch_path)
#      12     # Get the bounds of the raster patch
#      13     bounds = raster_patch.bounds
#
# File ~/miniforge3/envs/geek/lib/python3.9/site-packages/rasterio/env.py:451, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     448     session = DummySession()
#     450 with env_ctor(session=session):
# --> 451     return f(*args, **kwds)
#
# File ~/miniforge3/envs/geek/lib/python3.9/site-packages/rasterio/__init__.py:304, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, **kwargs)
#     301 path = _parse_path(raw_dataset_path)
#     303 if mode == "r":
# --> 304     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     305 elif mode == "r+":
#     306     dataset = get_writer_for_path(path, driver=driver)(
#     307         path, mode, driver=driver, sharing=sharing, **kwargs
#     308     )
#
# File rasterio/_base.pyx:329, in rasterio._base.DatasetBase.__init__()
#
# File rasterio/_base.pyx:351, in rasterio._base.DatasetBase._set_attrs_from_dataset_handle()
#
# File rasterio/_base.pyx:968, in rasterio._base.DatasetBase.meta.__get__()
#
# File rasterio/_base.pyx:601, in rasterio._base.DatasetBase.nodata.__get__()
#
# File rasterio/_base.pyx:582, in rasterio._base.DatasetBase.nodatavals.__get__()
#
# File rasterio/_base.pyx:562, in rasterio._base.DatasetBase.get_nodatavals()
#
# File ~/miniforge3/envs/geek/lib/python3.9/site-packages/rasterio/dtypes.py:102, in in_dtype_range(value, dtype)
#      98     dtype_ranges['int64'] = (-9223372036854775808, 9223372036854775807)
#      99     dtype_ranges['uint64'] = (0, 18446744073709551615)
# --> 102 def in_dtype_range(value, dtype):
#     103     """
#     104     Check if the value is within the dtype range
#     105     """
#     106     if numpy.dtype(dtype).kind == "f" and (numpy.isinf(value) or numpy.isnan(value)):
#
# KeyboardInterrupt:

# %%
# Visualising an image and labels

import numpy as np  
import cv2


def print_labels_on_image(image_path, yolo_label_format):
    '''
    image_path: path to image
    yolo_label_format: path to label file
    '''

    # Load image
    image = cv2.imread(image_path)

    # Load labels
    with open(yolo_label_format,'r'):
        labels = [line.rstrip('\n') for line in open(yolo_label_format)]

    # Get image dimensions
    image_height, image_width, _ = image.shape

    # Scaling the labels (x labels are scaled by image_width and y labels are scaled by image_height)
    x_scale = image_width
    y_scale = image_height

    # Loop through labels
    for label in labels:

        # Converting string labels list to integer
        flat_coordinates = convert_string_list_to_float(label)[1:]

        # Scaling up the coordinates to x_scale and y_scale
        for i in range(len(flat_coordinates)):

            # x values
            if i % 2 == 0:
                flat_coordinates[i] *= x_scale
            # y values
            else:
                flat_coordinates[i] *= y_scale

        # Draw polygon
        polygon_coordinates = np.array(flat_coordinates).reshape((-1,1,2)).astype(np.int32)
        cv2.polylines(image, [polygon_coordinates], True, (0, 255, 0), 1)

    # Display image
    cv2.imshow('image', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
