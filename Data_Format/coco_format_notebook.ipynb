# %%
# imports
import os
from shapely.geometry import Polygon
import numpy as np
import xml.etree.ElementTree as ET
import json
import cv2
import glob

from PIL import Image

import matplotlib.pyplot as plt

# %%
# Image alteration functions:
def apply_gamma_correction(image, gamma):
    # Normalize the image to [0, 1]
    image_float = image / 255.0
    # Apply gamma correction
    corrected_image = np.power(image_float, gamma)
    # Scale back to [0, 255] and convert to 8-bit
    corrected_image = np.clip(corrected_image * 255, 0, 255).astype(np.uint8)
    return corrected_image

def adjust_brightness(image, brightness_factor):
    adjusted_image = image + brightness_factor
    adjusted_image = np.clip(adjusted_image, 0, 255).astype(np.uint8)
    return adjusted_image

def adjust_contrast(image, contrast_factor):
    # Calculate the mean of the image for contrast adjustment
    mean = np.mean(image)
    adjusted_image = (image - mean) * contrast_factor + mean
    adjusted_image = np.clip(adjusted_image, 0, 255).astype(np.uint8)
    return adjusted_image

def histogram_stretching(image):
    # Convert to float to avoid issues during division
    img = image.astype('float')
    
    # Get minimum and maximum pixel values
    min_val = np.min(img)
    max_val = np.max(img)
    
    # Apply histogram stretching
    stretched_img = (img - min_val) / (max_val - min_val) * 255.0
    
    return stretched_img.astype('uint8')

def linear_stretch(image):
    # Get the minimum and maximum pixel values
    min_val = np.min(image)
    max_val = np.max(image)
    
    # Apply the linear stretch
    stretched_image = (image - min_val) * (255.0 / (max_val - min_val))
    
    # Clip the values to ensure they are within the valid range [0, 255]
    stretched_image = np.clip(stretched_image, 0, 255)
    
    # Convert the stretched image to uint8
    stretched_image = stretched_image.astype('uint8')
    
    return stretched_image

def percent_clip(image, percent):
    # Calculate the number of pixels to clip
    num_pixels = image.size
    num_to_clip = int(num_pixels * percent / 100)
    
    # Sort the pixel values
    sorted_pixels = np.sort(image, axis=None)
    
    # Clip the pixel values
    clipped_image = np.clip(image, sorted_pixels[num_to_clip], sorted_pixels[-num_to_clip - 1])
    
    return clipped_image

def histogram_equalize(image):
    # Initialize an empty array to store the equalized image
    equalized_image = np.zeros_like(image)

    # Iterate over each channel of the image
    for channel in range(image.shape[2]):
        # Flatten the channel to 1D array
        channel_values = image[:, :, channel].flatten()

        # Calculate the histogram of the channel
        hist, bins = np.histogram(channel_values, bins=256, range=(0, 256), density=True)

        # Calculate the cumulative distribution function (CDF)
        cdf = hist.cumsum()

        # Normalize the CDF to the range [0, 255]
        cdf_normalized = ((cdf - cdf.min()) / (cdf.max() - cdf.min())) * 255

        # Interpolate the CDF values to get the equalized values
        equalized_values = np.interp(channel_values, bins[:-1], cdf_normalized)

        # Reshape the equalized values back to the original shape of the channel
        equalized_channel = equalized_values.reshape(image[:, :, channel].shape)

        # Assign the equalized channel to the equalized image
        equalized_image[:, :, channel] = equalized_channel

    # Convert the equalized image to uint8
    equalized_image = equalized_image.astype('uint8')

    return equalized_image

# %%
# Dataset Paths:

###### UCSB Dataset ######
ucsb_parent_folder = '/Users/vihaan/Workspace/!Datasets/Processed_Data_S24'
ucsb_full_images_numpy  = os.path.join(ucsb_parent_folder, 'image_patches')
ucsb_full_labels = os.path.join(ucsb_parent_folder, 'labels')

# create images (jpg) folder:
ucsb_full_images = os.path.join(ucsb_parent_folder, 'images')

# If it exists and has files inside, delete the folder and recreate it:
if os.path.exists(ucsb_full_images) and os.listdir(ucsb_full_images):
    print('Deleting and recreating the images folder...')
    os.system(f'rm -rf {ucsb_full_images}')
    os.mkdir(ucsb_full_images)

# number of image patches and labels:
ucsb_image_patches = os.listdir(ucsb_full_images_numpy)
ucsb_labels = os.listdir(ucsb_full_labels)

print(len(ucsb_image_patches), len(ucsb_labels))
# Out:
# Deleting and recreating the images folder...
# 1088 1063

# %% [markdown]
# # UCSB Data Manipulation and Visualisation

# %% [markdown]
# # Instance Segmentation XML Creation

# %%
# Converting one line of the above to coco format instance segmentation for the image:

# Example:

Source: https://docs.nvidia.com/tao/tao-toolkit/text/data_annotation_format.html#id9
annotation{
"id": int,
"image_id": int,
"category_id": int,
"segmentation": RLE or [polygon],
"area": float,
"bbox": [x,y,width,height],
"iscrowd": 0 or 1,
}

image{
"id": int,
"width": int,
"height": int,
"file_name": str,
"license": int,
"flickr_url": str,
"coco_url": str,
"date_captured": datetime,
}

categories[{
"id": int,
"name": str,
"supercategory": str,
}]
'''


##### Handling main dictionaries #####
# Preparing categories field:
categories = [
    {
        "id": 1,
        "name": "Landslide",
        "supercategory": "Natural_Disaster"
    }
]
# Setting up images and annotations fields:
images = []
annotations = []
landslide_count = 0

# Iterating through the images folder enumerating with number:
for image_index, image_name in enumerate(os.listdir(ucsb_full_images_numpy)):

    # Obtain image details:
    image_path = os.path.join(ucsb_full_images_numpy, image_name)

    # Reading image
    sample_image_numpy = np.load(image_path)

    # Obtain image height and width
    image_height = sample_image_numpy.shape[1]
    image_width = sample_image_numpy.shape[2]

    # save image as jpg in images folder
    image_jpg_name = image_name.split('.')[0] + '.jpg'
    image_jpg_path = os.path.join(ucsb_full_images, image_jpg_name)

    # Change the orientation from (C x H x W) to (H x W x C)
    sample_image_numpy = np.transpose(sample_image_numpy, (1, 2, 0))

    # Choose bands 2,1 and 0 for RGB
    sample_image_numpy = sample_image_numpy[:, :, [2, 1, 0]]

    # Normalising the image:
    img_reshaped = sample_image_numpy
    if img_reshaped.dtype == np.uint16:
        scale_factor = 65535 // 255
        img_reshaped = (img_reshaped / scale_factor).astype(np.uint8)
    elif img_reshaped.max() <= 1:  # float images in [0, 1] range
        img_reshaped = (img_reshaped* 255).astype(np.uint8)
        
    cv2.imwrite(image_jpg_path, img_reshaped)

    # Preparing the next set of fields for the current image:
    image = {
        "id": image_index,
        "width": image_width,
        "height": image_height,
        "file_name": image_jpg_name,
        "license": 1,
        "flickr_url": "http://www.flickr.com/",
        "coco_url": "http://www.coco.com/",
        "date_captured": "2021-08-06"
    }

    # Appending the image to the images list
    images.append(image)

    ### Find the corresponding label file
    # Get the name of the image
    image_name = image_name.split('.')[0]

    # Find the corresponding label file
    label_file = image_name + '.txt'

    # Get the full path of the label file
    label_file_path = os.path.join(ucsb_full_labels, label_file)

    # If label doesn't exist, we move on to the next image
    if not os.path.exists(label_file_path):
        continue

    # Read the label file and obtain line by line as a list
    with open(label_file_path, 'r') as f:
        lines = f.readlines()

    # iterating through all landslide annotations in the labels file (enumerate)
    for i, line in enumerate(lines):

        # obtaining segmentation polygon from line,
        full_annotation_polygon_normalised = lines[i].split(' ')[1:]

        # Convert polygon to non-normalised format by multiplying with image width (for 1,3,5... coordinates) and height (for 2,4,6... coordinates):
        x_coords = []
        y_coords = []
        for i, coord in enumerate(full_annotation_polygon_normalised):
            if i % 2 == 0:
                x_coords.append(float(coord) * image_width)
            else:
                y_coords.append(float(coord) * image_height)
        # Create a polygon object
        full_annotation_polygon = []
        for i in range(len(x_coords)):
            full_annotation_polygon.append(x_coords[i])
            full_annotation_polygon.append(y_coords[i])

        segmentation_polygon = [full_annotation_polygon]

        ### obtaining area of the polygon
        x = x_coords
        y = y_coords

        # creating a polygon object
        polygon = Polygon(zip(x, y))

        # obtaining area of the polygon
        area = polygon.area

        ### obtaining bounding box of the polygon (as x,y,width,height):
        x_min, y_min, x_max, y_max = polygon.bounds

        # obtaining bounding box of the polygon
        bbox = [x_min, y_min, x_max-x_min, y_max-y_min]

        # obtaining iscrowd field of the polygon
        iscrowd = 0

        # creating annotation dictionary
        annotation = {
            "id": landslide_count,
            "image_id": image_index,
            "category_id": 1,
            "segmentation": segmentation_polygon,
            "area": area,
            "bbox": bbox,
            "iscrowd": iscrowd
        }

        # incrementing landslide count
        landslide_count += 1

        # appending annotation to annotations list
        annotations.append(annotation)
# Out:
# [127.38476800000001, 2.4731840000000003, 10.543455999999992, 8.630944]
# [52.743488, 5.097568, 8.733984, 4.900448]
# [98.688128, 25.430272000000002, 5.182687999999985, 8.457343999999999]
# [128.47139199999998, 36.603616, 8.504832000000022, 16.528511999999992]
# [109.063136, 41.710592000000005, 3.852800000000002, 7.198463999999994]
# [147.406336, 63.03696000000001, 8.737567999999982, 10.700703999999988]
# [105.152992, 156.768416, 4.648223999999999, 9.018016000000017]
# [118.34681599999999, 158.310208, 9.174592000000018, 9.8784]
# [132.59120000000001, 128.49894400000002, 3.5927359999999737, 12.083007999999978]
# [124.27094399999999, 125.366976, 4.964736000000016, 11.576544000000013]
# [109.1832, 119.91839999999999, 3.0430399999999906, 10.589823999999993]
# [98.576576, 116.420416, 4.532640000000001, 8.64752]
# [77.830368, 70.66729600000001, 6.595007999999993, 13.699615999999992]
# [76.336288, 32.481792, 7.679615999999996, 17.819648]
# [71.96739199999999, 35.656991999999995, 21.28694400000002, 35.743007999999996]
# [202.916448, 13.99776, 4.487392, 11.060000000000002]
# [161.28403200000002, 20.586047999999998, 6.244895999999983, 3.6798719999999996]
# [156.753184, 24.658816, 8.632735999999994, 7.655200000000001]
# [87.176768, 32.511136, 5.821088000000003, 11.409216]
# [32.33328, 138.666752, 4.500159999999994, 13.666687999999994]
# [101.074848, 7.823872, 14.52707199999999, 19.526975999999998]
# [41.384448, 70.46435199999999, 6.687295999999996, 9.948736000000011]
# [47.266016, 74.459616, 5.556095999999997, 6.638239999999996]
# [49.691488, 78.321376, 5.976991999999996, 7.3187520000000035]
# [77.046144, 0.0, 7.306207999999998, 6.703872]
# [44.121056, 12.015136, 13.588287999999999, 5.917631999999999]
# [157.16176, 12.742464, 3.632159999999999, 12.561024000000002]
# [29.832544, 87.4104, 4.075232, 6.763456000000005]
# [65.92521599999999, 222.557888, 7.067424000000003, 1.4421120000000087]
# [46.747679999999995, 219.39792, 3.3266240000000025, 4.602080000000001]
# [5.1495359999999994, 212.75968, 11.615743999999998, 5.919647999999995]
# [28.21168, 216.338752, 5.5041280000000015, 7.6612480000000005]
# [6.860672, 180.963776, 11.675999999999998, 6.574176000000023]
# [28.503328, 200.251968, 10.795232000000002, 4.163488000000001]
# [7.145152, 197.537312, 35.592479999999995, 14.198464000000001]
# [20.103552, 204.51558400000002, 17.195135999999998, 8.810367999999983]
# [7.433216, 188.953632, 11.152960000000002, 2.95702399999999]
# [198.517536, 0.0, 1.709791999999993, 19.8968]
# [195.430816, 10.321248, 3.7488639999999975, 10.475807999999997]
# [181.034784, 0.0, 2.610272000000009, 7.393568]
# [191.675232, 0.0, 2.4516800000000103, 9.635808]
# [174.649888, 83.690208, 7.919520000000006, 5.179552000000001]
# [188.59388800000002, 75.296928, 20.693343999999968, 5.272064]
# [221.54518399999998, 52.984736, 2.4548160000000223, 4.125856000000006]
# [38.285408000000004, 50.750336, 6.394303999999998, 3.527776000000003]
# [0.0, 142.990848, 2.7581119999999997, 21.34876799999998]
# [3.8104639999999996, 146.61740799999998, 3.439744, 14.444192000000015]
# [7.058463999999999, 146.08944, 3.077088, 11.962720000000019]
# [7.216608000000001, 146.241312, 4.265632, 13.631519999999995]
# [189.78736, 187.054112, 12.900608000000005, 25.78419199999999]
# [122.66822399999998, 223.96528, 0.28985600000001455, 0.03471999999999298]
# [135.360064, 205.912224, 5.591712000000001, 18.08777599999999]
# [149.45839999999998, 216.801984, 6.659072000000037, 7.1980159999999955]
# [213.118752, 187.833408, 5.97587200000001, 14.947519999999997]
# [223.807136, 186.747904, 0.19286399999998594, 1.4087359999999762]
# [36.788416, 63.676480000000005, 4.684512000000005, 12.560799999999993]
# [0.0, 19.046944, 1.178016, 2.330943999999999]
# [149.98816, 90.12572800000001, 7.3084479999999985, 11.823615999999987]
# [133.043008, 93.008832, 10.168256000000014, 5.672800000000009]
# [155.07699200000002, 108.215968, 7.952224000000001, 12.003488000000004]
# [130.173568, 115.86735999999999, 10.440191999999996, 11.975263999999996]
# [98.374528, 125.290144, 7.027776000000003, 8.029728000000006]
# [88.296768, 130.996768, 7.279104000000004, 4.9374079999999765]
# [89.46336000000001, 186.611936, 3.222911999999994, 7.434784000000036]
# [90.41311999999999, 182.087584, 4.939200000000014, 7.248415999999992]
# [35.166208, 80.89804799999999, 12.754784000000008, 3.3528320000000065]
# [34.64608, 85.18540800000001, 5.620160000000006, 7.416639999999987]
# [31.104864000000003, 81.99721600000001, 19.720287999999993, 12.448352]
# [50.01696, 122.67875199999999, 6.005887999999999, 4.10323200000002]
# [51.622816, 130.507328, 5.9162880000000015, 7.350784000000004]
# [1.33952, 107.856224, 5.429984, 11.424672000000001]
# [18.995648, 113.41164800000001, 5.954143999999999, 5.385407999999998]
# [22.764447999999998, 186.406752, 4.690111999999999, 11.141759999999977]
# [55.578432, 187.184704, 4.595808000000005, 7.329279999999983]
# [33.866336, 165.085312, 5.457088000000006, 7.094976000000003]
# [109.096512, 153.977152, 10.494399999999999, 5.436256000000014]
# [83.09593600000001, 64.129856, 2.496479999999991, 11.582367999999988]
# [85.34937599999999, 63.43008, 0.03068800000001204, 0.6997760000000071]
# [85.244992, 41.860896, 5.5870080000000115, 21.569184]
# [98.060928, 44.874816, 4.255775999999997, 17.252927999999997]
# [89.37084800000001, 141.445248, 18.690111999999985, 24.380383999999992]
# [192.018848, 92.15561600000001, 5.929952000000014, 19.21068799999999]
# [210.707168, 91.49839999999999, 3.6458240000000046, 18.357472]
# [174.17344, 118.324864, 6.209951999999987, 12.411839999999998]
# [165.44752, 72.776032, 12.053663999999998, 17.97264]
# [177.594368, 103.69587200000001, 23.568832000000015, 23.60848]
# [42.545215999999996, 96.899936, 7.020160000000004, 8.508192000000008]
# [110.114144, 69.32016, 4.068960000000018, 15.817536000000004]
# [9.092832, 132.105568, 6.397440000000001, 8.662528000000009]
# [40.107423999999995, 52.000928, 9.462656000000003, 6.991488000000004]
# [157.376576, 120.18832, 11.289600000000007, 13.477183999999994]
# [48.819232, 17.041024, 8.168608000000006, 7.954688000000001]
# [136.827264, 104.973568, 3.2464319999999987, 13.644735999999995]
# [128.976736, 102.39264, 5.3343360000000075, 12.440064000000007]
# [112.522144, 103.216736, 33.07516799999999, 26.77606399999999]
# [84.44374400000001, 110.30678400000001, 22.39865599999999, 15.12806399999998]
# [157.38128, 62.780704, 6.866272000000009, 6.683039999999991]
# [130.9952, 62.266847999999996, 6.574175999999966, 11.495680000000007]
# [151.451104, 65.198784, 11.104800000000012, 10.094560000000001]
# [152.299616, 72.11971199999999, 4.612160000000017, 7.555071999999996]
# [23.666719999999998, 198.66672, 5.333216, 6.6666879999999935]
# [4.499936, 88.666592, 8.500128, 4.666816000000011]
# [49.0, 126.666624, 13.666688, 15.666783999999993]
# [190.847104, 0.0, 2.4048640000000034, 0.291424]
# [180.254816, 169.374912, 23.355136000000016, 4.425120000000021]
# [217.198016, 191.39075200000002, 6.18150399999999, 4.825183999999979]
# [5.5946240000000005, 0.0, 2.525152000000001, 5.27184]
# [157.330432, 8.224608, 7.101023999999995, 5.36032]
# [128.41427199999998, -2.282784, 7.764288000000022, 11.177824]
# [148.066688, 11.362624, 5.890304000000015, 6.858879999999999]
# [144.330816, 7.635039999999999, 4.507328000000001, 6.035456000000001]
# [133.39334399999998, 2.837184, 11.293856000000005, 12.794656]
# [176.46608, 29.23536, 9.33990399999999, 3.520159999999997]
# [160.72, 37.45257599999999, 10.898719999999997, 6.045984000000004]
# [211.69612800000002, 17.183264, 12.303871999999984, 6.782719999999998]
# [143.843168, 55.143648, 4.019679999999994, 12.483071999999993]
# [141.490048, 63.17964800000001, 5.1526719999999955, 5.446559999999998]
# [146.60195199999998, 87.39024, 6.889344000000023, 14.337344000000002]
# [143.00988800000002, 97.079136, 4.750591999999983, 9.634911999999986]
# [113.75795199999999, 74.618656, 10.256288000000012, 13.663328000000007]
# [113.879808, 84.36848, 6.348160000000007, 4.872223999999989]
# [111.002528, 128.988832, 14.887488000000005, 12.675711999999976]
# [146.422752, 116.175136, 8.829183999999998, 11.240768000000017]
# [122.314752, 121.98345599999999, 9.548224000000005, 2.4458560000000062]
# [31.865344, 33.101375999999995, 3.938368000000004, 7.6193600000000075]
# [22.508416, 59.88752, 4.637920000000001, 12.767552000000002]
# [56.190400000000004, 93.28144, 5.456863999999989, 9.796639999999996]
# [26.274752, 75.592384, 4.060223999999998, 8.124928000000011]
# [35.976416, 82.524512, 4.113087999999998, 5.848640000000003]
# [57.78752, 194.279232, 6.414687999999998, 3.5716799999999864]
# [24.964576, 149.57824, 9.828223999999999, 15.604960000000005]
# [123.14892800000001, 155.027712, 5.321567999999985, 8.68470400000001]
# [32.662784, 63.547231999999994, 6.3822079999999985, 5.176416000000003]
# [172.884768, 12.588576, 4.354783999999995, 14.190624]
# [169.11686400000002, 7.2499839999999995, 3.936800000000005, 14.613760000000001]
# [163.213344, 3.96816, 2.8911679999999933, 14.063167999999997]
# [39.230912, 17.197152, 24.912160000000007, 17.563392000000004]
# [51.961504000000005, 24.338272, 17.704511999999994, 10.525760000000002]
# [94.91798399999999, 131.57871999999998, 7.468832000000006, 13.795936000000012]
# [217.901824, 216.398784, 4.660320000000013, 5.818624]
# [193.5192, 154.784448, 10.094335999999998, 10.699808000000019]
# [166.775392, 187.13497600000002, 13.803776, 15.486239999999981]
# [46.030656, 134.32115199999998, 12.027455999999994, 16.952992000000023]
# [28.439712, 139.6696, 9.728767999999995, 15.999424000000005]
# [185.5504, 135.485952, 6.705664000000013, 6.648544000000015]
# [180.479712, 211.287104, 10.28921600000001, 6.980063999999999]
# [196.60368, 218.272544, 5.540639999999996, 4.2002239999999915]
# [0.0, 204.997856, 8.603392, 3.326623999999981]
# [39.131904, 189.628544, 9.916704000000003, 2.585183999999998]
# [39.045664, 197.08124800000002, 9.998016, 2.863839999999982]
# [185.508288, 169.75392, 12.415199999999999, 5.94944000000001]
# [201.241376, 186.13168000000002, 11.390175999999997, 7.863295999999963]
# [216.222272, 194.671456, 6.360928000000001, 10.099711999999982]
# [204.005984, 215.518912, 9.551359999999988, 6.73187200000001]
# [128.66672, 211.166592, 8.99987200000001, 9.166752000000002]
# [24.5672, 121.15241599999999, 26.262208, 10.026688000000007]
# [28.78288, 122.009664, 15.738912, 5.647487999999996]
# [47.273408, 146.61494399999998, 4.792255999999995, 9.695840000000032]
# [1.513792, 165.703328, 14.187488, 15.875551999999999]
# [110.776736, 184.37932800000002, 11.945024000000018, 29.52207999999999]
# [42.006272, 175.50982399999998, 43.71897599999999, 6.631744000000026]
# [104.39184, 156.72384, 25.33014399999999, 8.292256000000009]
# [137.15139200000002, 200.02124799999999, 3.352831999999978, 6.866944000000018]
# [62.26528, 218.820672, 17.442432000000004, 5.179327999999998]
# [146.272896, 212.307648, 4.244799999999998, 9.598175999999995]
# [134.090432, 190.558368, 17.8416, 21.714112]
# [128.362528, 190.1592, 3.992128000000008, 18.12092800000002]
# [87.013472, 57.629376, 5.597536000000005, 4.029535999999993]
# [87.21664, 59.572128, 11.39667200000001, 8.689855999999999]
# [72.25568000000001, 208.96064, 7.147391999999996, 15.039359999999988]
# [8.792895999999999, 207.040736, 4.947712000000001, 16.95926399999999]
# [61.268704, 209.311648, 9.348416, 4.586176000000023]
# [86.32848, 0.0, 11.34604800000001, 3.9863039999999996]
# [125.42656, 63.273056000000004, 5.291775999999999, 6.1382719999999935]
# [5.326944, 128.372608, 5.953247999999999, 5.18156799999997]
# [184.420544, 111.896512, 7.386176000000006, 6.173664000000002]
# [153.552224, 75.847072, 7.606816000000009, 3.9686080000000032]
# [168.350112, 75.559456, 55.649888000000004, 26.361664000000005]
# [136.340064, 7.790944, 27.916671999999977, 19.4544]
# [160.83849600000002, 0.0, 3.2972799999999722, 5.7904]
# [146.06278400000002, 0.0, 5.663167999999956, 9.07536]
# [151.5584, 0.0, 5.0249919999999975, 10.816288]
# [147.90944, 39.856320000000004, 12.111680000000007, 7.226911999999992]
# [112.105504, 9.879744, 39.683840000000004, 13.402144000000002]
# [107.78297599999999, 16.743551999999998, 48.50988800000002, 19.116832000000006]
# [166.44902399999998, 21.814016, 57.55097600000002, 21.881888]
# [44.494912, 133.868672, 8.33952, 18.257119999999986]
# [38.890208, 136.77664, 7.385503999999997, 12.736640000000023]
# [75.500096, 201.666752, 11.333280000000002, 7.166655999999989]
# [61.833408000000006, 214.99990400000002, 6.333151999999998, 5.500095999999985]
# [21.187712, 110.188736, 7.755327999999995, 24.494399999999985]
# [184.554048, 113.767584, 9.716224000000011, 6.31456]
# [190.199744, 107.25657600000001, 8.733312000000012, 3.5383039999999966]
# [176.996512, 78.39663999999999, 12.543776000000008, 6.941760000000016]
# [196.503328, 196.150752, 8.171071999999981, 9.125535999999983]
# [200.107712, 192.953152, 7.875840000000011, 6.885536000000002]
# [181.54304, 0.0, 19.97296, 15.343104]
# [148.43830400000002, 5.369504, 23.89094399999999, 16.381120000000003]
# [181.028064, 211.39977599999997, 3.9394880000000114, 6.894272000000029]
# [52.478944, 103.9696, 20.110048000000006, 24.71996800000001]
# [50.174431999999996, 98.799904, 6.296863999999999, 7.035392000000002]
# [127.406496, 98.727776, 5.1159359999999765, 5.0697919999999925]
# [24.383072000000002, 88.535552, 15.269184, 18.39196799999999]
# [33.717376, 72.40083200000001, 5.4053439999999995, 13.246687999999992]
# [30.446527999999997, 85.732864, 9.914016000000007, 10.244863999999993]
# [35.312928, 58.351327999999995, 14.368032, 25.255104000000003]
# [0.0, 53.263168, 31.49328, 42.333536]
# [175.718144, 0.0, 4.577440000000024, 16.45392]
# [14.871584000000002, 186.72192, 9.008831999999998, 3.74751999999998]
# [0.0, 46.794048000000004, 4.234496, 17.697791999999993]
# [84.89824, 61.962656, 12.789056000000002, 22.88742399999999]
# [169.033088, 90.11587200000001, 11.035359999999997, 2.901247999999981]
# [57.138144, 49.493024000000005, 14.008511999999996, 14.625855999999999]
# [52.109568, 56.16195199999999, 12.315071999999994, 13.836928000000007]
# [0.0, 51.3184, 10.594528, 36.26828800000001]
# [125.93952, 51.641856, 16.963296, 23.448320000000002]
# [88.87043200000001, 216.889344, 10.534272000000001, 4.8507199999999955]
# [179.910976, 33.652192, 6.934367999999978, 2.855328]
# [117.151776, 76.766592, 18.879616000000013, 18.385024]
# [115.08403200000001, 90.0704, 13.392735999999985, 16.453024]
# [33.94944, 142.975392, 5.655327999999997, 6.183296000000013]
# [65.811872, 41.83088, 18.146016000000003, 28.222208000000002]
# [71.076768, 82.558112, 7.552608000000006, 4.081952000000015]
# [51.299583999999996, 85.60719999999999, 10.583328000000002, 10.186624000000009]
# [70.481824, 87.194688, 13.361599999999996, 9.260608000000005]
# [166.89254400000002, 166.957728, 8.399327999999997, 5.379807999999997]
# [165.68876799999998, 101.466848, 2.7982080000000167, 7.7192639999999955]
# [93.814336, 213.692192, 16.792832000000004, 4.676223999999991]
# [220.44848000000002, 160.539904, 3.5515199999999822, 5.298944000000006]
# [154.88076800000002, 185.034528, 2.978751999999986, 7.724863999999997]
# [66.581088, 135.14435200000003, 7.967904000000004, 8.918335999999954]
# [146.55312, 39.177376, 4.613056, 14.069887999999999]
# [3.186176, 189.562016, 23.769984, 7.592479999999995]
# [168.928928, 0.0, 17.24710399999998, 12.62128]
# [209.468672, 0.0, 12.777856000000014, 8.013152]
# [3.0685759999999997, 3.313632, 20.024256, 18.034688000000003]
# [74.273248, 205.71936, 13.200320000000005, 4.268319999999989]
# [106.759968, 76.060096, 5.954816000000008, 9.722943999999998]
# [104.709696, 78.060416, 5.07337600000001, 9.308095999999992]
# [87.46617599999999, 59.288095999999996, 3.054688000000013, 9.546208000000007]
# [57.70643200000001, 47.251456, 7.910336000000001, 7.266336000000003]
# [38.775072, 55.238400000000006, 13.816319999999997, 17.343871999999983]
# [44.548671999999996, 52.878783999999996, 7.179648, 11.700192000000015]
# [48.810496, 49.644895999999996, 9.262847999999998, 11.689440000000005]
# [123.279296, 167.874336, 13.713503999999986, 6.506752000000006]
# [119.12947199999999, 100.156896, 10.445792000000012, 3.332000000000008]
# [0.0, 184.102912, 10.002496, 3.1335359999999923]
# [0.0, 159.772704, 14.627424, 10.726240000000018]
# [0.0, 95.437888, 3.857504, 9.681280000000001]
# [44.613408, 116.620672, 7.461887999999995, 6.492191999999989]
# [65.221184, 92.37603200000001, 8.539328000000012, 5.0915199999999885]
# [63.985823999999994, 49.805279999999996, 12.682432000000006, 4.856320000000004]
# [49.528416, 218.934912, 11.213887999999997, 5.065088000000003]
# [59.941504, 181.49868800000002, 12.000127999999997, 6.642944]
# [0.0, 109.98848000000001, 2.001216, 4.342911999999984]
# [0.0, 74.33664, 0.958496, 4.934495999999996]
# [53.90896, 86.629312, 18.622239999999998, 11.6648]
# [211.180704, 149.8168, 12.819296000000008, 19.272960000000012]
# [101.615808, 106.97097600000001, 6.137376000000003, 15.365279999999984]
# [147.49952, 106.275008, 18.30819200000002, 20.40975999999999]
# [153.2328, 58.578464, 8.459360000000004, 4.435199999999995]
# [40.784128, 106.096032, 8.044063999999999, 26.832735999999997]
# [143.13107200000002, 25.90224, 13.073311999999987, 8.746975999999997]
# [25.99408, 126.678272, 5.476800000000001, 9.422783999999993]
# [66.003616, 40.749856, 10.16803200000001, 8.103424000000004]
# [67.171776, 52.454304, 10.515008000000009, 8.163903999999995]
# [66.074624, 57.856064, 7.041663999999997, 7.236319999999992]
# [61.403104, 33.382048, 6.669600000000003, 7.422912000000004]
# [158.666592, 88.33328, 7.733599999999996, 11.833472]
# [172.666592, 94.16668800000001, 4.500159999999994, 7.666623999999985]
# [178.833312, 109.666592, 10.666655999999989, 14.49996800000001]
# [200.08508799999998, 107.500064, 4.915008, 7.548576000000011]
# [216.666688, 74.833248, 7.3333120000000065, 5.500095999999999]
# [153.099072, 36.459807999999995, 11.465439999999973, 15.522304000000005]
# [151.33328, 87.5, 9.666719999999998, 10.333343999999997]
# [156.166752, 91.0, 7.0, 6.5000320000000045]
# [1.561728, 130.21657599999998, 8.092448, 4.015424000000024]
# [0.0, 124.60806399999998, 1.2658239999999998, 4.233375999999993]
# [80.22784, 0.0, 4.210751999999999, 2.29264]
# [117.89747200000001, 0.0, 3.039903999999993, 0.371168]
# [119.499968, 40.833408000000006, 7.290303999999992, 33.597759999999994]
# [135.159584, 113.012704, 13.019328000000002, 5.308351999999999]
# [214.67488, 7.613312, 8.776319999999998, 10.355968]
# [147.28784, 51.071776, 6.263936000000001, 14.75084799999999]
# [205.948736, 59.22044799999999, 18.051264000000003, 5.180447999999998]
# [33.095327999999995, 183.673728, 5.815040000000003, 5.073824000000002]
# [29.533952, 25.781952, 16.642303999999996, 57.99695999999999]
# [220.654336, 31.454976, 3.3456639999999993, 3.9184319999999992]
# [202.587168, 103.10272, 7.363103999999993, 11.107711999999992]
# [222.488672, 12.604256, 1.5113279999999918, 2.541056000000001]
# [74.68832, 110.478144, 8.149344, 8.461600000000004]
# [160.278944, 116.39420799999999, 25.372479999999996, 7.485184000000004]
# [188.03276799999998, 182.706048, 13.60262400000002, 5.813695999999993]
# [185.808672, 187.154464, 14.909216000000015, 9.06595200000001]
# [182.65139200000002, 0.0, 8.380287999999979, 3.005856]
# [41.39296, 181.57327999999998, 10.379711999999998, 4.557504000000023]
# [178.205888, 86.288832, 9.60153600000001, 8.772512000000006]
# [0.0, 186.69952, 2.92768, 2.4870719999999835]
# [221.230688, 0.0, 1.9391680000000235, 0.069216]
# [200.541824, 14.49392, 22.675296000000003, 13.106016]
# [200.87289600000003, 28.246848, 17.780895999999984, 5.961984000000001]
# [157.63328, 0.0, 10.058719999999994, 21.507360000000002]
# [137.42288, 34.01328, 6.892928000000012, 25.489856000000003]
# [109.542944, 45.209696, 5.38585599999999, 15.566207999999996]
# [107.15398400000001, 32.774336, 3.048415999999989, 21.278208]
# [158.15072, 102.30371199999999, 11.328575999999998, 3.6680000000000064]
# [113.59152, 89.685568, 17.764991999999978, 4.478208000000009]
# [132.36831999999998, 84.03696000000001, 5.358528000000007, 6.671839999999989]
# [152.555872, 143.019072, 15.24611200000001, 18.635456000000005]
# [121.250976, 146.580448, 13.203007999999997, 12.102720000000005]
# [122.291008, 177.69673600000002, 11.022143999999997, 9.102239999999995]
# [175.66192, 187.443872, 0.5873280000000136, 0.0705600000000004]
# [210.070112, 185.672032, 0.6328000000000031, 0.3111359999999763]
# [159.282144, 184.918272, 16.37977600000002, 2.772672]
# [176.24924800000002, 184.305856, 33.82086399999997, 3.1380159999999933]
# [210.702912, 184.272704, 4.867072000000007, 1.399327999999997]
# [70.18256, 221.670848, 2.4207680000000096, 2.3291519999999934]
# [48.751584, 220.759392, 10.457663999999994, 3.240608000000009]
# [153.25654400000002, 159.746048, 14.948191999999977, 10.449151999999998]
# [0.0, 167.540576, 16.04624, 7.8417920000000265]
# [59.910368, 0.0, 3.176544, 3.065664]
# [98.071904, 65.71622400000001, 11.676447999999993, 10.681887999999987]
# [0.0, 51.084992, 5.356064, 6.116320000000002]
# [10.839360000000001, 31.464608000000002, 4.247039999999997, 18.236288]
# [14.877408, 42.108416000000005, 4.443712, 12.135423999999993]
# [210.34608, 61.95056, 13.65392, 17.379936000000008]
# [206.48432, 78.804096, 6.892480000000006, 18.599168000000006]
# [202.44604800000002, 85.94544, 7.189503999999971, 11.286239999999992]
# [8.44368, 0.0, 0.7488319999999984, 3.472448]
# [114.91043200000001, 210.678944, 4.003999999999991, 5.62688]
# [105.62496, 7.3380160000000005, 6.123487999999995, 12.806528]
# [163.115232, 58.36387199999999, 6.76121599999999, 9.851296000000012]
# [186.61350399999998, 82.17574400000001, 8.39372800000001, 4.282207999999997]
# [164.65568, 199.070144, 3.7188480000000084, 9.42143999999999]
# [211.39395199999998, 65.971808, 6.3853440000000035, 6.171872000000008]
# [85.33257599999999, 175.096768, 5.084576000000013, 9.218047999999982]
# [11.200896, 76.48300800000001, 12.697664, 5.423487999999978]
# [0.0, 77.200256, 2.5260480000000003, 2.8766080000000045]
# [183.858752, 0.0, 7.196224000000001, 3.441312]
# [177.61072, 46.297664000000005, 28.626976000000013, 20.196288000000003]
# [191.00076800000002, 38.746624, 29.81910399999998, 20.917344000000007]
# [186.112192, 79.606688, 17.763871999999992, 12.19187199999999]
# [218.33481600000002, 138.964448, 5.665183999999982, 15.785504000000003]
# [174.695584, 19.424608, 9.006592000000012, 6.428576000000003]
# [175.413504, 8.417472, 9.767520000000019, 7.885248000000001]
# [49.88368, 48.858432, 17.49865600000001, 15.423296]
# [210.39872, 132.548864, 4.146912000000015, 10.989215999999999]
# [166.404448, 199.430112, 8.656480000000016, 14.381472000000002]
# [31.447584, 175.575456, 4.880288, 5.64591999999999]
# [24.79568, 170.82352, 5.184256000000001, 6.089663999999999]
# [69.908384, 208.83363200000002, 13.030079999999998, 7.099679999999978]
# [80.022656, 0.0, 6.1096, 3.9533760000000004]
# [218.94947200000001, 9.380896, 5.050527999999986, 11.414591999999999]
# [204.943872, 0.0, 5.335903999999999, 8.73488]
# [207.124288, 29.121792000000003, 16.479007999999993, 6.9186879999999995]
# [216.334944, 15.095360000000001, 4.936959999999971, 10.089632]
# [222.07203199999998, 3.334912, 1.9279680000000212, 5.504352]
# [75.648832, 60.442368, 5.559232000000009, 5.5941760000000045]
# [76.928544, 53.764256, 6.305824000000001, 7.775487999999996]
# [87.972192, 53.231136, 28.076384000000004, 16.107391999999997]
# [60.227104000000004, 69.491072, 7.195551999999985, 9.769760000000005]
# [92.661856, 53.824960000000004, 14.653856000000005, 6.265056000000001]
# [41.974912, 5.855808, 32.910752, 28.168896]
# [65.171232, 0.0, 5.280127999999991, 13.888]
# [50.899519999999995, 3.9399360000000003, 4.953088000000008, 7.018591999999999]
# [139.56028799999999, 219.151744, 6.385568000000006, 4.848255999999992]
# [193.408768, 203.779296, 13.488831999999974, 5.763520000000028]
# [0.0, 141.292704, 5.5328, 9.627968000000038]
# [16.081632, 118.713728, 14.684992000000001, 12.531008000000014]
# [117.72006400000001, 113.66566399999999, 4.872223999999989, 10.952256000000006]
# [185.767904, 135.04847999999998, 7.425824000000006, 11.626496000000031]
# [169.83545600000002, 218.887872, 12.854687999999982, 5.112128000000013]
# [0.0, 38.379264, 9.058336, 13.668256]
# [201.03664, 197.041824, 5.30655999999999, 7.6513920000000155]
# [100.10336000000001, 58.268896, 8.72278399999999, 5.89321600000001]
# [117.138112, 53.451552, 7.1137919999999895, 12.340831999999999]
# [111.411776, 49.011648, 10.487456000000009, 17.682336]
# [152.325152, 49.146944, 2.411135999999999, 8.659616]
# [138.382272, 137.659872, 7.796991999999989, 4.479775999999987]
# [167.389376, 116.196192, 4.900671999999986, 3.9710719999999924]
# [164.73990400000002, 117.97743999999999, 8.795583999999963, 10.786048000000008]
# [150.816288, 207.43161600000002, 7.456288000000029, 8.827615999999978]
# [66.36179200000001, 0.0, 7.9410239999999845, 9.44048]
# [62.115872, 5.9133759999999995, 6.698271999999996, 7.867776000000001]
# [34.531167999999994, 171.238368, 14.516544000000003, 4.813087999999993]
# [56.44464000000001, 175.927136, 11.58035199999999, 10.187296000000032]
# [36.804768, 213.917088, 12.102272, 7.942815999999993]
# [33.639872000000004, 208.857376, 10.017951999999994, 8.470560000000006]
# [38.331552, 138.794656, 6.678559999999997, 5.372863999999993]
# [34.310528, 139.60934400000002, 10.412640000000003, 9.330495999999982]
# [168.23990400000002, 0.0, 1.4286719999999775, 0.862624]
# [221.37024, 197.861888, 2.6297600000000045, 3.498656000000011]
# [33.205984, 20.207264, 8.142176, 9.363872]
# [14.807071999999998, 20.342560000000002, 7.7201600000000035, 4.41056]
# [9.42144, 17.964352, 7.509152, 3.594975999999999]
# [10.439744000000001, 46.415264, 6.986784, 8.980159999999998]
# [98.59046400000001, 142.159136, 6.535423999999992, 21.52169600000002]
# [14.953792, 136.241952, 6.527135999999999, 10.508735999999999]
# [16.67008, 157.4272, 7.174496000000001, 6.776895999999994]
# [216.907488, 222.26736, 2.2653119999999944, 1.7326400000000035]
# [93.744224, 66.28832, 3.786047999999994, 15.120671999999999]
# [18.934496000000003, 51.9568, 8.818431999999994, 12.097791999999998]
# [213.606624, 190.400672, 10.39337599999999, 10.930752000000012]
# [222.536832, 143.491264, 1.463167999999996, 5.756799999999998]
# [32.456704, 17.212608, 12.235327999999996, 38.478719999999996]
# [5.6692160000000005, 196.957152, 5.233312, 16.578911999999974]
# [166.729696, 181.430592, 12.76576, 12.078080000000028]
# [145.06755199999998, 196.09139199999998, 24.700928000000033, 17.298176000000012]
# [72.59728000000001, 163.947392, 4.518079999999983, 16.016447999999997]
# [130.42467200000002, 86.31705600000001, 6.090783999999985, 12.42416]
# [90.995744, 175.52998399999998, 20.63017599999999, 44.79104000000001]
# [104.080928, 180.496736, 2.6140800000000013, 11.295423999999997]
# [110.61904000000001, 181.03590400000002, 3.0824640000000016, 12.577823999999964]
# [64.025248, 182.313824, 9.183551999999992, 36.76601599999998]
# [35.97552, 91.555968, 18.021023999999997, 20.89830400000001]
# [31.401216, 94.495072, 15.201760000000004, 10.473120000000009]
# [32.976384, 98.477792, 11.871103999999995, 9.795072000000005]
# [90.07376, 95.824512, 10.610208, 10.659040000000005]
# [35.711872, 173.593504, 3.7999360000000024, 9.670975999999996]
# [152.273632, 104.89359999999999, 26.035296000000017, 19.42124800000002]
# [58.894527999999994, 168.216608, 7.774144000000007, 10.541888]
# [25.891712, 129.493952, 9.229248000000005, 21.516767999999985]
# [45.082688, 219.365664, 3.941728000000005, 4.6343359999999905]
# [25.178272, 219.210656, 1.3773760000000017, 4.789344]
# [4.266751999999999, 217.870688, 3.000032, 6.129311999999999]
# [7.790495999999999, 214.423776, 3.4462400000000013, 9.576223999999996]
# [80.43772799999999, 164.74841600000002, 4.504863999999998, 9.534335999999968]
# [184.311456, 40.833184, 9.772224000000023, 15.497664]
# [220.146304, 61.281696000000004, 3.8536960000000136, 5.492479999999993]
# [107.133152, 84.58665599999999, 3.338943999999998, 8.800288000000009]
# [82.320672, 184.600864, 11.046335999999997, 10.369408000000021]
# [32.322752, 149.03324800000001, 8.67776, 7.676479999999998]
# [148.47056, 215.809888, 8.197279999999978, 8.190112]
# [91.56044800000001, 215.31888, 6.122143999999992, 3.637535999999983]
# [10.653664, 133.777952, 9.789472, 13.782496000000009]
# [156.176832, 0.0, 6.859552000000008, 3.612672]
# [220.175424, 189.000224, 3.8245760000000075, 4.576319999999981]
# [221.398912, 194.793984, 2.6010880000000043, 5.886271999999991]
# [208.46918399999998, 213.08246400000002, 15.530816000000016, 4.494335999999976]
# [216.50518399999999, 44.832032, 4.790464000000014, 4.4864960000000025]
# [220.638432, 44.801792, 3.3615680000000054, 4.636800000000001]
# [207.586176, 152.388768, 7.301952, 13.301792000000006]
# [174.133792, 145.858272, 6.442239999999998, 4.959583999999978]
# [168.552608, 134.86368, 3.202303999999998, 4.445504000000028]
# [169.5288, 130.154976, 4.799648000000019, 5.4328959999999995]
# [160.75248, 144.39577599999998, 4.135040000000004, 9.090592000000015]
# [141.11664000000002, 223.08003200000002, 11.643295999999992, 0.919967999999983]
# [129.57952, 144.97817600000002, 5.961759999999998, 3.6404479999999637]
# [98.285376, 166.383168, 7.9952320000000014, 7.552607999999992]
# [103.894784, 165.703104, 9.991071999999988, 5.648384000000021]
# [108.70832, 166.375776, 8.401791999999986, 6.023135999999994]
# [117.4376, 185.94128, 4.272352000000012, 4.6126079999999945]
# [102.282656, 147.540512, 3.1028479999999945, 7.834847999999994]
# [97.747552, 208.678624, 4.6271679999999975, 13.26751999999999]
# [85.371104, 125.48704, 4.295648, 6.063008000000011]
# [88.727744, 125.71260799999999, 3.755359999999996, 5.8744000000000085]
# [86.255456, 137.753056, 6.253408000000007, 3.948896000000019]
# [110.851776, 128.66828800000002, 8.040927999999994, 7.468607999999989]
# [194.268704, 115.6736, 3.917759999999987, 5.567520000000016]
# [193.37472000000002, 112.91459199999998, 4.921055999999965, 6.556928000000013]
# [194.721632, 87.90096, 6.8409599999999955, 5.937120000000007]
# [196.84224, 87.76992, 6.7045439999999985, 6.9312320000000085]
# [196.634144, 79.911328, 6.319040000000001, 5.558784000000003]
# [186.526368, 72.92544000000001, 4.583264000000014, 8.066239999999993]
# [159.50076800000002, 94.628128, 22.765791999999976, 22.615488]
# [172.013408, 94.497312, 15.988, 9.35132800000001]
# [165.79808, 100.810976, 5.353151999999994, 5.9003840000000025]
# [183.288448, 95.132352, 13.640480000000025, 6.7045439999999985]
# [193.24390400000001, 94.40681599999999, 5.955264, 8.317568000000009]
# [183.811488, 61.640096, 3.815392000000003, 6.547967999999997]
# [185.83353599999998, 59.563616, 7.04121600000002, 4.825855999999995]
# [188.121248, 59.177440000000004, 6.465088000000009, 5.121535999999992]
# [132.07376, 31.447359999999996, 7.187263999999999, 7.279328000000007]
# [133.31852800000001, 33.956384, 8.309280000000001, 6.446944000000002]
# [117.04089599999999, 83.842304, 12.52070400000001, 12.475455999999994]
# [119.13036799999999, 83.221376, 11.675104000000019, 13.093919999999997]
# [118.52399999999999, 120.305696, 5.281472000000022, 5.209119999999999]
# [79.352896, 89.390112, 6.301568000000003, 4.22105599999999]
# [35.489888, 136.19491200000002, 7.775264, 11.71206399999997]
# [78.59510399999999, 133.646912, 6.041728000000006, 3.8729600000000346]
# [38.965472, 190.643936, 5.277439999999999, 6.952960000000019]
# [202.770848, 192.520832, 15.416575999999992, 15.833439999999996]
# [131.802944, 30.511488, 26.220544000000018, 8.927744000000004]
# [167.15888, 37.129791999999995, 18.508447999999987, 5.37532800000001]
# [180.885376, 194.649504, 5.6752639999999985, 10.362239999999986]
# [178.304, 205.48259199999998, 5.310144000000008, 8.347584000000012]
# [30.312352, 212.308544, 8.032864, 11.691455999999988]
# [23.550912, 101.642464, 7.547680000000003, 14.822751999999994]
# [48.086304, 97.092576, 3.3371520000000032, 12.902624000000003]
# [115.987648, 108.466624, 5.760832000000008, 6.898303999999996]
# [137.385472, 171.306464, 9.371936000000005, 17.480511999999976]
# [141.03823999999997, 188.184864, 11.531072000000023, 15.95798400000001]
# [211.76624, 202.299328, 12.23375999999999, 7.954239999999999]
# [31.818752000000003, 74.71632, 13.358016, 12.479935999999995]
# [65.186688, 178.120544, 7.4144000000000005, 5.74291199999999]
# [76.257216, 155.314432, 11.731552000000008, 3.810687999999999]
# [99.886976, 92.343552, 23.187359999999998, 15.255743999999993]
# [155.646848, 189.859488, 3.620287999999988, 7.049504000000013]
# [223.98767999999998, 0.0, 0.012320000000016762, 0.014784000000000002]
# [96.039776, 25.821824, 36.905568, 48.08496]
# [65.916032, 59.521728, 27.09884799999999, 11.593567999999998]
# [136.46752, 13.133792, 15.220127999999988, 11.071648]
# [94.282048, 66.848992, 4.606560000000002, 5.010432000000009]
# [81.16304000000001, 65.933056, 7.4215679999999935, 6.6671360000000135]
# [82.981472, 77.058464, 3.2056639999999987, 4.822047999999995]
# [14.824096, 134.8648, 8.337504, 5.751423999999986]
# [15.362816000000002, 139.01328, 7.663936, 4.269888000000009]
# [68.30678400000001, 0.0, 4.5660159999999905, 2.97472]
# [151.195968, 1.627808, 6.38444800000002, 7.515872]
# [86.761024, 129.191104, 4.000416000000001, 5.320447999999999]
# [181.06704000000002, 37.47296, 7.219519999999989, 8.310399999999994]
# [68.569536, 22.350272, 8.943424000000007, 3.556000000000001]
# [52.951584, 94.78515200000001, 5.097344000000007, 3.638879999999986]
# [30.414720000000003, 65.69247999999999, 7.813344000000001, 3.853024000000005]
# [42.455616, 63.738976, 4.7362560000000045, 4.281311999999993]
# [54.45328, 29.706208000000004, 5.539071999999997, 5.084128]
# [220.40412800000001, 15.903552000000001, 3.5958719999999857, 4.318496]
# [73.93007999999999, 19.50144, 3.825248000000002, 4.606336000000002]
# [65.040416, 20.121024000000002, 8.997408000000007, 5.225919999999999]
# [56.932064000000004, 19.878432, 6.263263999999992, 2.9632959999999997]
# [73.94374400000001, 70.71119999999999, 6.734559999999988, 5.926368000000011]
# [49.6216, 36.368192, 4.150047999999998, 4.727743999999994]
# [87.87743999999999, 2.503424, 5.131839999999997, 4.794944]
# [147.397824, 0.819616, 5.8723839999999825, 8.970528]
# [180.5552, 41.163360000000004, 6.57305599999998, 5.737983999999997]
# [222.936224, 18.324096, 1.06377599999999, 2.7377280000000006]
# [192.633728, 34.570144, 4.798304000000002, 4.182527999999998]
# [194.745152, 29.519392000000003, 8.037791999999996, 6.990367999999997]
# [62.31948800000001, 7.332191999999999, 7.596735999999993, 5.2261440000000015]
# [41.30784, 15.346464000000001, 35.450688, 4.323423999999999]
# [41.30784, 0.0, 85.098048, 21.279328]
# [53.168864, 59.693535999999995, 18.695263999999995, 9.509248000000014]
# [49.666848, 57.080576, 5.199263999999999, 7.448447999999992]
# [61.210015999999996, 34.256992000000004, 40.86544000000001, 21.415968]
# [59.36336, 30.606912, 3.974879999999999, 5.603135999999999]
# [129.82300800000002, 216.592992, 7.073247999999978, 7.4070079999999905]
# [174.871648, 217.449344, 4.455360000000013, 6.550656000000004]
# [137.851168, 183.56822400000001, 5.339488000000017, 14.37609599999999]
# [128.65283200000002, 212.123744, 4.977727999999985, 11.876256000000012]
# [125.56790400000001, 210.419552, 4.073439999999991, 13.58044799999999]
# [106.85427200000001, 208.143264, 2.7415359999999964, 15.856736000000012]
# [183.645728, 217.42179199999998, 3.469760000000008, 6.578208000000018]
# [113.83344, 70.499968, 5.833184000000003, 4.499936000000005]
# [181.995072, 98.89219200000001, 6.658175999999997, 5.872159999999994]
# [187.292896, 96.147968, 3.1718399999999747, 10.380607999999995]
# [175.656768, 127.10230399999999, 2.6828479999999786, 7.72777600000002]
# [165.211648, 123.554144, 9.052512000000007, 8.24051200000001]
# [34.733664000000005, 157.27129599999998, 7.301503999999994, 11.704672000000045]
# [62.187327999999994, 131.220096, 5.421024000000003, 6.833568000000014]
# [170.191168, 36.921024, 2.914463999999981, 14.530879999999996]
# [179.003328, 106.435168, 9.711967999999985, 12.142591999999993]
# [173.945184, 105.32121599999999, 9.802463999999986, 11.282880000000006]
# [45.312064, 47.724095999999996, 11.352320000000006, 16.88758400000001]
# [75.21136, 36.023904, 8.908928000000003, 12.255712000000003]
# [130.8328, 35.212576, 13.227648000000016, 12.003488000000004]
# [135.00883199999998, 44.805152, 13.151936000000035, 9.763488000000002]
# [170.3744, 43.527007999999995, 7.342719999999986, 11.665696000000004]
# [166.737312, 170.398368, 5.6255359999999826, 7.314495999999991]
# [52.879456, 111.39564800000001, 8.554784000000005, 7.7586880000000065]
# [62.65728000000001, 114.40688, 6.017983999999991, 8.44435200000001]
# [28.753312, 111.05404800000001, 8.68224, 14.234751999999986]
# [180.05097600000002, 104.11856, 5.656671999999986, 8.520064000000005]
# [124.64412800000001, 81.569824, 6.954527999999996, 3.045504000000008]
# [160.000064, 148.829632, 8.118431999999984, 7.332639999999998]
# [6.321728, 121.77110400000001, 17.360672, 54.68176]
# [56.280224000000004, 198.212, 8.419039999999995, 17.48768000000001]
# [54.022976, 144.384128, 11.590431999999993, 18.293408]
# [54.5664, 137.341568, 9.106719999999996, 20.73859200000001]
# [77.105504, 165.868416, 5.996928000000011, 11.820704000000006]
# [80.456096, 158.02550399999998, 10.536736000000005, 25.12832000000003]
# [91.716128, 157.856608, 7.601888000000002, 24.76140799999999]
# [104.684608, 164.826368, 2.9637439999999913, 22.09827200000001]
# [107.91468800000001, 165.03423999999998, 3.405247999999986, 22.626240000000024]
# [206.426528, 173.02432, 7.497056000000015, 10.165568000000007]
# [223.87792, 144.09830399999998, 0.12208000000001107, 1.070272000000017]
# [215.01737599999998, 145.189184, 3.5530880000000025, 21.204735999999997]
# [219.65260800000001, 143.802624, 4.347391999999985, 21.596959999999996]
# [48.078912, 5.714688, 9.313695999999993, 6.9366080000000006]
# [39.393088, 2.7836480000000003, 16.037952000000004, 11.906272000000001]
# [31.806880000000003, 0.0, 15.961567999999996, 10.582432]
# [33.707296, 27.12752, 5.733952000000002, 6.299103999999996]
# [59.432351999999995, 25.818688, 5.781664000000006, 3.3584320000000005]
# [28.973727999999998, 82.59977599999999, 0.09721600000000308, 0.4659200000000112]
# [28.734496, 81.000864, 0.5723200000000013, 1.5989119999999843]
# [27.288576, 79.016672, 6.807359999999996, 15.190336000000002]
# [42.17248, 72.963296, 6.677888000000003, 13.144768]
# [34.33024, 82.509952, 3.1451840000000004, 7.293216000000001]
# [69.04464, 90.723136, 16.820607999999993, 15.926176000000012]
# [57.871968, 73.583328, 4.617536000000001, 5.290208000000007]
# [81.070752, 68.740224, 9.425472, 15.771615999999995]
# [54.847967999999995, 109.004448, 15.668127999999996, 8.257312000000013]
# [51.177952000000005, 108.77776, 7.941248000000002, 7.436800000000005]
# [48.276256, 11.013408, 36.647743999999996, 17.354624]
# [77.342944, 13.448512000000001, 14.129024000000001, 8.219007999999999]
# [65.38224, 26.925248, 10.670240000000007, 11.213216]
# [89.069344, 65.521568, 2.637824000000009, 6.700736000000006]
# [126.29523200000001, 85.735328, 10.348351999999991, 11.906047999999998]
# [145.601568, 109.88252800000001, 8.162560000000013, 4.830335999999988]
# [116.387488, 110.96848, 26.036863999999994, 6.389375999999999]
# [170.51977599999998, 158.403392, 13.53072000000003, 2.97180800000001]
# [127.53798400000001, 182.510944, 4.736479999999986, 13.286784000000011]
# [94.033184, 159.39212799999999, 6.6563839999999885, 11.595584000000002]
# [84.88704, 174.044192, 12.627775999999997, 10.628799999999984]
# [49.278208, 34.107584, 12.797344000000002, 5.600672000000003]
# [28.938784, 217.69395200000002, 3.3951680000000053, 6.306047999999976]
# [71.412768, 28.307775999999997, 8.505055999999996, 17.138016000000007]
# [124.54220800000002, 0.0, 11.872895999999969, 25.275488000000003]
# [220.37836800000002, 137.938752, 3.621631999999977, 19.49113600000001]
# [78.169728, 17.828832, 8.727487999999994, 13.4344]
# [81.965408, 12.297376, 2.7572159999999997, 10.771487999999998]
# [83.373024, 63.47331199999999, 27.211296000000004, 44.72742400000001]
# [156.389632, 201.077856, 6.125952000000012, 22.922144000000003]
# [140.271488, 214.02124799999999, 8.249696, 9.978752000000014]
# [140.962752, 211.577408, 11.732, 12.422592000000009]
# [40.69968, 29.187872, 10.033183999999999, 9.797760000000004]
# [159.36256, 50.339743999999996, 10.404127999999986, 5.722080000000005]
# [59.055136000000005, 222.525408, 2.6864319999999964, 1.4745920000000012]
# [67.984672, 221.863936, 5.953247999999988, 2.1360640000000046]
# [187.195456, 180.413632, 16.860479999999995, 5.505696]
# [165.31603199999998, 173.09017599999999, 9.41494400000002, 8.507072000000022]
# [204.720768, 189.711648, 8.473472000000015, 4.4329600000000084]
# [205.790144, 193.704, 12.70908799999998, 2.9238719999999887]
# [165.21075199999999, 88.666592, 6.3190400000000295, 3.7533439999999985]
# [166.08368000000002, 98.129024, 5.877311999999989, 5.046720000000008]
# [172.728192, 129.60304, 9.537696000000011, 8.970976000000007]
# [157.011904, 37.16384, 7.207424000000032, 20.787872000000007]
# [140.233632, 43.240288, 10.543679999999995, 11.227328]
# [132.896064, 33.166784, 5.827584000000002, 7.037632000000002]
# [146.683712, 12.541088, 6.256543999999963, 3.387999999999998]
# [138.19993599999998, 9.299807999999999, 5.061952000000019, 15.927968]
# [138.403776, 168.699104, 6.6351040000000125, 6.446271999999993]
# [185.587136, 199.166688, 3.6339519999999936, 18.47551999999999]
# [146.70364800000002, 188.162016, 11.202463999999964, 4.426687999999984]
# [49.182784000000005, 104.35555199999999, 3.702943999999995, 5.93734400000001]
# [67.46454399999999, 123.134592, 22.496096000000023, 7.370944000000009]
# [57.302112, 37.293536, 11.856320000000004, 16.742207999999998]
# [63.096992, 45.017728000000005, 7.348544000000004, 9.468031999999994]
# [79.169216, 116.10748800000002, 20.010143999999997, 9.383807999999974]
# [65.455936, 111.853952, 27.622336000000004, 15.841055999999995]
# [66.879904, 78.673728, 27.438879999999997, 32.243904]
# [67.51897600000001, 95.731776, 25.78867199999999, 19.087488000000008]
# [67.668832, 99.89683199999999, 3.202528000000001, 10.18640000000002]
# [76.23459199999999, 76.159776, 6.19628800000001, 18.670176000000012]
# [206.444896, 192.34275200000002, 7.954239999999999, 10.409055999999993]
# [176.08528, 147.18704, 11.744096000000013, 9.078047999999995]
# [161.90159999999997, 152.208896, 2.5222400000000107, 10.566527999999977]
# [93.659552, 223.71171199999998, 1.7704959999999943, 0.28828800000002275]
# [153.370336, 4.654272000000001, 28.76115199999998, 14.270591999999999]
# [195.201888, 40.851776, 13.99708799999999, 14.960735999999997]
# [192.54256, 32.004, 15.441664000000003, 15.837471999999998]
# [191.206176, 20.912416, 11.341343999999992, 20.356896]
# [177.475424, 69.69424, 23.16787199999999, 8.641248000000004]
# [17.833312, 78.499904, 18.499936000000005, 23.000096]
# [85.166592, 101.333344, 22.83344000000001, 5.166560000000004]
# [115.166688, 10.333344, 15.333247999999998, 2.166751999999999]
# [109.690784, 2.6756800000000003, 7.478911999999994, 7.408352000000001]
# [76.50249600000001, 152.25728, 8.190111999999985, 7.702911999999998]
# [83.53139200000001, 146.99552, 7.902719999999988, 7.384384000000011]
# [71.60495999999999, 86.7552, 4.149152000000001, 14.422015999999985]
# [90.764128, 56.157247999999996, 6.221375999999992, 6.506080000000011]
# [95.62134400000001, 88.381664, 13.150591999999989, 7.1865920000000045]
# [52.850112, 111.697824, 21.371839999999985, 16.846592000000015]
# [138.329184, 103.80899199999999, 6.4025919999999985, 12.445663999999994]
# [84.49056, 116.71161599999999, 10.349472000000006, 13.327776]
# [53.744544000000005, 37.191615999999996, 7.512287999999991, 7.61824]
# [148.307488, 143.707872, 2.556063999999992, 8.37961599999997]
# [107.504992, 39.882752, 6.734335999999999, 8.644383999999995]
# [57.832992, 221.013632, 2.692927999999995, 2.986367999999999]
# [58.05744, 212.93888, 22.09939200000001, 11.061119999999988]
# [188.041504, 171.070368, 4.514944000000014, 14.079296]
# [171.978464, 167.1152, 4.376064000000014, 8.02345600000001]
# [14.806847999999999, 179.719232, 5.844608000000001, 5.100703999999979]
# [144.352544, 151.65225600000002, 6.834239999999994, 9.201919999999973]
# [146.230112, 82.829824, 10.545695999999992, 6.371008000000003]
# [145.708416, 87.1136, 11.042304000000001, 6.930335999999997]
# [138.77830400000002, 156.100672, 7.794975999999963, 13.432383999999985]
# [101.425856, 46.222624, 6.0166400000000095, 7.376319999999993]
# [118.565888, 21.333088, 17.843391999999994, 9.88176]
# [100.920736, 80.595872, 14.011424000000005, 3.604383999999996]
# [67.410112, 80.235904, 4.976608000000013, 6.01731199999999]
# [46.65024, 46.4632, 6.871200000000002, 10.377695999999993]
# [102.95308800000001, 149.263296, 16.747808000000006, 7.724863999999997]
# [91.709184, 176.22976, 6.394080000000002, 4.59177600000001]
# [50.978368, 206.948896, 5.514656000000002, 4.093600000000009]
# [194.25145600000002, 65.97740800000001, 8.32831999999999, 6.163359999999983]
# [39.018112, 15.158976, 12.886271999999998, 14.795872000000003]
# [19.331872, 22.289344, 10.824127999999998, 11.948160000000001]
# [11.759552000000001, 8.993599999999999, 8.323167999999997, 22.288672]
# [34.551103999999995, 36.500128000000004, 7.215488000000008, 8.339743999999996]
# [181.856416, 204.858528, 16.298912, 15.37088]
# [148.641696, 139.58896, 7.0994560000000035, 5.606496000000021]
# [146.450528, 135.170784, 3.2119360000000086, 8.03958400000002]
# [200.667712, 2.7332479999999997, 4.620672000000013, 11.086208]
# [97.754272, 203.326368, 13.150592000000003, 20.673631999999998]
# [91.05219199999999, 208.683776, 9.696736000000016, 10.399872000000016]
# [78.667008, 199.184384, 15.457567999999995, 10.279584]
# [39.286463999999995, 183.91296, 8.537312, 40.08704]
# [45.436384, 190.904672, 6.708352000000005, 9.681056000000012]
# [26.285951999999998, 197.49632, 10.702943999999999, 26.503680000000003]
# [25.327232000000002, 206.154144, 3.2775679999999987, 17.845855999999998]
# [16.26352, 203.19689599999998, 9.593024, 19.92368000000002]
# [0.0, 221.873792, 2.694944, 2.0009919999999966]
# [64.803648, 65.855328, 6.2733439999999945, 9.922752000000003]
# [38.02624, 74.557728, 17.496192, 14.236992]
# [38.422944, 91.75152, 14.00224, 8.004415999999992]
# [7.527296000000001, 98.197344, 17.666432, 31.60617599999999]
# [23.232608, 88.70960000000001, 14.727328, 9.053855999999996]
# [10.866464, 86.533664, 22.81328, 10.665983999999995]
# [16.731455999999998, 96.664512, 12.781664000000003, 6.194720000000004]
# [13.128864, 104.11721600000001, 5.168575999999998, 19.54489599999998]
# [0.0, 106.58144, 13.258111999999999, 18.651808000000003]
# [0.0, 165.542496, 7.064511999999999, 4.16640000000001]
# [184.417408, 155.118208, 14.666848000000016, 5.904191999999995]
# [174.608224, 48.8488, 16.786111999999974, 22.427999999999997]
# [185.696672, 85.807456, 13.685727999999983, 16.847488]
# [198.239552, 100.550912, 9.31056000000001, 8.891456000000005]
# [197.657152, 89.025888, 14.81625600000001, 22.134336000000005]
# [182.935648, 73.437952, 6.784288000000032, 10.148544000000001]
# [183.436288, 56.6776, 21.461888000000016, 39.964512]
# [163.176608, 11.764928, 16.463775999999996, 10.340511999999999]
# [164.47647999999998, 2.694048, 14.352800000000002, 9.256576]
# [9.552032, 127.33728, 2.3208640000000003, 15.13679999999998]
# [87.898272, 216.30336, 8.932896, 7.696640000000002]
# [68.21248, 197.78281600000003, 16.998688, 26.217183999999975]
# [131.18067200000002, 154.47711999999999, 11.088447999999971, 2.8750400000000127]
# [158.022368, 149.332736, 4.271903999999978, 5.134751999999992]
# [85.438976, 44.535904, 13.411776000000003, 8.462496000000002]
# [28.529760000000003, 35.226016, 5.635839999999995, 9.520671999999998]
# [213.202752, 176.63632, 10.335584000000011, 7.167103999999995]
# [119.485856, 160.16448, 6.624127999999999, 6.939295999999985]
# [157.563616, 155.596448, 11.236063999999999, 30.45593599999998]
# [199.189536, 194.68511999999998, 8.540896000000004, 25.755743999999993]
# [93.183104, 132.692672, 10.754688000000002, 18.613056]
# [154.266336, 139.240192, 18.684736000000015, 6.371007999999989]
# [116.625824, 183.279264, 6.878368000000009, 11.11263999999997]
# [110.23823999999999, 189.648704, 9.706368000000012, 7.814239999999984]
# [112.438144, 184.99420800000001, 7.082207999999994, 9.734815999999995]
# [176.311296, 10.161536, 12.718272000000013, 12.4488]
# [187.800928, 0.101696, 13.465983999999992, 7.004480000000001]
# [137.82272, 22.266048, 8.030847999999992, 3.384415999999998]
# [16.407104, 157.935008, 9.182879999999997, 15.900416000000007]
# [209.74352000000002, 185.700928, 9.478111999999982, 23.21782399999998]
# [204.82112, 194.876192, 9.22006399999998, 19.726560000000006]
# [163.504544, 24.319904, 12.180447999999984, 6.229664]
# [201.066208, 42.097663999999995, 9.589888000000002, 9.911328000000005]
# [51.078720000000004, 0.0, 5.085248, 2.79104]
# [154.91392, 63.634368, 6.135584000000023, 9.045343999999993]
# [0.0, 201.057024, 4.332832, 8.077215999999993]
# [0.0, 92.658944, 1.4728, 2.5966080000000034]
# [3.127488, 97.224288, 5.3704, 5.322912000000002]
# [0.0, 71.54896, 7.83104, 2.6691840000000013]
# [158.675552, 90.191808, 10.664191999999986, 17.075072000000006]
# [193.32633600000003, 120.736672, 9.334079999999972, 12.563264000000004]
# [168.381696, 203.27104, 5.2716159999999945, 3.501119999999986]
# ...
# [147.93587200000002, 28.245504000000004, 6.5282559999999705, 4.592672]
# [190.912736, 27.940416, 10.987200000000001, 10.627232]
# [187.72208, 23.172576, 5.048064000000011, 18.518976000000002]
# [173.333664, 71.09984, 9.888031999999981, 5.038656000000003]
# [156.825536, 92.120896, 10.958303999999998, 11.819808000000009]
# [147.352576, 91.56044800000001, 8.911392000000006, 14.172479999999993]
# [79.14704, 57.783936000000004, 5.655103999999994, 8.642143999999995]
# [164.98316799999998, 117.83295999999999, 10.191776000000033, 3.9016320000000064]
# [156.461536, 123.772992, 5.470976000000007, 6.338752000000014]
# [126.794752, 173.14752, 7.737183999999999, 6.930784000000017]
# [76.09347199999999, 176.845536, 2.523136000000008, 9.526719999999983]
# [96.28192, 189.751744, 6.099744000000001, 5.570432000000011]
# [82.907552, 186.788, 8.337280000000007, 11.929567999999989]
# [98.480256, 199.6904, 4.19507200000001, 12.156031999999982]
# [222.90374400000002, 184.91424, 1.0962559999999826, 6.5531199999999785]
# [185.37344, 184.412256, 6.046880000000016, 6.422751999999974]
# [74.604544, 202.596576, 12.080767999999992, 4.9934080000000165]
# [187.067104, 128.452352, 9.157567999999998, 2.9321600000000103]
# [44.692256, 164.515456, 13.238624000000002, 9.670303999999987]
# [146.556032, 9.752288, 13.026272000000006, 7.064288000000001]
# [142.34662400000002, 15.482208, 12.72812799999997, 10.474463999999998]
# [122.88416000000001, 12.9192, 11.501728000000014, 25.782847999999998]
# [129.163552, 9.49648, 4.657631999999978, 19.226368]
# [199.5, 169.333248, 24.5, 27.579104]
# [159.20419199999998, 171.693984, 4.666368000000034, 21.421344000000005]
# [43.874208, 95.03984, 11.591103999999994, 11.469024000000005]
# [169.545824, 135.270016, 8.376479999999987, 11.835487999999998]
# [184.792608, 136.774624, 1.9582080000000133, 22.549408]
# [32.699968, 113.419488, 4.893056000000001, 13.275136000000003]
# [166.074048, 165.79427199999998, 4.7349120000000084, 26.68489600000001]
# [154.34720000000002, 173.605376, 4.161919999999981, 20.087199999999996]
# [37.406432, 23.962624, 13.670048000000001, 6.754271999999997]
# [105.777504, 101.25718400000001, 17.924704000000006, 11.006687999999997]
# [196.12588799999997, 18.650464, 9.43622400000001, 9.675904000000003]
# [145.17619200000001, 12.781664, 2.4767679999999928, 9.823296000000003]
# [184.395456, 160.565664, 11.30304000000001, 6.294399999999996]
# [86.543968, 73.394944, 7.023967999999982, 4.110848000000004]
# [73.92672, 53.52704, 14.696416, 13.573055999999994]
# [78.35856, 23.66448, 21.814912000000007, 24.390463999999998]
# [186.84064, 31.706304000000003, 8.946335999999974, 20.214208]
# [143.81785599999998, 42.924672, 7.840000000000003, 7.248415999999999]
# [101.314752, 87.16288, 5.860287999999997, 11.267647999999994]
# [54.507488, 83.206816, 10.667104000000002, 9.135391999999996]
# [65.757888, 74.897088, 9.500736000000003, 9.98569599999999]
# [48.414688, 83.91152000000001, 15.380288000000007, 10.499103999999988]
# [55.688192, 95.40204800000001, 7.996352000000002, 6.020447999999988]
# [42.214591999999996, 92.380512, 20.251616, 11.656735999999995]
# [49.092287999999996, 105.93945599999999, 9.916032000000001, 4.912768]
# [94.323936, 205.585408, 12.62688, 9.681279999999987]
# [40.67952, 133.267232, 8.117984000000007, 5.716927999999996]
# [36.03936, 137.884544, 9.339008, 6.8602240000000165]
# [31.565184000000002, 162.223488, 5.850655999999994, 4.621567999999996]
# [8.341984, 154.88457599999998, 14.474879999999999, 2.8450240000000235]
# [0.0, 0.0, 8.95552, 18.212320000000002]
# [0.0, 132.10870400000002, 0.508928, 2.4624319999999784]
# [63.501087999999996, 66.224704, 4.173568000000003, 12.616351999999992]
# [85.826048, 72.433984, 3.6718079999999986, 4.424447999999998]
# [34.100416, 90.134912, 7.0790719999999965, 6.025824]
# [24.020864, 99.35161599999999, 4.863264000000001, 5.2299520000000115]
# [12.130944000000001, 113.36953599999998, 9.285023999999998, 17.049984000000023]
# [139.546176, 92.59151999999999, 20.616287999999997, 6.288800000000009]
# [0.0, 21.7224, 21.1736, 30.634015999999995]
# [194.97744, 181.570592, 29.02256, 22.986432000000008]
# [184.324448, 183.138144, 16.054304000000002, 15.442335999999983]
# [12.78704, 211.136576, 5.316864000000001, 10.879008000000027]
# [128.472736, 135.365664, 5.418336000000011, 5.192095999999992]
# [137.741184, 126.012768, 10.756256000000008, 12.994912]
# [140.686112, 130.110176, 8.212735999999978, 9.543968000000007]
# [132.890464, 153.803328, 8.60294399999998, 3.2408320000000117]
# [83.33584, 203.93856, 10.117856000000003, 6.959679999999992]
# [138.659808, 209.95856, 10.241056000000015, 10.474240000000009]
# [131.17305599999997, 196.030912, 17.23859200000004, 4.198656]
# [115.14944, 183.53888, 13.84656000000001, 11.637471999999974]
# [129.34992, 144.048576, 8.223488000000003, 12.37936000000002]
# [149.742208, 222.014464, 6.202112, 1.9855359999999962]
# [80.333344, 70.0, 6.000064000000009, 4.499936000000005]
# [73.753568, 79.367008, 6.217792000000003, 8.290239999999997]
# [85.7304, 59.399648, 5.9091200000000015, 7.58486400000001]
# [90.93705600000001, 39.098976, 15.345791999999989, 21.431200000000004]
# [99.103872, 21.697983999999998, 10.530240000000006, 19.05008]
# [189.18457600000002, 64.47347199999999, 14.377887999999984, 15.054592000000014]
# [135.437344, 0.0, 5.311263999999994, 3.85728]
# [176.038016, 0.0, 4.004671999999999, 5.38832]
# [0.0, 62.978048, 4.953088, 3.883263999999997]
# [196.479136, 79.00502399999999, 6.072863999999981, 10.149215999999996]
# [133.41552000000001, 25.299456, 6.324191999999982, 10.781568]
# [120.12313599999999, 18.10032, 5.277440000000013, 7.674464]
# [178.74147200000002, 56.889504, 2.8835519999999804, 6.3922879999999935]
# [198.09888, 97.88911999999999, 19.635167999999993, 20.443808000000004]
# [99.544928, 197.816192, 8.197727999999998, 7.4372479999999825]
# [184.298464, 28.699104000000002, 6.63712000000001, 4.434079999999998]
# [39.982208, 97.93548799999999, 9.480576, 17.33401600000002]
# [62.85104, 90.273792, 5.348671999999993, 9.652832000000004]
# [74.79964799999999, 87.12793599999999, 5.930848000000012, 15.676640000000006]
# [78.01091199999999, 85.277024, 4.908287999999999, 23.702112]
# [192.807552, -12.899263999999999, 5.118400000000008, 18.279519999999998]
# [208.86432, 0.0, 6.575520000000012, 4.61328]
# [198.264192, 0.0, 3.7425919999999735, 5.655552]
# [201.064416, 41.84992, 18.203360000000004, 11.162144000000005]
# [181.48502399999998, 28.60368, 9.16518400000001, 6.533184000000002]
# [166.046496, 138.55094400000002, 3.36336, 8.554112000000003]
# [181.90793599999998, 123.813312, 5.2812480000000335, 13.587392000000023]
# [216.04576, 70.79968000000001, 4.666815999999983, 12.035967999999997]
# [221.578784, 86.064832, 2.421215999999987, 9.744]
# [218.67305599999997, 84.134624, 4.4596160000000395, 10.031391999999997]
# [208.88134399999998, 83.52668800000001, 9.54867200000001, 15.923711999999995]
# [149.85779200000002, 86.672768, 6.267967999999996, 8.14979199999999]
# [156.59951999999998, 79.748032, 17.918656, 15.501920000000013]
# [101.12592, 111.641824, 7.72038400000001, 10.367391999999981]
# [217.25715200000002, 110.177088, 6.742847999999981, 4.614848000000009]
# [223.40886400000002, 48.724703999999996, 0.5911359999999775, 1.0915520000000072]
# [219.722496, 118.474272, 4.277503999999993, 14.148960000000002]
# [189.262752, 62.455232, 10.788287999999994, 5.193663999999991]
# [78.247456, 122.00720000000001, 5.400192000000004, 5.831615999999997]
# [85.435168, 223.76345600000002, 1.9635839999999973, 0.23654399999998077]
# [91.07459200000001, 200.975936, 8.199967999999984, 9.493792000000013]
# [205.43219200000001, 178.916192, 5.352479999999986, 8.949248000000011]
# [212.07737600000002, 175.098784, 11.618655999999987, 16.219616000000002]
# [18.822944, 174.55334399999998, 14.947296000000001, 14.150304000000034]
# [33.910016, 171.488576, 10.668447999999998, 30.337439999999987]
# [45.000704, 176.47503999999998, 6.316127999999999, 21.695968000000022]
# [63.821184, 175.161056, 14.758911999999995, 7.35772799999998]
# [147.887264, 72.836288, 34.239968000000005, 14.906304000000006]
# [109.223072, 40.083231999999995, 3.4130879999999877, 9.656640000000003]
# [80.799264, 16.877504, 7.612864000000016, 6.353760000000001]
# [5.767552, 32.373376, 8.492512, 6.094367999999996]
# [162.688736, 0.0, 17.362240000000014, 15.614592000000002]
# [173.791072, 6.335392, 11.122271999999981, 17.731168]
# [191.649248, 18.233376, 5.12736000000001, 8.234912000000001]
# [33.671904000000005, 0.961632, 9.679711999999995, 13.687296]
# [88.959808, 5.6488320000000005, 11.101439999999997, 10.318783999999999]
# [123.71161599999999, 58.909312, 15.059296000000018, 20.434176000000008]
# [134.38700799999998, 93.813216, 28.173824000000025, 24.808447999999984]
# [86.66739199999999, 134.918336, 14.530656000000008, 23.755871999999982]
# [96.753216, 142.216256, 14.520128, 18.176479999999998]
# [163.94268799999998, 150.060064, 8.753472000000016, 12.416543999999988]
# [0.0, 117.938912, 1.577856, 3.433472000000009]
# [0.0, 106.588384, 15.325855999999998, 12.284608000000006]
# [37.314816, 76.57328, 11.286912000000001, 21.39536000000001]
# [11.732224, 79.033248, 9.748031999999997, 17.535616000000005]
# [0.0, 84.64937599999999, 8.350048, 12.237344000000022]
# [202.041952, 166.13161599999998, 11.380544000000015, 13.096608000000032]
# [80.582656, 107.631104, 11.886111999999997, 7.2504320000000035]
# [92.289344, 94.138464, 26.51577599999999, 6.4491840000000025]
# [87.223136, 103.235328, 10.677408, 8.529696000000001]
# [92.397088, 100.528064, 10.643135999999998, 6.778687999999988]
# [134.714496, 200.433184, 6.5607359999999915, 9.39724799999999]
# [13.585600000000001, 157.006752, 13.536991999999996, 11.279743999999994]
# [0.0, 174.402368, 40.329856, 26.94272000000001]
# [0.0, 192.29548799999998, 8.535968, 15.783712000000037]
# [0.0, 73.357536, 5.249888, 3.656576000000001]
# [0.0, 77.78175999999999, 16.665824, 13.409536000000017]
# [64.08505600000001, 6.724480000000001, 2.9995839999999987, 7.917503999999998]
# [59.822559999999996, 6.953184, 2.864512000000005, 7.341823999999999]
# [85.35027199999999, 104.689984, 6.325984000000005, 7.959167999999991]
# [105.07235200000001, 63.923552, 6.963039999999992, 8.92774399999999]
# [167.873664, 22.063552, 11.023264000000012, 5.224352]
# [20.457024, 194.56416, 6.669823999999998, 2.7858880000000283]
# [1.07296, 142.07871999999998, 8.643264, 3.7508800000000235]
# [20.406848, 23.093056, 3.8653440000000003, 7.964544]
# [0.0, 19.494495999999998, 4.91568, 7.891968000000002]
# [0.0, 26.677504, 13.047776, 3.5456959999999995]
# [18.375616, 161.970592, 13.871423999999998, 3.5096320000000105]
# [20.453664, 184.36544, 7.738303999999999, 7.335999999999984]
# [18.394432, 181.09145600000002, 13.172768000000001, 5.18671999999998]
# [34.040608, 142.360512, 4.536896000000006, 5.479711999999978]
# [55.383328, 178.60483200000002, 9.602207999999997, 10.019967999999977]
# [87.43952, 12.103392, 6.8857599999999906, 7.142464]
# [103.69072, 10.87408, 3.459680000000006, 6.337184000000001]
# [96.717152, 10.512544, 2.5500159999999994, 6.042399999999999]
# [105.67872, 2.21088, 6.069056000000003, 5.6212800000000005]
# [82.162528, 5.367936, 24.561375999999996, 8.305472]
# [14.839103999999999, 168.082656, 35.029792, 12.832064000000003]
# [21.308896, 55.432832, 21.020383999999996, 8.711360000000006]
# [28.972384, 14.472864000000001, 8.647967999999995, 8.479295999999998]
# [175.457408, 107.585408, 21.13372799999999, 11.634336000000005]
# [177.500064, 122.66665599999999, 12.243840000000006, 18.421760000000006]
# [179.950176, 118.16672000000001, 7.373184000000009, 4.074559999999977]
# [146.02716800000002, 62.361376, 7.715007999999983, 22.167712]
# [131.793536, 96.289088, 10.865120000000019, 6.508319999999998]
# [108.697792, 215.498976, 19.218303999999975, 8.501024000000001]
# [78.406944, 218.821792, 20.192704000000006, 5.178208000000012]
# [119.53872, 4.0918079999999994, 4.894624000000007, 8.510656]
# [184.30787199999997, 18.295872, 6.680128000000025, 5.5686399999999985]
# [194.83788800000002, 15.24656, 13.26751999999999, 8.543359999999998]
# [163.356704, 120.185856, 22.21587199999999, 17.816959999999995]
# [200.385696, 110.849536, 19.921215999999987, 14.222656]
# [210.027552, 105.522816, 13.972448000000014, 15.841503999999986]
# [219.58272, 106.623328, 4.417280000000005, 8.693215999999993]
# [223.16828800000002, 84.878304, 0.8317119999999818, 3.3485759999999942]
# [12.636512, 180.64256, 10.733632, 18.989599999999996]
# [21.3528, 187.56304, 8.282176000000003, 13.244896000000011]
# [42.475104, 189.260064, 11.351199999999999, 21.298816000000016]
# [55.918016, 188.429472, 9.117247999999996, 23.465119999999985]
# [62.851487999999996, 186.55728, 4.789792000000013, 7.793183999999997]
# [217.528192, 178.401216, 6.47180800000001, 8.037567999999993]
# [196.997248, 186.228672, 27.002751999999987, 30.151296000000002]
# [71.53887999999999, 38.823904, 6.891136000000003, 7.845600000000005]
# [12.655104, 128.58451200000002, 12.454175999999999, 10.505151999999981]
# [59.719967999999994, 77.460768, 7.048832000000004, 4.955999999999989]
# [13.63152, 111.212192, 11.008928, 4.243008000000003]
# [79.29712, 9.227680000000001, 6.78876799999999, 10.622303999999998]
# [98.601664, 68.84438399999999, 7.813568000000004, 5.931520000000006]
# [205.426368, 92.078112, 6.702976000000007, 9.313247999999987]
# [0.0, 130.959136, 3.559136, 4.432735999999977]
# [207.363072, 41.248704000000004, 16.63692800000001, 7.545439999999999]
# [101.625216, 49.706272, 9.210432000000011, 8.805887999999996]
# [55.25184, 185.43280000000001, 6.038144000000003, 4.0465599999999995]
# [14.417984, 103.27363199999999, 3.197151999999999, 7.275968000000006]
# [11.22576, 53.830112, 7.267232000000002, 5.644576000000008]
# [13.631968, 56.605247999999996, 6.55424, 3.5750400000000084]
# [95.45648, 186.314464, 4.101216000000008, 8.598912000000013]
# [92.095808, 219.651936, 11.562879999999993, 4.348063999999994]
# [97.953408, 209.906368, 7.973951999999997, 5.732832000000002]
# [7.391328, 47.74672, 5.5563199999999995, 4.630303999999995]
# [16.784095999999998, 89.418784, 6.349952000000002, 6.085408000000001]
# [53.058431999999996, 106.616608, 5.291776000000006, 5.953248000000002]
# [44.6712, 133.815808, 7.937440000000002, 6.614719999999977]
# [47.160288, 133.022176, 7.697312000000004, 4.630080000000021]
# [48.11072, 130.50867200000002, 7.276192000000002, 4.762463999999994]
# [121.66515199999999, 184.483712, 8.731296, 4.233375999999993]
# [128.875488, 219.513504, 5.622399999999999, 3.086720000000014]
# [78.091328, 145.372864, 6.217791999999989, 12.171040000000005]
# [77.032928, 141.404256, 3.3073600000000027, 8.201983999999982]
# [117.02924800000001, 193.249504, 3.968832000000006, 5.181343999999996]
# [89.05321599999999, 212.774912, 16.88243200000001, 10.118976000000004]
# [26.909792, 86.588992, 11.906271999999998, 8.307935999999998]
# [172.442144, 150.33983999999998, 9.084319999999991, 24.969504]
# [150.860192, 9.758111999999999, 12.375776000000002, 4.706912000000001]
# [151.003104, 6.017088, 10.947552000000002, 2.890719999999999]
# [145.194112, 41.716416, 12.356960000000015, 9.946496000000003]
# [207.03423999999998, 174.211296, 6.394528000000008, 3.5255359999999882]
# [208.778752, 122.816736, 8.408063999999996, 7.549695999999997]
# [217.889504, 147.80326399999998, 5.59462400000001, 7.8442560000000014]
# [217.75152, 141.33728000000002, 6.248480000000001, 10.280703999999957]
# [181.301344, 210.283584, 10.68592000000001, 13.71641600000001]
# [16.423232, 179.61865600000002, 20.993727999999997, 11.212095999999974]
# [0.0, 147.604128, 8.60384, 9.040639999999996]
# [0.0, 132.320832, 30.637600000000003, 19.271615999999995]
# [14.565152, 146.531616, 10.675840000000003, 10.196703999999983]
# [20.593216, 83.74038399999999, 11.052608000000003, 9.486400000000003]
# [24.511872, 79.709056, 19.770464, 14.934303999999997]
# [23.613632, 203.233856, 10.037664000000003, 2.6530559999999923]
# [176.38275199999998, 223.49443200000002, 1.961792000000031, 0.5055679999999825]
# [193.401152, 163.32175999999998, 7.675360000000012, 8.197056000000003]
# [10.59184, 104.89382400000001, 11.468352000000001, 7.616671999999994]
# [10.85728, 108.357536, 8.251936, 6.848576000000008]
# [216.688864, 91.267232, 7.311136000000005, 4.1175679999999915]
# [163.902368, 73.669568, 3.4975359999999966, 5.810783999999998]
# [166.361888, 73.331328, 4.459168000000005, 6.803328000000008]
# [196.485184, 63.71366400000001, 8.116415999999987, 12.108992]

# %%
# Preparing the final xml file:

def create_xml(annotations, images, categories, output_file):
    # Create the root element
    root = ET.Element("dataset")
    
    # Add images element
    images_element = ET.SubElement(root, "images")
    for image in images:
        image_element = ET.SubElement(images_element, "image")
        for key, value in image.items():
            ET.SubElement(image_element, key).text = str(value)
    
    # Add annotations element
    annotations_element = ET.SubElement(root, "annotations")
    for annotation in annotations:
        annotation_element = ET.SubElement(annotations_element, "annotation")
        for key, value in annotation.items():
            if key == "bbox" and isinstance(value, list):
                bbox_element = ET.SubElement(annotation_element, "bbox")
                for bbox_value in value:
                    ET.SubElement(bbox_element, "value").text = str(bbox_value)
            else:
                ET.SubElement(annotation_element, key).text = str(value)
    
    # Add categories element
    categories_element = ET.SubElement(root, "categories")
    for category in categories:
        category_element = ET.SubElement(categories_element, "category")
        for key, value in category.items():
            ET.SubElement(category_element, key).text = str(value)
    
    # Create a tree from the root element
    tree = ET.ElementTree(root)
    
    # Write the tree to an XML file
    tree.write(output_file, encoding='utf-8', xml_declaration=True)


output_file = 'ucsb_full_coco_format_instance_segmentation.xml'

# If file already exists, delete it:
if os.path.exists(output_file):
    os.remove(output_file)

# Create the XML file
create_xml(annotations, images, categories, output_file)

# %% [markdown]
# # YOLO Labels to PASCAL VOC XML

# %%
img_path = '/Users/vihaan/Workspace/!Datasets/Processed_Data_S24/images'
label_path = '/Users/vihaan/Workspace/!Datasets/Processed_Data_S24/labels'
output_image_path = '/Users/vihaan/Workspace/!Datasets/Processed_Data_S24/data_images/'

# Make sure the output directory exists
if not os.path.exists(output_image_path):
    os.makedirs(output_image_path)

# Remove existing files in the output directory
files = [file for file in os.listdir(output_image_path) if os.path.isfile(os.path.join(output_image_path, file))]
for file in files:
    os.remove(os.path.join(output_image_path, file))

# Setting a threshold:
threshold = 1  # how the bbox area should be at least 10 pixels

# Ensure the output directory exists
if not os.path.exists(output_image_path):
    os.makedirs(output_image_path)

# Remove existing files in the output directory
files = [file for file in os.listdir(output_image_path) if os.path.isfile(os.path.join(output_image_path, file))]
for file in files:
    os.remove(os.path.join(output_image_path, file))

for filename_temp in glob.glob(img_path+'/*'):

    # Choose a file
    filename = filename_temp.split('/')[-1].split('.')[0]

    # Read the image for image dimensions
    img = cv2.imread(f'{img_path}/{filename}.jpg')
    image = Image.fromarray(img, 'RGB')
    
    # Get the corresponding label name
    label = f'{label_path}/{filename}.txt'

    # If the label file does not exist, skip the image
    if not os.path.exists(label):
        print(f'{filename} does not have a label file')
        continue

    with open(label, 'r') as file:
        file_content = file.read()
        file_content = file_content.split('\n')
    
    lst = [item.split(' ') for item in file_content]
    
    coords = []
    for i in lst:
        coords_temp = []
        for j in i[1:]:
            coords_temp.append(float(j))
        coords.append(np.array(coords_temp, dtype='object').reshape(-1,2))
    
    label_base='<annotation>\n<folder></folder>\n<filename>{}.jpg</filename>\n<path>{}.jpg</path>\n<source>\n<database></database>\n</source>\n<size>\n<width>{}</width>\n<height>{}</height>\n<depth>3</depth>\n</size>\n<segmented>0</segmented>\n'.format(filename,filename, img.shape[0], img.shape[1])
    label_base_end = '</annotation>'

    ct = 0
    for num_labels in range(len(coords)):
        if len(coords[num_labels]) != 0:
            big_x=np.where(coords[num_labels][:,0] == max(coords[num_labels][:,0]))[0][0] # big x
            small_x=np.where(coords[num_labels][:,0] == min(coords[num_labels][:,0]))[0][0] # small x
            big_y=np.where(coords[num_labels][:,1] == max(coords[num_labels][:,1]))[0][0] # big y
            small_y=np.where(coords[num_labels][:,1] == min(coords[num_labels][:,1]))[0][0]# small y
                
            xmin, ymin = [int(coords[num_labels][small_x][0]*img.shape[0]),
                          int((coords[num_labels][small_y][1])*img.shape[1])]
            xmax, ymax = [int(coords[num_labels][big_x][0]*img.shape[0]), 
                          int((coords[num_labels][big_y][1])*img.shape[1])]

            if xmin<0 or ymin<0 or xmax<0 or ymax<0: continue
            elif xmax-xmin<1 or ymax-ymin<1: continue
            elif (xmax-xmin) *  (ymax-ymin) < threshold: continue
            else:
                label_name = '<object>\n<name>landslides</name>\n<pose>Unspecified</pose>\n<truncated>0</truncated>\n<difficult>0</difficult>\n<occluded>0</occluded>\n<bndbox><xmin>{}</xmin><xmax>{}</xmax><ymin>{}</ymin><ymax>{}</ymax></bndbox>\n</object>\n'.format(xmin, xmax, ymin, ymax)
                label_base=label_base+label_name
                ct += 1

    if ct == 0:
        continue
       #print(filename, 'does not have any labels')
    else:
        print(filename, 'has', ct, 'labels')
        label_base = label_base+label_base_end

        image.save(output_image_path + str(filename) + '.jpg', 'JPEG')
        
        xml_label_path = output_image_path + str(filename) + '.txt'
        with open(xml_label_path, 'w') as file:
            file.write(label_base)
        
        new_file_name = xml_label_path.split('.')[0] + '.xml'
        
        os.rename(xml_label_path, new_file_name)

# Print the total number of images in the output folder with .jpg extension :
print(len([file for file in os.listdir(output_image_path) if file.endswith('.jpeg')]))
# Out:
# 2011 sikkim earthquake_patch_8288_4704 has 2 labels
# 2010 Haiti_patch_4928_4480 has 4 labels
# 1987 Sichuan pre-earthquake_patch_7616_7168 has 1 labels
# 2011 sikkim earthquake_patch_9408_3360 has 5 labels
# 2011 sikkim earthquake_patch_9408_3360 has 5 labels
# 2011 sikkim earthquake_patch_8288_4704 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7616_7168 has 1 labels
# 2010 Haiti_patch_4928_4480 has 4 labels
# 1999 chamoli earthquake_patch_8064_7840 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4704_8512 has 13 labels
# 1987 Sichuan pre-earthquake_patch_2464_8960 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7616_6048 has 24 labels
# 1987 Sichuan pre-earthquake_patch_2464_8960 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7616_6048 has 24 labels
# 1987 Sichuan pre-earthquake_patch_4704_8512 has 13 labels
# 1999 chamoli earthquake_patch_8064_7840 has 1 labels
# 1987 Sichuan pre-earthquake_patch_2912_9856 has 3 labels
# 1987 Sichuan pre-earthquake_patch_8512_6944 has 1 labels
# 1999 chamoli earthquake_patch_7168_9184 has 2 labels
# 2015 gorkha earthquake_patch_6272_5152 has 3 labels
# 1987 Sichuan pre-earthquake_patch_4928_8512 has 8 labels
# 1987 Sichuan pre-earthquake_patch_4928_11200 has 1 labels
# 2015 gorkha earthquake_patch_6272_5152 has 3 labels
# 1987 Sichuan pre-earthquake_patch_4928_11200 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4928_8512 has 8 labels
# 1987 Sichuan pre-earthquake_patch_2912_9856 has 3 labels
# 1987 Sichuan pre-earthquake_patch_8512_6944 has 1 labels
# 1999 chamoli earthquake_patch_7168_9184 has 2 labels
# 1987 Sichuan pre-earthquake_patch_3360_10080 has 12 labels
# 2011 sikkim earthquake_patch_10080_2688 has 3 labels
# 1987 Sichuan pre-earthquake_patch_3808_10304 has 17 labels
# 1987 Sichuan pre-earthquake_patch_4480_11200 has 8 labels
# 2015 gorkha earthquake_patch_9408_6720 has 22 labels
# 2016 Arun rainstorm_patch_5152_3360 has 2 labels
# Sulawesi 2018_patch_24864_7392 does not have a label file
# 2015 gorkha earthquake_patch_6496_8736 has 1 labels
# Sulawesi 2018_patch_24864_7392 does not have a label file
# 2016 Arun rainstorm_patch_5152_3360 has 2 labels
# 2015 gorkha earthquake_patch_6496_8736 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3360_10080 has 12 labels
# 2011 sikkim earthquake_patch_10080_2688 has 3 labels
# 1987 Sichuan pre-earthquake_patch_3808_10304 has 17 labels
# 1987 Sichuan pre-earthquake_patch_4480_11200 has 8 labels
# 2015 gorkha earthquake_patch_9408_6720 has 22 labels
# 2010 Haiti_patch_5376_4704 has 2 labels
# 1987 Sichuan pre-earthquake_patch_6496_9408 has 8 labels
# 1999 chamoli earthquake_patch_8512_8960 has 7 labels
# 1987 Sichuan pre-earthquake_patch_8960_6048 has 10 labels
# 1987 Sichuan pre-earthquake_patch_5152_8736 has 7 labels
# 2015 gorkha earthquake_patch_10752_9184 has 1 labels
# 2015 gorkha earthquake_patch_7392_5600 has 4 labels
# 1987 Sichuan pre-earthquake_patch_5152_8736 has 7 labels
# 2015 gorkha earthquake_patch_10752_9184 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6496_9408 has 8 labels
# 1987 Sichuan pre-earthquake_patch_8960_6048 has 10 labels
# 1999 chamoli earthquake_patch_8512_8960 has 7 labels
# 2015 gorkha earthquake_patch_7392_5600 has 4 labels
# 2010 Haiti_patch_5376_4704 has 2 labels
# 1987 Sichuan pre-earthquake_patch_8960_7168 has 1 labels
# 2018 Lombok_patch_6496_2464 has 1 labels
# 2015 gorkha earthquake_patch_10528_7392 has 1 labels
# 2015 gorkha earthquake_patch_10528_7392 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8960_7168 has 1 labels
# 2018 Lombok_patch_6496_2464 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6944_9856 has 1 labels
# 2011 sikkim earthquake_patch_9856_3136 has 6 labels
# 1987 Sichuan pre-earthquake_patch_4256_12544 has 25 labels
# 2015 gorkha earthquake_patch_6496_5824 has 9 labels
# 1987 Sichuan pre-earthquake_patch_7616_8064 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4928_10080 has 8 labels
# 1987 Sichuan pre-earthquake_patch_7616_9408 has 7 labels
# 2015 gorkha earthquake_patch_6496_5824 has 9 labels
# 1987 Sichuan pre-earthquake_patch_7616_8064 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7616_9408 has 7 labels
# 1987 Sichuan pre-earthquake_patch_4928_10080 has 8 labels
# 1987 Sichuan pre-earthquake_patch_6944_9856 has 1 labels
# 2011 sikkim earthquake_patch_9856_3136 has 6 labels
# 1987 Sichuan pre-earthquake_patch_4256_12544 has 25 labels
# 2015 gorkha earthquake_patch_10304_8064 has 2 labels
# 2015 gorkha earthquake_patch_5376_5152 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4480_10080 has 5 labels
# 1987 Sichuan pre-earthquake_patch_6720_9856 has 7 labels
# 1987 Sichuan pre-earthquake_patch_7392_9184 has 6 labels
# 2011 sikkim earthquake_patch_9632_3136 has 12 labels
# 1999 chamoli earthquake_patch_7616_8736 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4032_7616 has 2 labels
# 1987 Sichuan pre-earthquake_patch_6720_9856 has 7 labels
# 1987 Sichuan pre-earthquake_patch_7392_9184 has 6 labels
# 2011 sikkim earthquake_patch_9632_3136 has 12 labels
# 1999 chamoli earthquake_patch_7616_8736 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4032_7616 has 2 labels
# 2015 gorkha earthquake_patch_5376_5152 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4480_10080 has 5 labels
# 2015 gorkha earthquake_patch_10304_8064 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7392_7168 has 9 labels
# 2011 sikkim earthquake_patch_8960_2912 has 4 labels
# 2015 gorkha earthquake_patch_6944_6944 has 2 labels
# 1998 Jueili_patch_1792_2240 has 5 labels
# 1987 Sichuan pre-earthquake_patch_6272_8736 has 9 labels
# 1987 Sichuan pre-earthquake_patch_4704_10528 has 4 labels
# 1987 Sichuan pre-earthquake_patch_6944_8960 has 5 labels
# 2015 gorkha earthquake_patch_6272_6048 has 13 labels
# 2016 Arun rainstorm_patch_5824_3136 has 4 labels
# 2015 gorkha earthquake_patch_4928_5376 has 1 labels
# 2004 Cheutsu Earthquake 2004_patch_3808_4032 has 71 labels
# 1987 Sichuan pre-earthquake_patch_6272_8736 has 9 labels
# 2015 gorkha earthquake_patch_6272_6048 has 13 labels
# 2016 Arun rainstorm_patch_5824_3136 has 4 labels
# 2015 gorkha earthquake_patch_4928_5376 has 1 labels
# 2004 Cheutsu Earthquake 2004_patch_3808_4032 has 71 labels
# 1987 Sichuan pre-earthquake_patch_4704_10528 has 4 labels
# 1987 Sichuan pre-earthquake_patch_6944_8960 has 5 labels
# 2011 sikkim earthquake_patch_8960_2912 has 4 labels
# 2015 gorkha earthquake_patch_6944_6944 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7392_7168 has 9 labels
# 1998 Jueili_patch_1792_2240 has 5 labels
# 2010 Haiti_patch_4032_5152 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6720_8960 has 1 labels
# 2011 sikkim earthquake_patch_9408_3808 has 2 labels
# 2015 gorkha earthquake_patch_6720_6944 has 2 labels
# 2015 gorkha earthquake_patch_9408_6496 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7392_6048 has 18 labels
# 2015 gorkha earthquake_patch_9408_6496 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7392_6048 has 18 labels
# 2015 gorkha earthquake_patch_6720_6944 has 2 labels
# 2010 Haiti_patch_4032_5152 has 1 labels
# 2011 sikkim earthquake_patch_9408_3808 has 2 labels
# 1987 Sichuan pre-earthquake_patch_6720_8960 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3584_10080 has 8 labels
# 2015 gorkha earthquake_patch_4032_4704 has 2 labels
# 2011 sikkim earthquake_patch_8960_4032 has 6 labels
# 2014 Arun rainstorm_patch_4256_3808 has 1 labels
# 1999 chamoli earthquake_patch_8512_9856 has 1 labels
# 1987 Sichuan pre-earthquake_patch_9408_6272 has 5 labels
# 2016 Arun rainstorm_patch_5376_3360 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7168_8736 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4928_8288 has 2 labels
# 2015 gorkha earthquake_patch_12096_8288 has 1 labels
# Sulawesi 2018_patch_24864_6272 does not have a label file
# 1987 Sichuan pre-earthquake_patch_4928_8288 has 2 labels
# 2015 gorkha earthquake_patch_12096_8288 has 1 labels
# Sulawesi 2018_patch_24864_6272 does not have a label file
# 2011 sikkim earthquake_patch_8960_4032 has 6 labels
# 1987 Sichuan pre-earthquake_patch_3584_10080 has 8 labels
# 2015 gorkha earthquake_patch_4032_4704 has 2 labels
# 2016 Arun rainstorm_patch_5376_3360 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7168_8736 has 2 labels
# 2014 Arun rainstorm_patch_4256_3808 has 1 labels
# 1999 chamoli earthquake_patch_8512_9856 has 1 labels
# 1987 Sichuan pre-earthquake_patch_9408_6272 has 5 labels
# 1987 Sichuan pre-earthquake_patch_2688_10080 has 6 labels
# 2015 gorkha earthquake_patch_4704_5376 has 1 labels
# 1999 chamoli earthquake_patch_7168_8064 has 2 labels
# 1987 Sichuan pre-earthquake_patch_3360_8960 has 2 labels
# 1991 Limon Earthquake_patch_896_4480 has 19 labels
# 1987 Sichuan pre-earthquake_patch_8736_6944 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3360_8960 has 2 labels
# 1991 Limon Earthquake_patch_896_4480 has 19 labels
# 1987 Sichuan pre-earthquake_patch_8736_6944 has 1 labels
# 1999 chamoli earthquake_patch_7168_8064 has 2 labels
# 1987 Sichuan pre-earthquake_patch_2688_10080 has 6 labels
# 2015 gorkha earthquake_patch_4704_5376 has 1 labels
# 2015 gorkha earthquake_patch_4704_4928 has 3 labels
# 2018 Arun rainstorm_patch_4928_3360 has 1 labels
# 2015 gorkha earthquake_patch_10528_8288 has 1 labels
# 2015 gorkha earthquake_patch_7616_5600 has 2 labels
# 2017 Milin_patch_18592_5152 has 2 labels
# 2004 Cheutsu Earthquake 2004_patch_4032_4032 has 8 labels
# 1991 Limon Earthquake_patch_672_4704 has 2 labels
# 2015 gorkha earthquake_patch_9856_6944 has 31 labels
# 2017 Milin_patch_18592_5152 has 2 labels
# 2004 Cheutsu Earthquake 2004_patch_4032_4032 has 8 labels
# 2015 gorkha earthquake_patch_7616_5600 has 2 labels
# 1991 Limon Earthquake_patch_672_4704 has 2 labels
# 2015 gorkha earthquake_patch_9856_6944 has 31 labels
# 2015 gorkha earthquake_patch_4704_4928 has 3 labels
# 2018 Arun rainstorm_patch_4928_3360 has 1 labels
# 2015 gorkha earthquake_patch_10528_8288 has 1 labels
# Sulawesi 2018_patch_24640_7840 does not have a label file
# 1987 Sichuan pre-earthquake_patch_4928_9632 has 2 labels
# 1987 Sichuan pre-earthquake_patch_5376_8736 has 9 labels
# 1987 Sichuan pre-earthquake_patch_4256_11648 has 10 labels
# 2015 gorkha earthquake_patch_9632_6944 has 4 labels
# 1999 chamoli earthquake_patch_8736_8960 has 2 labels
# 2010 Haiti_patch_5152_4704 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4032_11424 has 7 labels
# 1987 Sichuan pre-earthquake_patch_6496_9184 has 7 labels
# 1991 Limon Earthquake_patch_1120_4704 has 9 labels
# 1991 Limon Earthquake_patch_1120_4704 has 9 labels
# 1987 Sichuan pre-earthquake_patch_6496_9184 has 7 labels
# 2010 Haiti_patch_5152_4704 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4032_11424 has 7 labels
# Sulawesi 2018_patch_24640_7840 does not have a label file
# 2015 gorkha earthquake_patch_9632_6944 has 4 labels
# 1987 Sichuan pre-earthquake_patch_4256_11648 has 10 labels
# 1999 chamoli earthquake_patch_8736_8960 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4928_9632 has 2 labels
# 1987 Sichuan pre-earthquake_patch_5376_8736 has 9 labels
# 1987 Sichuan pre-earthquake_patch_3584_11200 has 6 labels
# 2015 gorkha earthquake_patch_8288_6944 has 27 labels
# 2016 Arun rainstorm_patch_4480_4032 has 1 labels
# 2015 gorkha earthquake_patch_3808_4704 has 1 labels
# 2016 Arun rainstorm_patch_5600_2912 has 3 labels
# 1987 Sichuan pre-earthquake_patch_7392_9408 has 16 labels
# 1987 Sichuan pre-earthquake_patch_6720_10528 has 2 labels
# 2015 gorkha earthquake_patch_5152_5152 has 3 labels
# 1987 Sichuan pre-earthquake_patch_7840_6944 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4704_9632 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7392_8064 has 1 labels
# 2011 sikkim earthquake_patch_10304_4032 has 3 labels
# 2015 gorkha earthquake_patch_6496_5600 has 6 labels
# 1987 Sichuan pre-earthquake_patch_7840_6944 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4704_9632 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7392_9408 has 16 labels
# 1987 Sichuan pre-earthquake_patch_6720_10528 has 2 labels
# 2015 gorkha earthquake_patch_5152_5152 has 3 labels
# 2015 gorkha earthquake_patch_6496_5600 has 6 labels
# 1987 Sichuan pre-earthquake_patch_7392_8064 has 1 labels
# 2011 sikkim earthquake_patch_10304_4032 has 3 labels
# 1987 Sichuan pre-earthquake_patch_3584_11200 has 6 labels
# 2015 gorkha earthquake_patch_8288_6944 has 27 labels
# 2016 Arun rainstorm_patch_4480_4032 has 1 labels
# 2015 gorkha earthquake_patch_3808_4704 has 1 labels
# 2016 Arun rainstorm_patch_5600_2912 has 3 labels
# 2015 gorkha earthquake_patch_5600_6272 has 1 labels
# 1987 Sichuan pre-earthquake_patch_2688_11200 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7392_10080 has 4 labels
# 1999 chamoli earthquake_patch_6272_7168 has 1 labels
# 1987 Sichuan pre-earthquake_patch_10304_5824 has 2 labels
# 2015 gorkha earthquake_patch_4928_4928 has 7 labels
# 1999 chamoli earthquake_patch_7392_8736 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7616_9184 has 2 labels
# 1987 Sichuan pre-earthquake_patch_5600_11424 has 2 labels
# 2014 Arun rainstorm_patch_5152_3136 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3808_10528 has 26 labels
# 1987 Sichuan pre-earthquake_patch_10304_5824 has 2 labels
# 2015 gorkha earthquake_patch_4928_4928 has 7 labels
# 1999 chamoli earthquake_patch_7392_8736 has 2 labels
# 2014 Arun rainstorm_patch_5152_3136 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3808_10528 has 26 labels
# 1987 Sichuan pre-earthquake_patch_7616_9184 has 2 labels
# 1987 Sichuan pre-earthquake_patch_5600_11424 has 2 labels
# 1987 Sichuan pre-earthquake_patch_2688_11200 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7392_10080 has 4 labels
# 1999 chamoli earthquake_patch_6272_7168 has 1 labels
# 2015 gorkha earthquake_patch_5600_6272 has 1 labels
# 1987 Sichuan pre-earthquake_patch_10080_6272 has 1 labels
# 2011 sikkim earthquake_patch_8960_3360 has 11 labels
# 1987 Sichuan pre-earthquake_patch_4704_8064 has 2 labels
# 1987 Sichuan pre-earthquake_patch_6048_10080 has 10 labels
# 1987 Sichuan pre-earthquake_patch_4704_9408 has 2 labels
# 2008 Iwate_patch_8288_3136 has 12 labels
# 1987 Sichuan pre-earthquake_patch_7392_9632 has 6 labels
# 1987 Sichuan pre-earthquake_patch_4704_8064 has 2 labels
# 1987 Sichuan pre-earthquake_patch_6048_10080 has 10 labels
# 1987 Sichuan pre-earthquake_patch_7392_9632 has 6 labels
# 1987 Sichuan pre-earthquake_patch_4704_9408 has 2 labels
# 2008 Iwate_patch_8288_3136 has 12 labels
# 1987 Sichuan pre-earthquake_patch_10080_6272 has 1 labels
# 2011 sikkim earthquake_patch_8960_3360 has 11 labels
# 2011 sikkim earthquake_patch_8512_4480 has 5 labels
# 1987 Sichuan pre-earthquake_patch_5600_8736 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5600_10528 has 19 labels
# 2010 Haiti_patch_4704_4928 has 3 labels
# 1987 Sichuan pre-earthquake_patch_6272_7616 has 12 labels
# 1987 Sichuan pre-earthquake_patch_3808_11424 has 3 labels
# 1999 chamoli earthquake_patch_7840_7840 has 1 labels
# 1999 chamoli earthquake_patch_7840_7840 has 1 labels
# 2011 sikkim earthquake_patch_8512_4480 has 5 labels
# 1987 Sichuan pre-earthquake_patch_5600_8736 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3808_11424 has 3 labels
# 1987 Sichuan pre-earthquake_patch_5600_10528 has 19 labels
# 2010 Haiti_patch_4704_4928 has 3 labels
# 1987 Sichuan pre-earthquake_patch_6272_7616 has 12 labels
# Sulawesi 2018_patch_24416_6944 does not have a label file
# 1987 Sichuan pre-earthquake_patch_4928_12096 has 6 labels
# 2016 Arun rainstorm_patch_5376_2912 has 3 labels
# 1987 Sichuan pre-earthquake_patch_3360_7840 has 2 labels
# 1987 Sichuan pre-earthquake_patch_6272_10976 has 2 labels
# 2010 Haiti_patch_4928_4928 has 5 labels
# 1987 Sichuan pre-earthquake_patch_3136_10304 has 9 labels
# 1999 chamoli earthquake_patch_7168_8288 has 1 labels
# 2010 Haiti_patch_4928_4928 has 5 labels
# 1987 Sichuan pre-earthquake_patch_6272_10976 has 2 labels
# 1999 chamoli earthquake_patch_7168_8288 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3136_10304 has 9 labels
# Sulawesi 2018_patch_24416_6944 does not have a label file
# 1987 Sichuan pre-earthquake_patch_4928_12096 has 6 labels
# 2016 Arun rainstorm_patch_5376_2912 has 3 labels
# 1987 Sichuan pre-earthquake_patch_3360_7840 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4032_10528 has 5 labels
# 1987 Sichuan pre-earthquake_patch_4928_9408 has 7 labels
# 2015 gorkha earthquake_patch_10976_7840 has 10 labels
# 1987 Sichuan pre-earthquake_patch_4480_8736 has 5 labels
# 1987 Sichuan pre-earthquake_patch_4928_8064 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4480_12096 has 12 labels
# 2011 sikkim earthquake_patch_10080_3584 has 12 labels
# 1987 Sichuan pre-earthquake_patch_8960_7392 has 1 labels
# 2010 Haiti_patch_5152_5152 has 2 labels
# 2015 gorkha earthquake_patch_10080_6720 has 2 labels
# 1987 Sichuan pre-earthquake_patch_6496_10752 has 1 labels
# 2015 gorkha earthquake_patch_8960_6720 has 5 labels
# 2010 Haiti_patch_5152_5152 has 2 labels
# 2015 gorkha earthquake_patch_10080_6720 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4480_12096 has 12 labels
# 2011 sikkim earthquake_patch_10080_3584 has 12 labels
# 1987 Sichuan pre-earthquake_patch_8960_7392 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6496_10752 has 1 labels
# 2015 gorkha earthquake_patch_8960_6720 has 5 labels
# 1987 Sichuan pre-earthquake_patch_4928_9408 has 7 labels
# 2015 gorkha earthquake_patch_10976_7840 has 10 labels
# 1987 Sichuan pre-earthquake_patch_4032_10528 has 5 labels
# 1987 Sichuan pre-earthquake_patch_4928_8064 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4480_8736 has 5 labels
# 1987 Sichuan pre-earthquake_patch_3584_12320 has 4 labels
# 1987 Sichuan pre-earthquake_patch_9408_6048 has 3 labels
# 2015 gorkha earthquake_patch_7168_6272 has 9 labels
# 2016 Arun rainstorm_patch_4480_3360 has 2 labels
# 2011 sikkim earthquake_patch_10304_3360 has 6 labels
# 1987 Sichuan pre-earthquake_patch_6496_7392 has 6 labels
# 1987 Sichuan pre-earthquake_patch_4256_10976 has 4 labels
# 2015 gorkha earthquake_patch_6496_6720 has 3 labels
# 1987 Sichuan pre-earthquake_patch_6496_7392 has 6 labels
# 2011 sikkim earthquake_patch_10304_3360 has 6 labels
# 1987 Sichuan pre-earthquake_patch_4256_10976 has 4 labels
# 2015 gorkha earthquake_patch_6496_6720 has 3 labels
# 1987 Sichuan pre-earthquake_patch_9408_6048 has 3 labels
# 1987 Sichuan pre-earthquake_patch_3584_12320 has 4 labels
# 2016 Arun rainstorm_patch_4480_3360 has 2 labels
# 2015 gorkha earthquake_patch_7168_6272 has 9 labels
# 1987 Sichuan pre-earthquake_patch_2688_12320 has 1 labels
# Sulawesi 2018_patch_24864_7168 does not have a label file
# 1987 Sichuan pre-earthquake_patch_5824_10528 has 10 labels
# 1987 Sichuan pre-earthquake_patch_6496_8512 has 7 labels
# 1987 Sichuan pre-earthquake_patch_9408_7168 has 3 labels
# 2011 sikkim earthquake_patch_9184_3136 has 5 labels
# 2015 gorkha earthquake_patch_10528_8064 has 2 labels
# 2017 Milin_patch_18816_5152 has 1 labels
# 2011 sikkim earthquake_patch_9184_3136 has 5 labels
# 2015 gorkha earthquake_patch_10528_8064 has 2 labels
# 1987 Sichuan pre-earthquake_patch_9408_7168 has 3 labels
# 2017 Milin_patch_18816_5152 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5824_10528 has 10 labels
# 1987 Sichuan pre-earthquake_patch_2688_12320 has 1 labels
# Sulawesi 2018_patch_24864_7168 does not have a label file
# 1987 Sichuan pre-earthquake_patch_6496_8512 has 7 labels
# 2016 Arun rainstorm_patch_5600_3360 has 3 labels
# 1987 Sichuan pre-earthquake_patch_4704_11424 has 2 labels
# 1999 chamoli earthquake_patch_7392_7616 has 2 labels
# 2015 gorkha earthquake_patch_6272_6272 has 55 labels
# 2015 gorkha earthquake_patch_7616_6720 has 21 labels
# 1987 Sichuan pre-earthquake_patch_7616_7392 has 6 labels
# 2015 gorkha earthquake_patch_7616_6720 has 21 labels
# 2015 gorkha earthquake_patch_6272_6272 has 55 labels
# 1987 Sichuan pre-earthquake_patch_7616_7392 has 6 labels
# 2016 Arun rainstorm_patch_5600_3360 has 3 labels
# 1999 chamoli earthquake_patch_7392_7616 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4704_11424 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7392_8288 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7616_8512 has 1 labels
# 2010 Haiti_patch_4032_4704 has 6 labels
# 1987 Sichuan pre-earthquake_patch_8288_7840 has 5 labels
# 1987 Sichuan pre-earthquake_patch_4256_12768 has 19 labels
# 2016 Arun rainstorm_patch_5600_2240 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7392_6272 has 12 labels
# 2010 Haiti_patch_6496_4480 has 1 labels
# 2016 Arun rainstorm_patch_5600_2240 has 2 labels
# 2010 Haiti_patch_6496_4480 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7392_6272 has 12 labels
# 2010 Haiti_patch_4032_4704 has 6 labels
# 1987 Sichuan pre-earthquake_patch_8288_7840 has 5 labels
# 1987 Sichuan pre-earthquake_patch_7392_8288 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7616_8512 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4256_12768 has 19 labels
# 1987 Sichuan pre-earthquake_patch_7616_9632 has 2 labels
# 2011 sikkim earthquake_patch_9408_2912 has 22 labels
# 1987 Sichuan pre-earthquake_patch_4928_12320 has 6 labels
# 2011 sikkim earthquake_patch_8736_4480 has 1 labels
# 1999 chamoli earthquake_patch_8064_8960 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7616_9632 has 2 labels
# 2011 sikkim earthquake_patch_9408_2912 has 22 labels
# 1999 chamoli earthquake_patch_8064_8960 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4928_12320 has 6 labels
# 2011 sikkim earthquake_patch_8736_4480 has 1 labels
# 2015 gorkha earthquake_patch_8960_6496 has 11 labels
# 1991 Limon Earthquake_patch_896_4928 has 2 labels
# 1987 Sichuan pre-earthquake_patch_10080_7392 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4480_12320 has 24 labels
# 2015 gorkha earthquake_patch_4480_5152 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5824_10304 has 19 labels
# 2011 sikkim earthquake_patch_8960_3808 has 5 labels
# 1987 Sichuan pre-earthquake_patch_4704_9184 has 3 labels
# 1987 Sichuan pre-earthquake_patch_5824_10304 has 19 labels
# 1987 Sichuan pre-earthquake_patch_4704_9184 has 3 labels
# 2011 sikkim earthquake_patch_8960_3808 has 5 labels
# 2015 gorkha earthquake_patch_8960_6496 has 11 labels
# 1987 Sichuan pre-earthquake_patch_10080_7392 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4480_12320 has 24 labels
# 2015 gorkha earthquake_patch_4480_5152 has 1 labels
# 1991 Limon Earthquake_patch_896_4928 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4928_9184 has 2 labels
# 1987 Sichuan pre-earthquake_patch_3808_8736 has 3 labels
# 1999 chamoli earthquake_patch_7168_8512 has 3 labels
# 1998 Jueili_patch_2016_2240 has 4 labels
# 1987 Sichuan pre-earthquake_patch_8960_6272 has 6 labels
# 1987 Sichuan pre-earthquake_patch_6496_9632 has 1 labels
# 1999 chamoli earthquake_patch_7168_8512 has 3 labels
# 1987 Sichuan pre-earthquake_patch_8960_6272 has 6 labels
# 1987 Sichuan pre-earthquake_patch_6496_9632 has 1 labels
# 1998 Jueili_patch_2016_2240 has 4 labels
# 1987 Sichuan pre-earthquake_patch_4928_9184 has 2 labels
# 1987 Sichuan pre-earthquake_patch_3808_8736 has 3 labels
# 2015 gorkha earthquake_patch_5600_5152 has 5 labels
# 2004 Cheutsu Earthquake 2004_patch_3808_3808 has 2 labels
# 2017 Milin_patch_19040_5152 has 3 labels
# 2016 Arun rainstorm_patch_5152_2912 has 5 labels
# 2016 Arun rainstorm_patch_5152_2912 has 5 labels
# 2015 gorkha earthquake_patch_5600_5152 has 5 labels
# 2004 Cheutsu Earthquake 2004_patch_3808_3808 has 2 labels
# 2017 Milin_patch_19040_5152 has 3 labels
# 2015 gorkha earthquake_patch_7616_6496 has 1 labels
# 1999 chamoli earthquake_patch_6496_7616 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4256_10752 has 2 labels
# 2018 Lombok_patch_6272_2912 has 4 labels
# 1987 Sichuan pre-earthquake_patch_4256_10752 has 2 labels
# 2018 Lombok_patch_6272_2912 has 4 labels
# 1999 chamoli earthquake_patch_6496_7616 has 1 labels
# 2015 gorkha earthquake_patch_7616_6496 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6496_8288 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3360_12320 has 5 labels
# 2011 sikkim earthquake_patch_10304_3808 has 10 labels
# 2015 gorkha earthquake_patch_4928_4480 has 2 labels
# 1987 Sichuan pre-earthquake_patch_10528_5824 has 2 labels
# 1999 chamoli earthquake_patch_8512_7840 has 4 labels
# 2015 gorkha earthquake_patch_10752_7392 has 2 labels
# 1987 Sichuan pre-earthquake_patch_5600_10304 has 17 labels
# 2015 gorkha earthquake_patch_10752_7392 has 2 labels
# 1987 Sichuan pre-earthquake_patch_5600_10304 has 17 labels
# 2011 sikkim earthquake_patch_10304_3808 has 10 labels
# 1987 Sichuan pre-earthquake_patch_3360_12320 has 5 labels
# 1987 Sichuan pre-earthquake_patch_6496_8288 has 1 labels
# 2015 gorkha earthquake_patch_4928_4480 has 2 labels
# 1987 Sichuan pre-earthquake_patch_10528_5824 has 2 labels
# 1999 chamoli earthquake_patch_8512_7840 has 4 labels
# 1987 Sichuan pre-earthquake_patch_4032_8736 has 1 labels
# 2015 gorkha earthquake_patch_6496_6496 has 6 labels
# 1987 Sichuan pre-earthquake_patch_3136_10528 has 9 labels
# 1987 Sichuan pre-earthquake_patch_8064_6944 has 3 labels
# 2015 gorkha earthquake_patch_8064_8960 has 3 labels
# 2015 gorkha earthquake_patch_4704_4480 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7392_7392 has 11 labels
# 2015 gorkha earthquake_patch_7392_6720 has 53 labels
# 1987 Sichuan pre-earthquake_patch_7392_7392 has 11 labels
# 2015 gorkha earthquake_patch_8064_8960 has 3 labels
# 2015 gorkha earthquake_patch_4704_4480 has 1 labels
# 2015 gorkha earthquake_patch_7392_6720 has 53 labels
# 2015 gorkha earthquake_patch_6496_6496 has 6 labels
# 1987 Sichuan pre-earthquake_patch_4032_8736 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3136_10528 has 9 labels
# 1987 Sichuan pre-earthquake_patch_8064_6944 has 3 labels
# 2015 gorkha earthquake_patch_11200_7616 has 1 labels
# 2015 gorkha earthquake_patch_9184_6944 has 41 labels
# 2015 gorkha earthquake_patch_6496_5376 has 3 labels
# 2004 Cheutsu Earthquake 2004_patch_4032_3808 has 6 labels
# 1987 Sichuan pre-earthquake_patch_7616_8288 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7392_8512 has 6 labels
# 1991 Limon Earthquake_patch_896_4256 has 28 labels
# 1987 Sichuan pre-earthquake_patch_7616_6272 has 25 labels
# 1987 Sichuan pre-earthquake_patch_7616_6272 has 25 labels
# 1991 Limon Earthquake_patch_896_4256 has 28 labels
# 2015 gorkha earthquake_patch_9184_6944 has 41 labels
# 2015 gorkha earthquake_patch_11200_7616 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7616_8288 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7392_8512 has 6 labels
# 2015 gorkha earthquake_patch_6496_5376 has 3 labels
# 2004 Cheutsu Earthquake 2004_patch_4032_3808 has 6 labels
# 1987 Sichuan pre-earthquake_patch_6048_7168 has 1 labels
# 2010 Haiti_patch_4256_4928 has 5 labels
# 2015 gorkha earthquake_patch_8288_6272 has 15 labels
# 1987 Sichuan pre-earthquake_patch_4032_9856 has 13 labels
# 1987 Sichuan pre-earthquake_patch_8064_9184 has 4 labels
# 1987 Sichuan pre-earthquake_patch_7840_6272 has 5 labels
# 1987 Sichuan pre-earthquake_patch_7840_6272 has 5 labels
# 2010 Haiti_patch_4256_4928 has 5 labels
# 1987 Sichuan pre-earthquake_patch_6048_7168 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4032_9856 has 13 labels
# 1987 Sichuan pre-earthquake_patch_8064_9184 has 4 labels
# 2015 gorkha earthquake_patch_8288_6272 has 15 labels
# 1987 Sichuan pre-earthquake_patch_3584_12768 has 1 labels
# 1987 Sichuan pre-earthquake_patch_2464_12320 has 3 labels
# 1999 chamoli earthquake_patch_6720_8288 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5600_8960 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5376_10528 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4256_9408 has 10 labels
# 1987 Sichuan pre-earthquake_patch_4032_12992 has 3 labels
# 1987 Sichuan pre-earthquake_patch_4256_8064 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6272_7840 has 11 labels
# 1987 Sichuan pre-earthquake_patch_4256_9408 has 10 labels
# 1987 Sichuan pre-earthquake_patch_5600_8960 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5376_10528 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4032_12992 has 3 labels
# 1987 Sichuan pre-earthquake_patch_4256_8064 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6272_7840 has 11 labels
# 1987 Sichuan pre-earthquake_patch_2464_12320 has 3 labels
# 1987 Sichuan pre-earthquake_patch_3584_12768 has 1 labels
# 1999 chamoli earthquake_patch_6720_8288 has 1 labels
# 2016 Arun rainstorm_patch_4256_3584 has 3 labels
# 2015 gorkha earthquake_patch_8736_7616 has 4 labels
# 1987 Sichuan pre-earthquake_patch_4256_12320 has 12 labels
# 1987 Sichuan pre-earthquake_patch_9184_5600 has 3 labels
# 1987 Sichuan pre-earthquake_patch_3584_10976 has 19 labels
# 2011 sikkim earthquake_patch_9856_2464 has 5 labels
# 1987 Sichuan pre-earthquake_patch_8288_5376 has 6 labels
# 2014 Arun rainstorm_patch_5376_2464 has 1 labels
# 2011 sikkim earthquake_patch_9856_2464 has 5 labels
# 1987 Sichuan pre-earthquake_patch_3584_10976 has 19 labels
# 2014 Arun rainstorm_patch_5376_2464 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8288_5376 has 6 labels
# 2016 Arun rainstorm_patch_4256_3584 has 3 labels
# 1987 Sichuan pre-earthquake_patch_9184_5600 has 3 labels
# 2015 gorkha earthquake_patch_8736_7616 has 4 labels
# 1987 Sichuan pre-earthquake_patch_4256_12320 has 12 labels
# 2011 sikkim earthquake_patch_9632_2464 has 5 labels
# 1987 Sichuan pre-earthquake_patch_7168_7840 has 2 labels
# 2015 gorkha earthquake_patch_7840_6496 has 29 labels
# 1987 Sichuan pre-earthquake_patch_2688_10976 has 5 labels
# Sulawesi 2018_patch_24416_7168 does not have a label file
# 2015 gorkha earthquake_patch_10976_7616 has 4 labels
# 2016 Arun rainstorm_patch_4480_4480 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8288_6496 has 1 labels
# 2015 gorkha earthquake_patch_9632_8288 has 2 labels
# 1987 Sichuan pre-earthquake_patch_3136_8288 has 6 labels
# 1987 Sichuan pre-earthquake_patch_4480_8960 has 3 labels
# 1987 Sichuan pre-earthquake_patch_3360_10752 has 23 labels
# 2016 Arun rainstorm_patch_4480_4480 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8288_6496 has 1 labels
# 1987 Sichuan pre-earthquake_patch_2688_10976 has 5 labels
# Sulawesi 2018_patch_24416_7168 does not have a label file
# 2015 gorkha earthquake_patch_10976_7616 has 4 labels
# 1987 Sichuan pre-earthquake_patch_3136_8288 has 6 labels
# 1987 Sichuan pre-earthquake_patch_4480_8960 has 3 labels
# 1987 Sichuan pre-earthquake_patch_3360_10752 has 23 labels
# 2015 gorkha earthquake_patch_9632_8288 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7168_7840 has 2 labels
# 2015 gorkha earthquake_patch_7840_6496 has 29 labels
# 2011 sikkim earthquake_patch_9632_2464 has 5 labels
# 1991 Limon Earthquake_patch_1792_4704 has 8 labels
# 1987 Sichuan pre-earthquake_patch_3136_9632 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5376_7840 has 1 labels
# 1987 Sichuan pre-earthquake_patch_9408_6944 has 3 labels
# 1987 Sichuan pre-earthquake_patch_3808_9856 has 4 labels
# Sulawesi 2018_patch_24640_8736 does not have a label file
# Sulawesi 2018_patch_24864_6944 does not have a label file
# 1987 Sichuan pre-earthquake_patch_9632_7616 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8512_8512 has 1 labels
# Sulawesi 2018_patch_24864_6944 does not have a label file
# 1987 Sichuan pre-earthquake_patch_9632_7616 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8512_8512 has 1 labels
# 1987 Sichuan pre-earthquake_patch_9408_6944 has 3 labels
# 1987 Sichuan pre-earthquake_patch_3808_9856 has 4 labels
# 1991 Limon Earthquake_patch_1792_4704 has 8 labels
# 1987 Sichuan pre-earthquake_patch_3136_9632 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5376_7840 has 1 labels
# Sulawesi 2018_patch_24640_8736 does not have a label file
# Sulawesi 2018_patch_24416_8064 does not have a label file
# 2015 gorkha earthquake_patch_8512_6720 has 27 labels
# 1987 Sichuan pre-earthquake_patch_8736_6272 has 5 labels
# 1987 Sichuan pre-earthquake_patch_8736_6272 has 5 labels
# 2015 gorkha earthquake_patch_8512_6720 has 27 labels
# Sulawesi 2018_patch_24416_8064 does not have a label file
# 1987 Sichuan pre-earthquake_patch_4928_10752 has 2 labels
# 1991 Limon Earthquake_patch_896_4032 has 8 labels
# 1987 Sichuan pre-earthquake_patch_2688_9408 has 1 labels
# 2015 gorkha earthquake_patch_6944_6272 has 48 labels
# 2008 Iwate_patch_7840_2912 has 5 labels
# 2015 gorkha earthquake_patch_8736_6496 has 10 labels
# 2015 gorkha earthquake_patch_11424_7168 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5824_8064 has 2 labels
# 2011 sikkim earthquake_patch_8736_3808 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6048_8064 has 2 labels
# 1987 Sichuan pre-earthquake_patch_5824_9408 has 8 labels
# 1999 chamoli earthquake_patch_8288_8288 has 1 labels
# 2011 sikkim earthquake_patch_8512_3360 has 10 labels
# 1987 Sichuan pre-earthquake_patch_2912_10304 has 1 labels
# 2011 sikkim earthquake_patch_8736_3808 has 1 labels
# 2015 gorkha earthquake_patch_11424_7168 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5824_8064 has 2 labels
# 1999 chamoli earthquake_patch_8288_8288 has 1 labels
# 2011 sikkim earthquake_patch_8512_3360 has 10 labels
# 1987 Sichuan pre-earthquake_patch_2912_10304 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6048_8064 has 2 labels
# 1987 Sichuan pre-earthquake_patch_5824_9408 has 8 labels
# 1991 Limon Earthquake_patch_896_4032 has 8 labels
# 1987 Sichuan pre-earthquake_patch_2688_9408 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4928_10752 has 2 labels
# 2008 Iwate_patch_7840_2912 has 5 labels
# 2015 gorkha earthquake_patch_8736_6496 has 10 labels
# 2015 gorkha earthquake_patch_6944_6272 has 48 labels
# 2018 Lombok_patch_6048_2464 has 4 labels
# 1987 Sichuan pre-earthquake_patch_8288_7616 has 6 labels
# 2011 sikkim earthquake_patch_8960_4480 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4480_10752 has 15 labels
# 1987 Sichuan pre-earthquake_patch_7840_9632 has 2 labels
# 2015 gorkha earthquake_patch_6720_6272 has 15 labels
# 2011 sikkim earthquake_patch_8960_4480 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4480_10752 has 15 labels
# 1987 Sichuan pre-earthquake_patch_8288_7616 has 6 labels
# 1987 Sichuan pre-earthquake_patch_7840_9632 has 2 labels
# 2015 gorkha earthquake_patch_6720_6272 has 15 labels
# 2018 Lombok_patch_6048_2464 has 4 labels
# 1991 Limon Earthquake_patch_1568_4928 has 2 labels
# 2015 gorkha earthquake_patch_9184_8064 has 1 labels
# 1991 Limon Earthquake_patch_1344_4480 has 11 labels
# 2015 gorkha earthquake_patch_12992_8512 has 1 labels
# 2017 Arun rainstorm_patch_5824_2016 has 2 labels
# 1999 chamoli earthquake_patch_8064_8736 has 11 labels
# 1987 Sichuan pre-earthquake_patch_7840_8512 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4256_9184 has 16 labels
# 2011 sikkim earthquake_patch_9184_2688 has 15 labels
# 1999 chamoli earthquake_patch_6944_8512 has 4 labels
# 1987 Sichuan pre-earthquake_patch_4256_12096 has 14 labels
# 1987 Sichuan pre-earthquake_patch_4704_11872 has 14 labels
# 1999 chamoli earthquake_patch_6720_7392 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4256_12096 has 14 labels
# 1987 Sichuan pre-earthquake_patch_4256_9184 has 16 labels
# 2011 sikkim earthquake_patch_9184_2688 has 15 labels
# 1999 chamoli earthquake_patch_6944_8512 has 4 labels
# 1999 chamoli earthquake_patch_6720_7392 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4704_11872 has 14 labels
# 1987 Sichuan pre-earthquake_patch_7840_8512 has 1 labels
# 1991 Limon Earthquake_patch_1568_4928 has 2 labels
# 1991 Limon Earthquake_patch_1344_4480 has 11 labels
# 2015 gorkha earthquake_patch_9184_8064 has 1 labels
# 2015 gorkha earthquake_patch_12992_8512 has 1 labels
# 2017 Arun rainstorm_patch_5824_2016 has 2 labels
# 1999 chamoli earthquake_patch_8064_8736 has 11 labels
# 1987 Sichuan pre-earthquake_patch_8064_8064 has 1 labels
# 2011 sikkim earthquake_patch_8288_3584 has 3 labels
# 2014 Arun rainstorm_patch_4928_2912 has 1 labels
# 2015 gorkha earthquake_patch_8288_7392 has 3 labels
# 1987 Sichuan pre-earthquake_patch_3584_9632 has 2 labels
# 1987 Sichuan pre-earthquake_patch_8288_6720 has 2 labels
# 1987 Sichuan pre-earthquake_patch_5152_11424 has 12 labels
# 1987 Sichuan pre-earthquake_patch_7840_7392 has 1 labels
# 2015 gorkha earthquake_patch_7840_6720 has 6 labels
# 1987 Sichuan pre-earthquake_patch_5152_11424 has 12 labels
# 1987 Sichuan pre-earthquake_patch_7840_7392 has 1 labels
# 2015 gorkha earthquake_patch_7840_6720 has 6 labels
# 2011 sikkim earthquake_patch_8288_3584 has 3 labels
# 2015 gorkha earthquake_patch_8288_7392 has 3 labels
# 2014 Arun rainstorm_patch_4928_2912 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8064_8064 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3584_9632 has 2 labels
# 1987 Sichuan pre-earthquake_patch_8288_6720 has 2 labels
# 1987 Sichuan pre-earthquake_patch_9632_6720 has 1 labels
# 2015 gorkha earthquake_patch_9632_7392 has 56 labels
# 2011 sikkim earthquake_patch_9632_3584 has 7 labels
# 2017 Arun rainstorm_patch_5376_2240 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3584_10752 has 24 labels
# 1987 Sichuan pre-earthquake_patch_3808_8960 has 5 labels
# 1987 Sichuan pre-earthquake_patch_3808_8960 has 5 labels
# 2017 Arun rainstorm_patch_5376_2240 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3584_10752 has 24 labels
# 1987 Sichuan pre-earthquake_patch_9632_6720 has 1 labels
# 2015 gorkha earthquake_patch_9632_7392 has 56 labels
# 2011 sikkim earthquake_patch_9632_3584 has 7 labels
# 2015 gorkha earthquake_patch_8064_5824 has 2 labels
# 2014 Arun rainstorm_patch_5376_3584 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3136_8512 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3360_10976 has 7 labels
# 2011 sikkim earthquake_patch_9856_3584 has 6 labels
# 2015 gorkha earthquake_patch_9856_7392 has 20 labels
# 1987 Sichuan pre-earthquake_patch_2464_12096 has 13 labels
# 1999 chamoli earthquake_patch_8960_7840 has 5 labels
# 1987 Sichuan pre-earthquake_patch_3360_10976 has 7 labels
# 2014 Arun rainstorm_patch_5376_3584 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3136_8512 has 1 labels
# 1999 chamoli earthquake_patch_8960_7840 has 5 labels
# 2011 sikkim earthquake_patch_9856_3584 has 6 labels
# 1987 Sichuan pre-earthquake_patch_2464_12096 has 13 labels
# 2015 gorkha earthquake_patch_9856_7392 has 20 labels
# 2015 gorkha earthquake_patch_8064_5824 has 2 labels
# 2016 Arun rainstorm_patch_5824_2464 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8512_6272 has 4 labels
# 1987 Sichuan pre-earthquake_patch_4480_12768 has 26 labels
# 2015 gorkha earthquake_patch_8736_6720 has 5 labels
# 1987 Sichuan pre-earthquake_patch_4256_13216 has 2 labels
# 1987 Sichuan pre-earthquake_patch_8736_7392 has 2 labels
# 2015 gorkha earthquake_patch_6048_5600 has 1 labels
# 2015 gorkha earthquake_patch_8736_6720 has 5 labels
# 1987 Sichuan pre-earthquake_patch_4256_13216 has 2 labels
# 1987 Sichuan pre-earthquake_patch_8736_7392 has 2 labels
# 2015 gorkha earthquake_patch_6048_5600 has 1 labels
# 2016 Arun rainstorm_patch_5824_2464 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8512_6272 has 4 labels
# 1987 Sichuan pre-earthquake_patch_4480_12768 has 26 labels
# 1991 Limon Earthquake_patch_448_5376 has 1 labels
# 2017 Milin_patch_18368_6048 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5376_10304 has 5 labels
# 1987 Sichuan pre-earthquake_patch_4480_9856 has 4 labels
# Sulawesi 2018_patch_24192_8064 does not have a label file
# 2015 gorkha earthquake_patch_8960_7840 has 1 labels
# 2015 gorkha earthquake_patch_10080_7840 has 6 labels
# 1987 Sichuan pre-earthquake_patch_4928_12768 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5152_7840 has 2 labels
# 2008 Iwate_patch_8288_2688 has 12 labels
# 2015 gorkha earthquake_patch_8960_7840 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5152_7840 has 2 labels
# 2008 Iwate_patch_8288_2688 has 12 labels
# 2015 gorkha earthquake_patch_10080_7840 has 6 labels
# 1987 Sichuan pre-earthquake_patch_4928_12768 has 1 labels
# 1991 Limon Earthquake_patch_448_5376 has 1 labels
# 2017 Milin_patch_18368_6048 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5376_10304 has 5 labels
# 1987 Sichuan pre-earthquake_patch_4480_9856 has 4 labels
# Sulawesi 2018_patch_24192_8064 does not have a label file
# 1999 chamoli earthquake_patch_9184_8064 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4928_10976 has 4 labels
# 1999 chamoli earthquake_patch_9184_9408 has 4 labels
# 1987 Sichuan pre-earthquake_patch_8064_6048 has 10 labels
# 1999 chamoli earthquake_patch_8288_8512 has 4 labels
# 2015 gorkha earthquake_patch_9184_7168 has 14 labels
# 1987 Sichuan pre-earthquake_patch_3584_8288 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4032_8960 has 7 labels
# 2008 Iwate_patch_8064_3360 has 18 labels
# 1987 Sichuan pre-earthquake_patch_3584_8288 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4032_8960 has 7 labels
# 1999 chamoli earthquake_patch_8288_8512 has 4 labels
# 2015 gorkha earthquake_patch_9184_7168 has 14 labels
# 2008 Iwate_patch_8064_3360 has 18 labels
# 1999 chamoli earthquake_patch_9184_8064 has 1 labels
# 1999 chamoli earthquake_patch_9184_9408 has 4 labels
# 1987 Sichuan pre-earthquake_patch_8064_6048 has 10 labels
# 1987 Sichuan pre-earthquake_patch_4928_10976 has 4 labels
# 2011 sikkim earthquake_patch_8736_3360 has 16 labels
# 1987 Sichuan pre-earthquake_patch_2688_9184 has 10 labels
# 2015 gorkha earthquake_patch_9184_6048 has 1 labels
# 2017 Arun rainstorm_patch_5600_2912 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5600_9856 has 12 labels
# 1999 chamoli earthquake_patch_8288_7392 has 3 labels
# 2015 gorkha earthquake_patch_8512_6496 has 4 labels
# 2015 gorkha earthquake_patch_11200_7840 has 2 labels
# 1987 Sichuan pre-earthquake_patch_6048_9184 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8064_7168 has 5 labels
# 1987 Sichuan pre-earthquake_patch_3808_11872 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4480_10976 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5824_9184 has 1 labels
# 2015 gorkha earthquake_patch_11200_7840 has 2 labels
# 1987 Sichuan pre-earthquake_patch_6048_9184 has 1 labels
# 2015 gorkha earthquake_patch_8512_6496 has 4 labels
# 1987 Sichuan pre-earthquake_patch_3808_11872 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5824_9184 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4480_10976 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8064_7168 has 5 labels
# 2015 gorkha earthquake_patch_9184_6048 has 1 labels
# 2011 sikkim earthquake_patch_8736_3360 has 16 labels
# 1987 Sichuan pre-earthquake_patch_2688_9184 has 10 labels
# 2017 Arun rainstorm_patch_5600_2912 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5600_9856 has 12 labels
# 1999 chamoli earthquake_patch_8288_7392 has 3 labels
# 1987 Sichuan pre-earthquake_patch_8064_6272 has 2 labels
# 1987 Sichuan pre-earthquake_patch_3584_12544 has 3 labels
# 1999 chamoli earthquake_patch_9184_9632 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4256_8512 has 4 labels
# 1987 Sichuan pre-earthquake_patch_6048_10752 has 8 labels
# 1987 Sichuan pre-earthquake_patch_7840_9184 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7840_9184 has 2 labels
# 1987 Sichuan pre-earthquake_patch_3584_12544 has 3 labels
# 1987 Sichuan pre-earthquake_patch_8064_6272 has 2 labels
# 1999 chamoli earthquake_patch_9184_9632 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4256_8512 has 4 labels
# 1987 Sichuan pre-earthquake_patch_6048_10752 has 8 labels
# 1987 Sichuan pre-earthquake_patch_2688_12544 has 5 labels
# 1987 Sichuan pre-earthquake_patch_2464_8736 has 1 labels
# 2015 gorkha earthquake_patch_7616_8960 has 2 labels
# 2004 Cheutsu Earthquake 2004_patch_3808_4256 has 31 labels
# 2014 Arun rainstorm_patch_4928_3360 has 1 labels
# 1999 chamoli earthquake_patch_8064_7616 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7616_6944 has 11 labels
# 1999 chamoli earthquake_patch_8064_7616 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7616_6944 has 11 labels
# 2015 gorkha earthquake_patch_7616_8960 has 2 labels
# 1987 Sichuan pre-earthquake_patch_2464_8736 has 1 labels
# 1987 Sichuan pre-earthquake_patch_2688_12544 has 5 labels
# 2014 Arun rainstorm_patch_4928_3360 has 1 labels
# 2004 Cheutsu Earthquake 2004_patch_3808_4256 has 31 labels
# 1999 chamoli earthquake_patch_8960_8960 has 2 labels
# 1987 Sichuan pre-earthquake_patch_8512_6048 has 9 labels
# 1987 Sichuan pre-earthquake_patch_3360_11648 has 4 labels
# 2015 gorkha earthquake_patch_11648_8288 has 1 labels
# 2015 gorkha earthquake_patch_6944_5152 has 1 labels
# 2015 gorkha earthquake_patch_8512_8736 has 1 labels
# 1998 Jueili_patch_2240_2016 has 5 labels
# 1998 Jueili_patch_2240_2016 has 5 labels
# 2015 gorkha earthquake_patch_11648_8288 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8512_6048 has 9 labels
# 1999 chamoli earthquake_patch_8960_8960 has 2 labels
# 1987 Sichuan pre-earthquake_patch_3360_11648 has 4 labels
# 2015 gorkha earthquake_patch_6944_5152 has 1 labels
# 2015 gorkha earthquake_patch_8512_8736 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4032_11872 has 7 labels
# 1987 Sichuan pre-earthquake_patch_3808_7840 has 2 labels
# 1987 Sichuan pre-earthquake_patch_6944_10080 has 2 labels
# 1987 Sichuan pre-earthquake_patch_6496_10080 has 31 labels
# 2011 sikkim earthquake_patch_8064_3808 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3136_9184 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8288_5600 has 36 labels
# 2011 sikkim earthquake_patch_8960_4256 has 6 labels
# 2015 gorkha earthquake_patch_6720_5152 has 3 labels
# 2015 gorkha earthquake_patch_7840_5600 has 4 labels
# 2015 gorkha earthquake_patch_8064_6496 has 62 labels
# 2011 sikkim earthquake_patch_8960_4256 has 6 labels
# 2015 gorkha earthquake_patch_6720_5152 has 3 labels
# 2015 gorkha earthquake_patch_8064_6496 has 62 labels
# 2015 gorkha earthquake_patch_7840_5600 has 4 labels
# 1987 Sichuan pre-earthquake_patch_6496_10080 has 31 labels
# 2011 sikkim earthquake_patch_8064_3808 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3808_7840 has 2 labels
# 1987 Sichuan pre-earthquake_patch_6944_10080 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4032_11872 has 7 labels
# 1987 Sichuan pre-earthquake_patch_8288_5600 has 36 labels
# 1987 Sichuan pre-earthquake_patch_3136_9184 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5152_8960 has 3 labels
# 1987 Sichuan pre-earthquake_patch_7168_9856 has 4 labels
# 2008 Iwate_patch_8288_2464 has 3 labels
# 1999 chamoli earthquake_patch_8512_8736 has 10 labels
# 1987 Sichuan pre-earthquake_patch_8960_6944 has 1 labels
# 1987 Sichuan pre-earthquake_patch_2912_11424 has 7 labels
# Sulawesi 2018_patch_24416_8512 does not have a label file
# 1987 Sichuan pre-earthquake_patch_8960_6944 has 1 labels
# Sulawesi 2018_patch_24416_8512 does not have a label file
# 1987 Sichuan pre-earthquake_patch_2912_11424 has 7 labels
# 2008 Iwate_patch_8288_2464 has 3 labels
# 1999 chamoli earthquake_patch_8512_8736 has 10 labels
# 1987 Sichuan pre-earthquake_patch_5152_8960 has 3 labels
# 1987 Sichuan pre-earthquake_patch_7168_9856 has 4 labels
# Sulawesi 2018_patch_24416_7392 does not have a label file
# 1999 chamoli earthquake_patch_6496_8960 has 2 labels
# 2011 sikkim earthquake_patch_8736_4032 has 3 labels
# 2010 Haiti_patch_5824_4480 has 3 labels
# 2010 Haiti_patch_5824_4480 has 3 labels
# Sulawesi 2018_patch_24416_7392 does not have a label file
# 1999 chamoli earthquake_patch_6496_8960 has 2 labels
# 2011 sikkim earthquake_patch_8736_4032 has 3 labels
# 1987 Sichuan pre-earthquake_patch_4480_11648 has 6 labels
# 1999 chamoli earthquake_patch_8288_9184 has 5 labels
# 2015 gorkha earthquake_patch_5824_6720 has 3 labels
# 1987 Sichuan pre-earthquake_patch_9184_7616 has 3 labels
# 2015 gorkha earthquake_patch_8736_5600 has 1 labels
# 2008 Iwate_patch_8064_2912 has 14 labels
# 1987 Sichuan pre-earthquake_patch_6048_7392 has 12 labels
# 2015 gorkha earthquake_patch_6048_6720 has 8 labels
# 1987 Sichuan pre-earthquake_patch_6272_9856 has 9 labels
# 2015 gorkha earthquake_patch_8736_5600 has 1 labels
# 2008 Iwate_patch_8064_2912 has 14 labels
# 1987 Sichuan pre-earthquake_patch_6048_7392 has 12 labels
# 2015 gorkha earthquake_patch_5824_6720 has 3 labels
# 1987 Sichuan pre-earthquake_patch_9184_7616 has 3 labels
# 2015 gorkha earthquake_patch_6048_6720 has 8 labels
# 1987 Sichuan pre-earthquake_patch_6272_9856 has 9 labels
# 1987 Sichuan pre-earthquake_patch_4480_11648 has 6 labels
# 1999 chamoli earthquake_patch_8288_9184 has 5 labels
# 1987 Sichuan pre-earthquake_patch_5824_8512 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8064_9632 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3584_9408 has 8 labels
# 1999 chamoli earthquake_patch_7616_8960 has 3 labels
# 1987 Sichuan pre-earthquake_patch_4032_7840 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6048_8512 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3584_8064 has 3 labels
# 2008 Iwate_patch_7840_3808 has 12 labels
# 1987 Sichuan pre-earthquake_patch_4928_11648 has 3 labels
# 2008 Iwate_patch_7840_3808 has 12 labels
# 1987 Sichuan pre-earthquake_patch_4928_11648 has 3 labels
# 1987 Sichuan pre-earthquake_patch_5824_8512 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8064_9632 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3584_9408 has 8 labels
# 1987 Sichuan pre-earthquake_patch_6048_8512 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3584_8064 has 3 labels
# 1999 chamoli earthquake_patch_7616_8960 has 3 labels
# 1987 Sichuan pre-earthquake_patch_4032_7840 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6272_8960 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6048_10976 has 4 labels
# 1987 Sichuan pre-earthquake_patch_4256_8288 has 2 labels
# 2015 gorkha earthquake_patch_6944_6048 has 10 labels
# 2015 gorkha earthquake_patch_9184_7392 has 24 labels
# ...
# 1987 Sichuan pre-earthquake_patch_3584_9856 has 3 labels
# 2010 Haiti_patch_4032_5600 has 1 labels
# 2014 Arun rainstorm_patch_5824_2464 has 1 labels
# 2018 Lombok_patch_6272_2464 has 3 labels
# 2014 Arun rainstorm_patch_6048_2464 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7840_8960 has 3 labels
# 1987 Sichuan pre-earthquake_patch_6272_8064 has 7 labels
# 1987 Sichuan pre-earthquake_patch_6272_9408 has 11 labels
# 1987 Sichuan pre-earthquake_patch_3136_10080 has 10 labels
# 1987 Sichuan pre-earthquake_patch_6272_8064 has 7 labels
# 1987 Sichuan pre-earthquake_patch_3136_10080 has 10 labels
# 1987 Sichuan pre-earthquake_patch_6272_9408 has 11 labels
# 1987 Sichuan pre-earthquake_patch_7392_7616 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4032_9184 has 2 labels
# 2008 Iwate_patch_7840_3136 has 13 labels
# 1987 Sichuan pre-earthquake_patch_8064_9856 has 1 labels
# 2011 sikkim earthquake_patch_10080_3360 has 9 labels
# 2011 sikkim earthquake_patch_8064_4704 has 1 labels
# 1991 Limon Earthquake_patch_1120_4480 has 24 labels
# 2015 gorkha earthquake_patch_5376_6496 has 1 labels
# 2016 Arun rainstorm_patch_4704_3360 has 1 labels
# 2010 Haiti_patch_5152_4480 has 20 labels
# 1987 Sichuan pre-earthquake_patch_5376_10752 has 6 labels
# 2010 Haiti_patch_5152_4480 has 20 labels
# 1991 Limon Earthquake_patch_1120_4480 has 24 labels
# 2015 gorkha earthquake_patch_5376_6496 has 1 labels
# 2016 Arun rainstorm_patch_4704_3360 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5376_10752 has 6 labels
# 1987 Sichuan pre-earthquake_patch_7392_7616 has 2 labels
# 2011 sikkim earthquake_patch_10080_3360 has 9 labels
# 2011 sikkim earthquake_patch_8064_4704 has 1 labels
# 2008 Iwate_patch_7840_3136 has 13 labels
# 1987 Sichuan pre-earthquake_patch_4032_9184 has 2 labels
# 1987 Sichuan pre-earthquake_patch_8064_9856 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5824_8960 has 1 labels
# 2018 Arun rainstorm_patch_4480_4032 has 1 labels
# 1987 Sichuan pre-earthquake_patch_9408_5824 has 15 labels
# 1987 Sichuan pre-earthquake_patch_6048_8960 has 1 labels
# 1999 chamoli earthquake_patch_8288_7840 has 7 labels
# 1999 chamoli earthquake_patch_7616_8512 has 11 labels
# 1999 chamoli earthquake_patch_7392_8288 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6272_9632 has 19 labels
# 2015 gorkha earthquake_patch_11200_7392 has 3 labels
# 2015 gorkha earthquake_patch_6048_6944 has 2 labels
# 1991 Limon Earthquake_patch_672_4480 has 6 labels
# 1987 Sichuan pre-earthquake_patch_3136_12320 has 7 labels
# 1998 Jueili_patch_2016_2464 has 10 labels
# 1987 Sichuan pre-earthquake_patch_2688_8960 has 4 labels
# 2015 gorkha earthquake_patch_5376_5376 has 2 labels
# 2015 gorkha earthquake_patch_11200_7392 has 3 labels
# 1987 Sichuan pre-earthquake_patch_6272_9632 has 19 labels
# 2015 gorkha earthquake_patch_6048_6944 has 2 labels
# 1991 Limon Earthquake_patch_672_4480 has 6 labels
# 1998 Jueili_patch_2016_2464 has 10 labels
# 1987 Sichuan pre-earthquake_patch_3136_12320 has 7 labels
# 1987 Sichuan pre-earthquake_patch_2688_8960 has 4 labels
# 2015 gorkha earthquake_patch_5376_5376 has 2 labels
# 2018 Arun rainstorm_patch_4480_4032 has 1 labels
# 1987 Sichuan pre-earthquake_patch_9408_5824 has 15 labels
# 1987 Sichuan pre-earthquake_patch_5824_8960 has 1 labels
# 1999 chamoli earthquake_patch_7616_8512 has 11 labels
# 1999 chamoli earthquake_patch_7392_8288 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6048_8960 has 1 labels
# 1999 chamoli earthquake_patch_8288_7840 has 7 labels
# 1987 Sichuan pre-earthquake_patch_5152_8512 has 2 labels
# 1987 Sichuan pre-earthquake_patch_3360_10528 has 14 labels
# 2017 Milin_patch_18816_5600 has 35 labels
# 1987 Sichuan pre-earthquake_patch_3360_10528 has 14 labels
# 2017 Milin_patch_18816_5600 has 35 labels
# 1987 Sichuan pre-earthquake_patch_5152_8512 has 2 labels
# 2015 gorkha earthquake_patch_10752_7616 has 9 labels
# 1998 Jueili_patch_2464_2016 has 1 labels
# 1987 Sichuan pre-earthquake_patch_2912_10976 has 3 labels
# 2016 Arun rainstorm_patch_4928_3360 has 11 labels
# 1987 Sichuan pre-earthquake_patch_7168_9632 has 9 labels
# 2015 gorkha earthquake_patch_8960_7392 has 4 labels
# 2011 sikkim earthquake_patch_8960_3584 has 4 labels
# 2011 sikkim earthquake_patch_9408_2688 has 22 labels
# 1987 Sichuan pre-earthquake_patch_5376_8288 has 1 labels
# 1987 Sichuan pre-earthquake_patch_10080_6496 has 2 labels
# 1987 Sichuan pre-earthquake_patch_5376_8288 has 1 labels
# 2015 gorkha earthquake_patch_8960_7392 has 4 labels
# 2011 sikkim earthquake_patch_8960_3584 has 4 labels
# 2011 sikkim earthquake_patch_9408_2688 has 22 labels
# 1987 Sichuan pre-earthquake_patch_10080_6496 has 2 labels
# 1998 Jueili_patch_2464_2016 has 1 labels
# 2015 gorkha earthquake_patch_10752_7616 has 9 labels
# 2016 Arun rainstorm_patch_4928_3360 has 11 labels
# 1987 Sichuan pre-earthquake_patch_7168_9632 has 9 labels
# 1987 Sichuan pre-earthquake_patch_2912_10976 has 3 labels
# 1987 Sichuan pre-earthquake_patch_3808_9184 has 2 labels
# 2015 gorkha earthquake_patch_6272_5376 has 3 labels
# 1999 chamoli earthquake_patch_8960_8512 has 3 labels
# 1987 Sichuan pre-earthquake_patch_4480_9408 has 1 labels
# 2017 Milin_patch_19040_5824 has 31 labels
# 1987 Sichuan pre-earthquake_patch_5600_12096 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7392_6496 has 6 labels
# 1987 Sichuan pre-earthquake_patch_5376_9632 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4928_8736 has 8 labels
# 2015 gorkha earthquake_patch_5600_5824 has 1 labels
# 2015 gorkha earthquake_patch_9632_7840 has 18 labels
# 1987 Sichuan pre-earthquake_patch_7168_8288 has 15 labels
# 2020 Arun rainstorm_patch_4480_1568 has 1 labels
# 1991 Limon Earthquake_patch_1120_5600 has 1 labels
# 2020 Arun rainstorm_patch_4480_1568 has 1 labels
# 1991 Limon Earthquake_patch_1120_5600 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7168_8288 has 15 labels
# 1987 Sichuan pre-earthquake_patch_4480_9408 has 1 labels
# 1999 chamoli earthquake_patch_8960_8512 has 3 labels
# 2017 Milin_patch_19040_5824 has 31 labels
# 1987 Sichuan pre-earthquake_patch_5600_12096 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7392_6496 has 6 labels
# 1987 Sichuan pre-earthquake_patch_3808_9184 has 2 labels
# 2015 gorkha earthquake_patch_6272_5376 has 3 labels
# 2015 gorkha earthquake_patch_5600_5824 has 1 labels
# 2015 gorkha earthquake_patch_9632_7840 has 18 labels
# 1987 Sichuan pre-earthquake_patch_5376_9632 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4928_8736 has 8 labels
# 1987 Sichuan pre-earthquake_patch_7392_5376 has 2 labels
# 1999 chamoli earthquake_patch_9408_9408 has 1 labels
# 2015 gorkha earthquake_patch_6272_6496 has 12 labels
# 2015 gorkha earthquake_patch_9408_7168 has 13 labels
# 2010 Haiti_patch_4480_4928 has 7 labels
# 2015 gorkha earthquake_patch_9856_7840 has 26 labels
# 1999 chamoli earthquake_patch_7168_7616 has 2 labels
# 2010 Haiti_patch_4480_4928 has 7 labels
# 2015 gorkha earthquake_patch_9408_7168 has 13 labels
# 1999 chamoli earthquake_patch_7168_7616 has 2 labels
# 2015 gorkha earthquake_patch_9856_7840 has 26 labels
# 1999 chamoli earthquake_patch_9408_9408 has 1 labels
# 2015 gorkha earthquake_patch_6272_6496 has 12 labels
# 1987 Sichuan pre-earthquake_patch_7392_5376 has 2 labels
# 1987 Sichuan pre-earthquake_patch_5600_8064 has 4 labels
# 1987 Sichuan pre-earthquake_patch_2688_10304 has 4 labels
# 2018 Arun rainstorm_patch_5824_2016 has 2 labels
# 1987 Sichuan pre-earthquake_patch_5600_9408 has 10 labels
# 1987 Sichuan pre-earthquake_patch_6272_8288 has 3 labels
# 1987 Sichuan pre-earthquake_patch_4032_12096 has 6 labels
# 1987 Sichuan pre-earthquake_patch_4256_8960 has 8 labels
# 1991 Limon Earthquake_patch_896_4704 has 3 labels
# 1987 Sichuan pre-earthquake_patch_7616_6720 has 7 labels
# 1987 Sichuan pre-earthquake_patch_7616_6720 has 7 labels
# 1991 Limon Earthquake_patch_896_4704 has 3 labels
# 1987 Sichuan pre-earthquake_patch_2688_10304 has 4 labels
# 1987 Sichuan pre-earthquake_patch_5600_8064 has 4 labels
# 1987 Sichuan pre-earthquake_patch_4032_12096 has 6 labels
# 1987 Sichuan pre-earthquake_patch_4256_8960 has 8 labels
# 2018 Arun rainstorm_patch_5824_2016 has 2 labels
# 1987 Sichuan pre-earthquake_patch_5600_9408 has 10 labels
# 1987 Sichuan pre-earthquake_patch_6272_8288 has 3 labels
# 1987 Sichuan pre-earthquake_patch_3584_10304 has 24 labels
# 1999 chamoli earthquake_patch_6944_7840 has 3 labels
# 1987 Sichuan pre-earthquake_patch_4928_10528 has 5 labels
# 1987 Sichuan pre-earthquake_patch_5152_11648 has 7 labels
# 2018 Lombok_patch_6496_2912 has 3 labels
# 2016 Arun rainstorm_patch_4480_3584 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7840_7840 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4704_8736 has 13 labels
# 2015 gorkha earthquake_patch_7168_6496 has 1 labels
# 2018 Arun rainstorm_patch_5824_3136 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7840_7840 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4704_8736 has 13 labels
# 2015 gorkha earthquake_patch_7168_6496 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5152_11648 has 7 labels
# 2018 Lombok_patch_6496_2912 has 3 labels
# 2016 Arun rainstorm_patch_4480_3584 has 1 labels
# 2018 Arun rainstorm_patch_5824_3136 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3584_10304 has 24 labels
# 1999 chamoli earthquake_patch_6944_7840 has 3 labels
# 1987 Sichuan pre-earthquake_patch_4928_10528 has 5 labels
# 2015 gorkha earthquake_patch_5152_5376 has 10 labels
# 1987 Sichuan pre-earthquake_patch_7616_7616 has 2 labels
# 1987 Sichuan pre-earthquake_patch_5376_10976 has 8 labels
# 1987 Sichuan pre-earthquake_patch_4256_9856 has 6 labels
# 2020 Arun rainstorm_patch_4480_3584 has 2 labels
# 2010 Haiti_patch_4032_4928 has 6 labels
# 1987 Sichuan pre-earthquake_patch_4256_9856 has 6 labels
# 1987 Sichuan pre-earthquake_patch_5376_10976 has 8 labels
# 2010 Haiti_patch_4032_4928 has 6 labels
# 2020 Arun rainstorm_patch_4480_3584 has 2 labels
# 2015 gorkha earthquake_patch_5152_5376 has 10 labels
# 1987 Sichuan pre-earthquake_patch_7616_7616 has 2 labels
# 1987 Sichuan pre-earthquake_patch_8960_6496 has 2 labels
# 1999 chamoli earthquake_patch_7392_8512 has 3 labels
# 1999 chamoli earthquake_patch_7616_8288 has 12 labels
# 1987 Sichuan pre-earthquake_patch_3584_7840 has 1 labels
# 2016 Arun rainstorm_patch_4704_3808 has 1 labels
# 2010 Haiti_patch_5376_4480 has 29 labels
# 1987 Sichuan pre-earthquake_patch_4032_9408 has 7 labels
# 1987 Sichuan pre-earthquake_patch_9408_5600 has 1 labels
# 2015 gorkha earthquake_patch_10304_7616 has 3 labels
# 2011 sikkim earthquake_patch_10080_3808 has 5 labels
# 2015 gorkha earthquake_patch_10304_7616 has 3 labels
# 2011 sikkim earthquake_patch_10080_3808 has 5 labels
# 2016 Arun rainstorm_patch_4704_3808 has 1 labels
# 1987 Sichuan pre-earthquake_patch_8960_6496 has 2 labels
# 1999 chamoli earthquake_patch_7392_8512 has 3 labels
# 1999 chamoli earthquake_patch_7616_8288 has 12 labels
# 1987 Sichuan pre-earthquake_patch_3584_7840 has 1 labels
# 1987 Sichuan pre-earthquake_patch_9408_5600 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4032_9408 has 7 labels
# 2010 Haiti_patch_5376_4480 has 29 labels
# 1987 Sichuan pre-earthquake_patch_6496_7616 has 3 labels
# 1987 Sichuan pre-earthquake_patch_5152_8288 has 2 labels
# 1987 Sichuan pre-earthquake_patch_3808_11200 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4480_10304 has 9 labels
# 2017 Milin_patch_18816_5824 has 22 labels
# 2015 gorkha earthquake_patch_8960_6272 has 2 labels
# 2017 Milin_patch_18816_5824 has 22 labels
# 2015 gorkha earthquake_patch_8960_6272 has 2 labels
# 1987 Sichuan pre-earthquake_patch_6496_7616 has 3 labels
# 1987 Sichuan pre-earthquake_patch_5152_8288 has 2 labels
# 1987 Sichuan pre-earthquake_patch_3808_11200 has 1 labels
# 1987 Sichuan pre-earthquake_patch_4480_10304 has 9 labels
# 1987 Sichuan pre-earthquake_patch_3136_12096 has 7 labels
# 1987 Sichuan pre-earthquake_patch_2912_10752 has 2 labels
# 2004 Cheutsu Earthquake 2004_patch_3584_4256 has 8 labels
# 1999 chamoli earthquake_patch_6496_8288 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3584_10528 has 27 labels
# 1987 Sichuan pre-earthquake_patch_4928_10304 has 16 labels
# 1987 Sichuan pre-earthquake_patch_3584_10528 has 27 labels
# 1987 Sichuan pre-earthquake_patch_4928_10304 has 16 labels
# 1987 Sichuan pre-earthquake_patch_3136_12096 has 7 labels
# 1987 Sichuan pre-earthquake_patch_2912_10752 has 2 labels
# 1999 chamoli earthquake_patch_6496_8288 has 1 labels
# 2004 Cheutsu Earthquake 2004_patch_3584_4256 has 8 labels
# 2020 Arun rainstorm_patch_4928_3360 has 2 labels
# 1999 chamoli earthquake_patch_8960_8288 has 4 labels
# 1999 chamoli earthquake_patch_9408_9184 has 3 labels
# 1987 Sichuan pre-earthquake_patch_7616_6496 has 15 labels
# 2017 Milin_patch_19040_5600 has 51 labels
# 1987 Sichuan pre-earthquake_patch_4032_12320 has 12 labels
# 2016 Arun rainstorm_patch_5600_2464 has 1 labels
# 1987 Sichuan pre-earthquake_patch_5152_12544 has 6 labels
# 1998 Jueili_patch_2240_2240 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7168_8512 has 6 labels
# 1987 Sichuan pre-earthquake_patch_5152_12544 has 6 labels
# 1987 Sichuan pre-earthquake_patch_4032_12320 has 12 labels
# 2016 Arun rainstorm_patch_5600_2464 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7168_8512 has 6 labels
# 1998 Jueili_patch_2240_2240 has 2 labels
# 2020 Arun rainstorm_patch_4928_3360 has 2 labels
# 2017 Milin_patch_19040_5600 has 51 labels
# 1999 chamoli earthquake_patch_8960_8288 has 4 labels
# 1987 Sichuan pre-earthquake_patch_7616_6496 has 15 labels
# 1999 chamoli earthquake_patch_9408_9184 has 3 labels
# 1987 Sichuan pre-earthquake_patch_4480_9184 has 9 labels
# 1987 Sichuan pre-earthquake_patch_8960_7616 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7616_5376 has 29 labels
# 1987 Sichuan pre-earthquake_patch_3808_9408 has 3 labels
# 1987 Sichuan pre-earthquake_patch_7168_7392 has 5 labels
# 2015 gorkha earthquake_patch_7168_6720 has 8 labels
# 2010 Haiti_patch_4928_4704 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3808_8064 has 3 labels
# 1987 Sichuan pre-earthquake_patch_4704_11200 has 11 labels
# 2015 gorkha earthquake_patch_4704_5152 has 5 labels
# 2015 gorkha earthquake_patch_6496_6272 has 9 labels
# 2015 gorkha earthquake_patch_4704_5152 has 5 labels
# 2015 gorkha earthquake_patch_6496_6272 has 9 labels
# 1987 Sichuan pre-earthquake_patch_8960_7616 has 1 labels
# 1987 Sichuan pre-earthquake_patch_7616_5376 has 29 labels
# 1987 Sichuan pre-earthquake_patch_3808_9408 has 3 labels
# 1987 Sichuan pre-earthquake_patch_7168_7392 has 5 labels
# 1987 Sichuan pre-earthquake_patch_4480_9184 has 9 labels
# 2010 Haiti_patch_4928_4704 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3808_8064 has 3 labels
# 1987 Sichuan pre-earthquake_patch_4704_11200 has 11 labels
# 2015 gorkha earthquake_patch_7168_6720 has 8 labels
# 1987 Sichuan pre-earthquake_patch_3360_10304 has 47 labels
# 1987 Sichuan pre-earthquake_patch_6272_8512 has 1 labels
# 2015 gorkha earthquake_patch_8064_6944 has 2 labels
# 1987 Sichuan pre-earthquake_patch_3808_10080 has 6 labels
# 1987 Sichuan pre-earthquake_patch_7392_6720 has 2 labels
# 1987 Sichuan pre-earthquake_patch_7392_6720 has 2 labels
# 1987 Sichuan pre-earthquake_patch_6272_8512 has 1 labels
# 1987 Sichuan pre-earthquake_patch_3360_10304 has 47 labels
# 2015 gorkha earthquake_patch_8064_6944 has 2 labels
# 1987 Sichuan pre-earthquake_patch_3808_10080 has 6 labels
# 1987 Sichuan pre-earthquake_patch_6720_10080 has 5 labels
# 1987 Sichuan pre-earthquake_patch_9184_6944 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4256_12992 has 12 labels
# 1987 Sichuan pre-earthquake_patch_2688_9856 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6048_9856 has 7 labels
# 2010 Haiti_patch_4032_5376 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6048_11424 has 1 labels
# 2015 gorkha earthquake_patch_7616_6272 has 7 labels
# 1987 Sichuan pre-earthquake_patch_5824_9856 has 9 labels
# 1987 Sichuan pre-earthquake_patch_6272_7392 has 5 labels
# 2015 gorkha earthquake_patch_7616_6272 has 7 labels
# 1987 Sichuan pre-earthquake_patch_6048_9856 has 7 labels
# 2010 Haiti_patch_4032_5376 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6048_11424 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6272_7392 has 5 labels
# 1987 Sichuan pre-earthquake_patch_5824_9856 has 9 labels
# 1987 Sichuan pre-earthquake_patch_9184_6944 has 2 labels
# 1987 Sichuan pre-earthquake_patch_4256_12992 has 12 labels
# 1987 Sichuan pre-earthquake_patch_2688_9856 has 1 labels
# 1987 Sichuan pre-earthquake_patch_6720_10080 has 5 labels
# 0

# %%
# Splitting data in Pascal ucsb folder into train tesst and val:
path_ucsb_pascal = '/Users/vihaan/Workspace/!Datasets/Processed_Data_S24/data_images'
final_ucsb_pascal = '/Users/vihaan/Workspace/!Datasets/ucsb_pascal'


# Create the train, test, and val directories
train_dir = os.path.join(final_ucsb_pascal, 'train')
test_dir = os.path.join(final_ucsb_pascal, 'test')
val_dir = os.path.join(final_ucsb_pascal, 'val')

# Create the directories if they do not exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

if not os.path.exists(test_dir):
    os.makedirs(test_dir)

if not os.path.exists(val_dir):
    os.makedirs(val_dir)

# Get the list of image files
image_files = [file for file in os.listdir(path_ucsb_pascal) if file.endswith('.jpg')]
# Shuffle the list of image files
np.random.shuffle(image_files)

# Split the image files into train, test, and val sets
train_files = image_files[:int(0.8 * len(image_files))]
test_files = image_files[int(0.8 * len(image_files)):int(0.9 * len(image_files))]
val_files = image_files[int(0.9 * len(image_files)):]

# Move the image files to the corresponding directories
for file in train_files:
    # copy the image file to the corresponding directory
    os.rename(os.path.join(path_ucsb_pascal, file), os.path.join(train_dir, file))
    # Move the corresponding label file to the corresponding directory
    os.rename(os.path.join(path_ucsb_pascal, file.replace('.jpg', '.xml')), os.path.join(train_dir, file.replace('.jpg', '.xml')))
# Out:
# Number of images in train: 1674
# Number of images in test: 0
# Number of images in val: 0

# %%
for file in test_files:
    # copy the image file to the corresponding directory
    os.rename(os.path.join(path_ucsb_pascal, file), os.path.join(test_dir, file))
    # Move the corresponding label file to the corresponding directory
    os.rename(os.path.join(path_ucsb_pascal, file.replace('.jpg', '.xml')), os.path.join(test_dir, file.replace('.jpg', '.xml')))

for file in val_files:
    # copy the image file to the corresponding directory
    os.rename(os.path.join(path_ucsb_pascal, file), os.path.join(val_dir, file))
    # Move the corresponding label file to the corresponding directory
    os.rename(os.path.join(path_ucsb_pascal, file.replace('.jpg', '.xml')), os.path.join(val_dir, file.replace('.jpg', '.xml')))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
#       1 for file in test_files:
#       2     # copy the image file to the corresponding directory
# ----> 3     os.rename(os.path.join(path_ucsb_pascal, file), os.path.join(test_dir, file))
#       4     # Move the corresponding label file to the corresponding directory
#       5     os.rename(os.path.join(path_ucsb_pascal, file.replace('.jpg', '.xml')), os.path.join(test_dir, file.replace('.jpg', '.xml')))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/vihaan/Workspace/!Datasets/Processed_Data_S24/data_images/1987 Sichuan pre-earthquake_patch_3136_11648.jpg' -> '/Users/vihaan/Workspace/!Datasets/ucsb_pascal/test/1987 Sichuan pre-earthquake_patch_3136_11648.jpg'

# %%
# Print the number of images in each directory
print('Number of images in train:', len(os.listdir(train_dir)))
print('Number of images in test:', len(os.listdir(test_dir)))
print('Number of images in val:', len(os.listdir(val_dir)))
# Out:
# Number of images in train: 1674
# Number of images in test: 210
# Number of images in val: 210

# %% [markdown]
# # SAR Dataset to PASCAL format

# %%
path_sar_unprocessed = '/Users/vihaan/Workspace/!Datasets/SAR Dataset Unprocessed'
regions_in_sar = os.listdir(path_sar_unprocessed)

output_file_path = '/Users/vihaan/Workspace/!Datasets/SAR Dataset Processed 1'

# If the output directory does not exist, create it
if not os.path.exists(output_file_path):
    os.makedirs(output_file_path)

# Remove existing files in the output directory
files = [file for file in os.listdir(output_file_path) if os.path.isfile(os.path.join(output_file_path, file))]
for file in files:
    os.remove(os.path.join(output_file_path, file))

# Remove .DS_Store if it exists
if '.DS_Store' in regions_in_sar:
    regions_in_sar.remove('.DS_Store')

# Ignore the shapefiles folder as well
if 'study areas shp' in regions_in_sar:
    regions_in_sar.remove('study areas shp')

# Setting a threshold
threshold = 1  # Bounding box area should be at least 1 pixel

# Iterate through each region and read the images and labels
for region in regions_in_sar:
    region_path = os.path.join(path_sar_unprocessed, region)
    
    images_path = os.path.join(region_path, 'img')
    images_list = os.listdir(images_path)
    
    labels_path = os.path.join(region_path, 'label')

    for image_tif in images_list:
        # Get the image name without the extension
        image_name = image_tif.split('.')[0]
        
        # Read the image
        image = cv2.imread(os.path.join(images_path, image_tif), cv2.IMREAD_UNCHANGED)
        
        # Get the image height and width
        image_height = image.shape[0]
        image_width = image.shape[1]
        
        # Save the image as a .jpg file
        cv2.imwrite(os.path.join(output_file_path, f'{image_name}.jpg'), image)
        
        # Read the corresponding label file
        label_file_path = os.path.join(labels_path, f'{image_name}.tif')
        
        # If the label file does not exist, skip the image
        if not os.path.exists(label_file_path):
            continue
        
        # Read the label file
        label_image = cv2.imread(label_file_path, cv2.IMREAD_UNCHANGED)
        
        # Extract the 0th band since all bands hold the same value
        band0 = label_image[:, :, 0]
        
        # Threshold the image to create a binary mask
        _, binary_mask = cv2.threshold(band0, 127, 255, cv2.THRESH_BINARY_INV)
        
        # Find contours in the binary mask
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        
        # Prepare XML content
        label_base = '<annotation>\n<folder></folder>\n<filename>{}.jpg</filename>\n<path>{}.jpg</path>\n<source>\n<database></database>\n</source>\n<size>\n<width>{}</width>\n<height>{}</height>\n<depth>3</depth>\n</size>\n<segmented>0</segmented>\n'.format(image_name, image_name, image_width, image_height)
        label_base_end = '</annotation>'
        
        ct = 0
        for contour in contours:
            x, y, w, h = cv2.boundingRect(contour)
            xmin, ymin, xmax, ymax = x, y, x + w, y + h
            
            if xmin < 0 or ymin < 0 or xmax < 0 or ymax < 0:
                continue
            elif xmax - xmin < 1 or ymax - ymin < 1:
                continue
            elif (xmax - xmin) * (ymax - ymin) < threshold:
                continue
            else:
                if ymin < 0:
                    print(ymin)
                label_name = '<object>\n<name>landslides</name>\n<pose>Unspecified</pose>\n<truncated>0</truncated>\n<difficult>0</difficult>\n<occluded>0</occluded>\n<bndbox><xmin>{}</xmin><xmax>{}</xmax><ymin>{}</ymin><ymax>{}</ymax></bndbox>\n</object>\n'.format(xmin, xmax, ymin, ymax)
                label_base = label_base + label_name
                ct += 1
        
        if ct == 0:
            continue
        else:
            #print(image_name, 'has', ct, 'labels')
            label_base = label_base + label_base_end
            
            xml_label_path = os.path.join(output_file_path, f'{image_name}.xml')
            with open(xml_label_path, 'w') as file:
                file.write(label_base)
            
# Print the total number of images in the output folder with .jpg extension
print(len([file for file in os.listdir(output_file_path) if file.endswith('.jpg')]))
# Out:
# 7422

# %%
# Split full SAR processed dataset into train test and val:

# Define the input and output directories
input_dir = '/Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1'
output_dir = '/Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1_Split'

# If the output directory does not exist, create it
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Remove existing files in the output directory
files = [file for file in os.listdir(output_dir) if os.path.isfile(os.path.join(output_dir, file))]

for file in files:
    os.remove(os.path.join(output_dir, file))

# Remove .DS_Store if it exists
if '.DS_Store' in os.listdir(input_dir):
    os.remove(os.path.join(input_dir, '.DS_Store'))

# Get the list of images in the input directory (images are in .jpg format)
images = [file for file in os.listdir(input_dir) if file.endswith('.jpg')]
print(len(images))

# Split the images into train, test, and validation sets
train_images = images[:int(0.8 * len(images))]
test_images = images[int(0.8 * len(images)):int(0.9 * len(images))]
val_images = images[int(0.9 * len(images)):]

# Create the train, test, and validation directories
train_dir = os.path.join(output_dir, 'train')
test_dir = os.path.join(output_dir, 'test')
val_dir = os.path.join(output_dir, 'val')

print(train_dir)

# Create the train, test, and validation directories if they do not exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

if not os.path.exists(test_dir):
    os.makedirs(test_dir)

if not os.path.exists(val_dir):
    os.makedirs(val_dir)

# Copy the images as well as the .xml labels files to the train, test, and validation directories
for image in train_images:
    image_path = os.path.join(input_dir, image)
    xml_path = os.path.join(input_dir, image.split('.')[0] + '.xml')
    os.system(f'cp {image_path} {train_dir}')
    os.system(f'cp {xml_path} {train_dir}')

for image in test_images:
    image_path = os.path.join(input_dir, image)
    xml_path = os.path.join(input_dir, image.split('.')[0] + '.xml')
    os.system(f'cp {image_path} {test_dir}')
    os.system(f'cp {xml_path} {test_dir}')

for image in val_images:
    image_path = os.path.join(input_dir, image)
    xml_path = os.path.join(input_dir, image.split('.')[0] + '.xml')
    os.system(f'cp {image_path} {val_dir}')
    os.system(f'cp {xml_path} {val_dir}')

# Print the number of images in the train, test, and validation directories
print(len(os.listdir(train_dir)))
print(len(os.listdir(test_dir)))
print(len(os.listdir(val_dir)))
# Out:
# 7422
# /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1_Split/train
# cp: /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1/Haiti705.xml: No such file or directory
# cp: /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1/Haiti739.xml: No such file or directory
# cp: /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1/Haiti824.xml: No such file or directory
# cp: /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1/Haiti825.xml: No such file or directory
# cp: /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1/Haiti831.xml: No such file or directory
# cp: /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1/Haiti765.xml: No such file or directory
# cp: /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1/Haiti764.xml: No such file or directory
# cp: /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1/Haiti740.xml: No such file or directory
# cp: /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1/Haiti583.xml: No such file or directory
# cp: /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1/Haiti637.xml: No such file or directory
# cp: /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1/Haiti801.xml: No such file or directory
# cp: /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1/Haiti815.xml: No such file or directory
# cp: /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1/Haiti793.xml: No such file or directory
# cp: /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1/Haiti816.xml: No such file or directory
# cp: /Users/vihaan/Workspace/!Datasets/SAR_Dataset_Processed_1/Haiti584.xml: No such file or directory
# 11859
# 1484
# 1486

# %%
################################### Calculating total area of landslides per region:
path_sar_unprocessed = '/Users/vihaan/Workspace/!Datasets/SAR Dataset Unprocessed'
regions_in_sar = os.listdir(path_sar_unprocessed)

# Remove .DS_Store if it exists
if '.DS_Store' in regions_in_sar:
    regions_in_sar.remove('.DS_Store')

# Ignore the shapefiles folder as well
if 'study areas shp' in regions_in_sar:
    regions_in_sar.remove('study areas shp')

for region in regions_in_sar:
    # Get the resolution from the user when code runs:
    print(f'Enter the resolution for the region {region}: ')
    resolution = float(input())

    pixel_to_meter = resolution*resolution

    # Open the label path:
    labels_path = os.path.join(path_sar_unprocessed, region, 'label')

    # Get the list of label files
    label_files = os.listdir(labels_path)

    # Initialize the total area of landslides
    total_landslide_area = 0

    # number of labels:
    print('Total number of labels for region:', region, 'is:', len(label_files))

    # Iterate through each label file
    for label_file in label_files:
        # Read the label file
        label_image = cv2.imread(os.path.join(labels_path, label_file), cv2.IMREAD_UNCHANGED)

        # Extract the 0th band since all bands hold the same value
        band0 = label_image[:, :, 0]

        # Count the number of pixels with landslide
        landslide_pixels = np.count_nonzero(band0 == 0)

        #print(landslide_pixels/band0.size)

        # Add the area to the total area
        total_landslide_area += landslide_pixels

    print(f'Total area of landslides in {region}: {total_landslide_area * pixel_to_meter / 1000000} square kms')
    print(f'Total image area in {region}: {len(label_files) * band0.size * pixel_to_meter / 1000000} square kms')
# Out:
# Enter the resolution for the region Lombok:
# Total number of labels for region: Lombok is: 436
# Total area of landslides in Lombok: 87.585025 square kms
# Total image area in Lombok: 2857.3696 square kms
# Enter the resolution for the region Mengdong Township:
# Total number of labels for region: Mengdong Township is: 1155
# Total area of landslides in Mengdong Township: 8.289362 square kms
# Total image area in Mengdong Township: 75.69408 square kms
# Enter the resolution for the region Wenchuan:
# Total number of labels for region: Wenchuan is: 178
# Total area of landslides in Wenchuan: 53.08375 square kms
# Total image area in Wenchuan: 1166.5408 square kms
# Enter the resolution for the region Moxitaidi (SAT):
# Total number of labels for region: Moxitaidi (SAT) is: 652
# Total area of landslides in Moxitaidi (SAT): 4.3708518 square kms
# Total image area in Moxitaidi (SAT): 61.53043968 square kms
# Enter the resolution for the region palu:
# Total number of labels for region: palu is: 817
# Total area of landslides in palu: 64.8624 square kms
# Total image area in palu: 5354.2912 square kms
# Enter the resolution for the region Tiburon Peninsula（planet）:
# Total number of labels for region: Tiburon Peninsula（planet） is: 325
# Total area of landslides in Tiburon Peninsula（planet）: 93.478448 square kms
# Total image area in Tiburon Peninsula（planet）: 1363.1488 square kms
# Enter the resolution for the region Longxi River(SAT):
# Total number of labels for region: Longxi River(SAT) is: 1769
# Total area of landslides in Longxi River(SAT): 10.21245075 square kms
# Total image area in Longxi River(SAT): 115.933184 square kms
# Enter the resolution for the region Tiburon Peninsula（Sentinel）:
# Total number of labels for region: Tiburon Peninsula（Sentinel） is: 591
# Total area of landslides in Tiburon Peninsula（Sentinel）: 141.750525 square kms
# Total image area in Tiburon Peninsula（Sentinel）: 3873.1776 square kms
# Enter the resolution for the region Hokkaido Iburi-Tobu:
# Total number of labels for region: Hokkaido Iburi-Tobu is: 1484
# Total area of landslides in Hokkaido Iburi-Tobu: 359.005905 square kms
# Total image area in Hokkaido Iburi-Tobu: 3501.195264 square kms

# %%
################################### Calculating total area of landslides fpr l4s:
path_l4s_full = '/Users/vihaan/Workspace/!Datasets/data_land4sensor/l4s_complete_xml'

# Get list of labels:
labels = os.listdir(path_l4s_full)
print(len(labels))

# Initialize the total area of landslides
total_landslide_area = 0

# Iterate through each label file
for label in labels:
    # Read the label file
    tree = ET.parse(os.path.join(path_l4s_full, label))
    root = tree.getroot()

    # Get the image width and height
    image_width = int(root.find('size').find('width').text)
    image_height = int(root.find('size').find('height').text)

    # Get the bounding box coordinates
    xmin = int(root.find('object').find('bndbox').find('xmin').text)
    xmax = int(root.find('object').find('bndbox').find('xmax').text)
    ymin = int(root.find('object').find('bndbox').find('ymin').text)
    ymax = int(root.find('object').find('bndbox').find('ymax').text)

    # Calculate the area of the bounding box
    area = (xmax - xmin) * (ymax - ymin)

    # sanity check
    print(area/(image_width*image_height))

    # Add the area to the total area
    total_landslide_area += area

total_image_area = len(labels) * image_width * image_height
pixel_sq_to_m_sq = 10 * 10

print(f'Total area of landslides in l4s: {total_landslide_area * pixel_sq_to_m_sq / 1000000} square kms')
print(f'Total image area in l4s: {total_image_area * pixel_sq_to_m_sq / 1000000} square kms')
# Out:
# 2057
# 0.0166015625
# 0.01348876953125
# 0.03717041015625
# 0.056396484375
# 0.0225830078125
# 0.1016845703125
# 0.19793701171875
# 0.00732421875
# 0.056396484375
# 0.05615234375
# 0.02435302734375
# 0.0166015625
# 0.0087890625
# 0.0186767578125
# 0.0263671875
# 0.015380859375
# 0.0111083984375
# 0.00732421875
# 0.0946044921875
# 0.0115966796875
# 0.01971435546875
# 0.099365234375
# 0.0093994140625
# 0.0487060546875
# 0.05810546875
# 0.59765625
# 0.017578125
# 0.543701171875
# 0.0164794921875
# 0.015380859375
# 0.066650390625
# 0.0166015625
# 0.03228759765625
# 0.01507568359375
# 0.0311279296875
# 0.0333251953125
# 0.09759521484375
# 0.0162353515625
# 0.034912109375
# 0.01513671875
# 0.0087890625
# 0.0087890625
# 0.10894775390625
# 0.048828125
# 0.0076904296875
# 0.006591796875
# 2.46844482421875
# 0.0146484375
# 0.07000732421875
# 0.72802734375
# 0.041015625
# 0.22430419921875
# 0.02490234375
# 0.032958984375
# 0.0589599609375
# 0.89556884765625
# 0.015625
# 0.0076904296875
# 0.1309814453125
# 0.201416015625
# 0.07305908203125
# 0.00726318359375
# 0.0238037109375
# 0.015380859375
# 0.04742431640625
# 0.120361328125
# 0.02105712890625
# 0.0228271484375
# 0.0316162109375
# 0.0140380859375
# 0.0079345703125
# 0.1409912109375
# 0.024169921875
# 0.03460693359375
# 0.0333251953125
# 0.037353515625
# 0.041015625
# 0.0166015625
# 0.02783203125
# 0.0076904296875
# 0.006591796875
# 0.0164794921875
# 0.0299072265625
# 0.01025390625
# 0.00982666015625
# 0.02142333984375
# 0.008544921875
# 0.02105712890625
# 0.0718994140625
# 0.0615234375
# 0.099609375
# 0.006591796875
# 0.009765625
# 0.0230712890625
# 0.2142333984375
# 0.349365234375
# 0.028564453125
# 0.028076171875
# 0.0087890625
# 0.03631591796875
# 0.010986328125
# 0.19140625
# 0.028076171875
# 0.0145263671875
# 0.10760498046875
# 0.0205078125
# 0.01971435546875
# 0.01141357421875
# 0.0361328125
# 0.117431640625
# 0.022216796875
# 0.05084228515625
# 0.009765625
# 0.93701171875
# 0.0162353515625
# 0.0126953125
# 0.0185546875
# 0.06793212890625
# 0.00732421875
# 0.0087890625
# 0.0069580078125
# 0.0068359375
# 0.015380859375
# 0.009765625
# 0.009521484375
# 0.0126953125
# 0.03594970703125
# 0.4453125
# 0.02392578125
# 0.06878662109375
# 0.01141357421875
# 0.0269775390625
# 0.015380859375
# 0.011962890625
# 0.196044921875
# 0.02734375
# 0.03076171875
# 0.3623046875
# 0.022705078125
# 0.016845703125
# 0.01025390625
# 0.0281982421875
# 0.028076171875
# 0.1580810546875
# 0.05419921875
# 0.0726318359375
# 0.01922607421875
# 0.017578125
# 0.0316162109375
# 0.0067138671875
# 0.00897216796875
# 0.0107421875
# 0.0252685546875
# 0.01318359375
# 0.01611328125
# 0.01904296875
# 0.32684326171875
# 0.0113525390625
# 0.5887451171875
# 0.0179443359375
# 0.104736328125
# 0.0142822265625
# 0.08892822265625
# 0.01220703125
# 0.05712890625
# 0.0333251953125
# 0.01953125
# 0.0142822265625
# 0.73828125
# 0.081298828125
# 0.15771484375
# 0.00823974609375
# 0.01043701171875
# 0.0067138671875
# 0.0107421875
# 0.0087890625
# 0.018798828125
# 0.01904296875
# 0.0093994140625
# 0.04833984375
# 0.0396728515625
# 0.006103515625
# 0.03204345703125
# 0.032470703125
# 0.186767578125
# 0.00732421875
# 0.07476806640625
# 0.018798828125
# 0.047607421875
# 0.072509765625
# 0.05859375
# 0.05126953125
# 0.26025390625
# 0.032958984375
# 0.011962890625
# 0.106689453125
# 0.063232421875
# 0.01922607421875
# 0.1856689453125
# 0.0677490234375
# 0.718994140625
# 0.017578125
# 0.05126953125
# 0.126953125
# 0.013916015625
# 0.02691650390625
# 0.011962890625
# 0.203369140625
# 0.06280517578125
# 0.009521484375
# 0.0166015625
# 0.119140625
# 0.0087890625
# 0.0333251953125
# 0.035888671875
# 0.03790283203125
# 0.0076904296875
# 0.02490234375
# 0.0076904296875
# 0.018798828125
# 0.06549072265625
# 0.0067138671875
# 0.01190185546875
# 0.01904296875
# 0.0128173828125
# 0.030517578125
# 0.01025390625
# 0.078857421875
# 0.0811767578125
# 0.03173828125
# 0.01611328125
# 0.0244140625
# 0.0794677734375
# 0.130126953125
# 0.00640869140625
# 0.066650390625
# 0.00811767578125
# 0.30084228515625
# 0.011962890625
# 0.0626220703125
# 0.01556396484375
# 0.04541015625
# 0.0281982421875
# 0.0380859375
# 0.0128173828125
# 0.15234375
# 0.022216796875
# 0.2249755859375
# 0.013671875
# 0.0457763671875
# 0.03369140625
# 0.011962890625
# 0.02435302734375
# 0.01239013671875
# 0.01904296875
# 0.03216552734375
# 0.04071044921875
# 0.015380859375
# 0.1043701171875
# 0.0146484375
# 0.02490234375
# 0.0068359375
# 0.04998779296875
# 0.01953125
# 0.008544921875
# 0.806640625
# 0.0142822265625
# 0.40008544921875
# 0.07611083984375
# 0.0166015625
# 0.0274658203125
# 0.0264892578125
# 0.1484375
# 0.008056640625
# 0.02899169921875
# 0.0384521484375
# 0.00811767578125
# 0.019775390625
# 0.0460205078125
# 0.0673828125
# 0.43878173828125
# 0.010986328125
# 0.0179443359375
# 0.02734375
# 0.0079345703125
# 0.013916015625
# 0.1761474609375
# 0.0811767578125
# 0.0478515625
# 0.07086181640625
# 0.0091552734375
# 0.0145263671875
# 0.147705078125
# 0.02435302734375
# 0.00726318359375
# 0.035888671875
# 0.0213623046875
# 0.0186767578125
# 0.0145263671875
# 0.2926025390625
# 0.1495361328125
# 0.013671875
# 0.09869384765625
# 0.00811767578125
# 0.009765625
# 0.0626220703125
# 0.069580078125
# 0.03173828125
# 0.01409912109375
# 0.04254150390625
# 0.0076904296875
# 0.01123046875
# 0.01025390625
# 0.0140380859375
# 0.010986328125
# 0.057373046875
# 0.041259765625
# 0.03759765625
# 0.0546875
# 0.0076904296875
# 0.0322265625
# 0.0244140625
# 0.0162353515625
# 0.0067138671875
# 0.04486083984375
# 0.0262451171875
# 0.3009033203125
# 0.051025390625
# 0.053955078125
# 0.1153564453125
# 0.1007080078125
# 0.4189453125
# 0.27728271484375
# 0.00738525390625
# 1.03143310546875
# 0.01031494140625
# 0.11865234375
# 0.020751953125
# 0.006591796875
# 0.010986328125
# 0.2215576171875
# 0.00732421875
# 0.0302734375
# 0.010986328125
# 0.034912109375
# 0.009765625
# 0.0311279296875
# 0.0068359375
# 0.041748046875
# 0.15509033203125
# 0.02490234375
# 0.1190185546875
# 0.017578125
# 0.2938232421875
# 0.029052734375
# 0.006103515625
# 0.02288818359375
# 0.0079345703125
# 0.0076904296875
# 0.23345947265625
# 0.037109375
# 0.1136474609375
# 0.16876220703125
# 0.02178955078125
# 0.03076171875
# 0.0205078125
# 0.119140625
# 0.04913330078125
# 0.2537841796875
# 0.0230712890625
# 0.01904296875
# 0.04443359375
# 0.02392578125
# 0.45703125
# 0.008544921875
# 0.1851806640625
# 0.16448974609375
# 0.05767822265625
# 0.322998046875
# 0.03076171875
# 0.015380859375
# 0.0714111328125
# 0.02459716796875
# 0.011962890625
# 0.01153564453125
# 0.01318359375
# 0.01904296875
# 0.16748046875
# 0.00732421875
# 0.0333251953125
# 0.04071044921875
# 0.0234375
# 0.04638671875
# 0.0213623046875
# 0.0205078125
# 0.00811767578125
# 0.018310546875
# 0.01153564453125
# 0.4833984375
# 0.0908203125
# 0.011962890625
# 0.079345703125
# 0.14312744140625
# 0.0384521484375
# 0.0120849609375
# 0.5643310546875
# 0.01409912109375
# 0.13671875
# 0.0140380859375
# 0.0255126953125
# 0.17388916015625
# 0.0234375
# 0.01123046875
# 0.0115966796875
# 0.00823974609375
# 0.07568359375
# 0.504638671875
# 0.7357177734375
# 0.0384521484375
# 0.0589599609375
# 0.034912109375
# 0.0201416015625
# 0.072998046875
# 0.00830078125
# 0.37603759765625
# 0.0341796875
# 0.01025390625
# 0.1832275390625
# 0.03076171875
# 0.05474853515625
# 0.485595703125
# 0.025634765625
# 0.0494384765625
# 0.00732421875
# 0.0107421875
# 0.021240234375
# 0.01275634765625
# 0.0224609375
# 0.0322265625
# 0.011962890625
# 0.04443359375
# 0.0213623046875
# 0.00811767578125
# 0.02801513671875
# 0.00872802734375
# 0.1248779296875
# 0.0845947265625
# 0.02471923828125
# 0.01220703125
# 0.22686767578125
# 0.0093994140625
# 0.0811767578125
# 0.15576171875
# 0.06884765625
# 0.19140625
# 0.0384521484375
# 0.05126953125
# 0.02734375
# 0.02203369140625
# 0.03424072265625
# 0.010986328125
# 0.05767822265625
# 0.03131103515625
# 0.01983642578125
# 0.0299072265625
# 0.00640869140625
# 1.6151123046875
# 0.0966796875
# 0.008544921875
# 0.01904296875
# 0.1102294921875
# 0.00982666015625
# 0.0091552734375
# 0.03973388671875
# 0.08203125
# 0.015625
# 0.0316162109375
# 0.2724609375
# 0.06195068359375
# 0.768798828125
# 0.00640869140625
# 0.0255126953125
# 0.02178955078125
# 0.01922607421875
# 0.0120849609375
# 0.01544189453125
# 0.019775390625
# 0.07177734375
# 0.06982421875
# 0.01025390625
# 0.06195068359375
# 0.02386474609375
# 0.0078125
# 0.148681640625
# 0.015380859375
# 0.0185546875
# 0.4605712890625
# 0.0145263671875
# 0.0341796875
# 0.0692138671875
# 0.035888671875
# 0.0478515625
# 0.107421875
# 0.08056640625
# 0.0224609375
# 0.2537841796875
# 0.507080078125
# 0.20849609375
# 0.00726318359375
# 0.24072265625
# 0.88824462890625
# 0.03369140625
# 0.2076416015625
# 0.0067138671875
# 0.0186767578125
# 0.00823974609375
# 0.0684814453125
# 0.08892822265625
# 0.0264892578125
# 0.01068115234375
# 0.0128173828125
# 0.46875
# 0.01922607421875
# 0.19500732421875
# 0.0185546875
# 0.0076904296875
# 0.03173828125
# 0.142822265625
# 0.0111083984375
# 0.008544921875
# 0.0205078125
# 0.1556396484375
# 0.056640625
# 0.04443359375
# 0.017578125
# 0.0087890625
# 0.0111083984375
# 0.02288818359375
# 0.04779052734375
# 0.0926513671875
# 0.07421875
# 0.029541015625
# 0.03826904296875
# 0.0166015625
# 0.02593994140625
# 0.05487060546875
# 0.018798828125
# 0.061767578125
# 0.068359375
# 0.68829345703125
# 0.0162353515625
# 0.01348876953125
# 0.035888671875
# 0.041015625
# 0.0247802734375
# 0.20208740234375
# 0.05859375
# 0.7574462890625
# 0.33795166015625
# 0.136474609375
# 0.25634765625
# 0.0076904296875
# 0.09375
# 0.0107421875
# 0.40545654296875
# 0.063232421875
# 0.008544921875
# 0.77197265625
# 0.18072509765625
# 0.05126953125
# 0.02490234375
# 0.0128173828125
# 0.0186767578125
# 0.0208740234375
# 0.00732421875
# 0.573486328125
# 0.01983642578125
# 0.03076171875
# 0.0318603515625
# 0.1351318359375
# 0.01068115234375
# 0.00830078125
# 0.0999755859375
# 0.01953125
# 0.0274658203125
# 0.05859375
# 0.310791015625
# 0.0247802734375
# 0.035888671875
# 0.1563720703125
# 0.0457763671875
# 0.09271240234375
# 0.00732421875
# 0.0333251953125
# 0.01739501953125
# 0.1512451171875
# 0.06884765625
# 0.021484375
# 0.0179443359375
# 0.022216796875
# 0.05865478515625
# 0.00732421875
# 0.12615966796875
# 0.0205078125
# 0.0068359375
# 0.022216796875
# 0.1614990234375
# 0.01068115234375
# 0.016845703125
# 0.0205078125
# 0.006591796875
# 0.02178955078125
# 0.0115966796875
# 0.96893310546875
# 0.01043701171875
# 0.0955810546875
# 0.02734375
# 0.0301513671875
# 0.0140380859375
# 0.0933837890625
# 0.7646484375
# 0.0732421875
# 0.00982666015625
# 0.0823974609375
# 0.0120849609375
# 0.020751953125
# 0.0087890625
# 2.091796875
# 0.029052734375
# 0.0087890625
# 0.1549072265625
# 0.01025390625
# 0.0128173828125
# 0.0126953125
# 0.03076171875
# 0.984619140625
# 0.063232421875
# 0.0068359375
# 0.006591796875
# 0.01007080078125
# 0.0274658203125
# 0.00872802734375
# 0.06097412109375
# 0.20733642578125
# 0.0107421875
# 0.00634765625
# 0.02178955078125
# 0.0333251953125
# 0.0179443359375
# 0.01171875
# 0.04913330078125
# 0.01263427734375
# 0.153076171875
# 0.0751953125
# 0.01318359375
# 0.0640869140625
# 0.00732421875
# 0.2939453125
# 0.06280517578125
# 0.547119140625
# 0.021484375
# 0.0384521484375
# 0.09613037109375
# 0.021484375
# 0.380859375
# 0.013671875
# 0.0186767578125
# 0.0322265625
# 0.06494140625
# 0.0966796875
# 0.056396484375
# 0.26287841796875
# 0.0701904296875
# 0.085693359375
# 0.01275634765625
# 0.037353515625
# 2.01959228515625
# 0.02490234375
# 0.0244140625
# 0.011962890625
# 0.13385009765625
# 0.13323974609375
# 0.019775390625
# 0.03594970703125
# 0.025634765625
# 0.0162353515625
# 0.10467529296875
# 0.00732421875
# 0.00726318359375
# 0.02935791015625
# 0.032470703125
# 0.01324462890625
# 0.193603515625
# 0.45318603515625
# 0.117431640625
# 0.02197265625
# 0.1319580078125
# 0.0247802734375
# 0.1663818359375
# 0.011962890625
# 0.013671875
# 0.13458251953125
# 0.12939453125
# 0.0093994140625
# 0.08892822265625
# 0.12451171875
# 0.025390625
# 0.02734375
# 0.00726318359375
# 0.19921875
# 0.07537841796875
# 0.0145263671875
# 0.0128173828125
# 0.0126953125
# 0.0244140625
# 0.0111083984375
# 0.0186767578125
# 0.0589599609375
# 0.048828125
# 0.006591796875
# 0.39825439453125
# 0.015380859375
# 1.423828125
# 0.03076171875
# 0.0146484375
# 0.0230712890625
# 0.0196533203125
# 0.2999267578125
# 0.0145263671875
# 0.00714111328125
# 0.013427734375
# 0.1512451171875
# 0.0477294921875
# 0.0196533203125
# 0.375244140625
# 0.04119873046875
# 0.10205078125
# 0.047607421875
# 0.1461181640625
# 0.09710693359375
# 0.0341796875
# 0.0196533203125
# 0.032470703125
# 0.013427734375
# 0.0093994140625
# 0.008056640625
# 0.0213623046875
# 0.016845703125
# 0.07177734375
# 0.072265625
# 0.0093994140625
# 0.0076904296875
# 0.00933837890625
# 0.00634765625
# 0.0098876953125
# 0.00872802734375
# 0.0205078125
# 0.1893310546875
# 0.04119873046875
# 0.7470703125
# 0.08203125
# 0.035888671875
# 0.2178955078125
# 0.23095703125
# 0.06195068359375
# 0.012451171875
# 0.58563232421875
# 0.0201416015625
# 0.0302734375
# 0.870849609375
# 0.244873046875
# 1.092041015625
# 0.010986328125
# 0.080322265625
# 0.01275634765625
# 0.0087890625
# 0.02667236328125
# 0.0767822265625
# 0.09869384765625
# 0.425537109375
# 0.0196533203125
# 0.00738525390625
# 0.573486328125
# 0.02899169921875
# 0.02435302734375
# 0.0126953125
# 0.015380859375
# 0.00640869140625
# 0.0098876953125
# 0.04486083984375
# 0.02459716796875
# 0.05438232421875
# 0.052978515625
# 0.0145263671875
# 0.0274658203125
# 0.22686767578125
# 0.0264892578125
# 0.0311279296875
# 0.00933837890625
# 0.146484375
# 0.0098876953125
# 0.0205078125
# 0.0692138671875
# 0.012451171875
# 0.01025390625
# 0.02593994140625
# 0.015380859375
# 0.06103515625
# 0.3729248046875
# 0.00982666015625
# 0.09600830078125
# 1.01385498046875
# 0.015380859375
# 0.07177734375
# 0.0196533203125
# 0.0078125
# 0.0186767578125
# 0.32958984375
# 0.07159423828125
# 0.022216796875
# 0.018310546875
# 0.05438232421875
# 0.009033203125
# 0.08319091796875
# 0.0115966796875
# 0.0238037109375
# 0.0093994140625
# 0.230712890625
# 0.00640869140625
# 0.06591796875
# 0.84228515625
# 0.076904296875
# 0.0948486328125
# 0.01904296875
# 0.07305908203125
# 0.066650390625
# 0.0067138671875
# 0.22760009765625
# 0.029296875
# 0.0196533203125
# 0.048828125
# 0.025634765625
# 0.18743896484375
# 0.01171875
# 0.00634765625
# 0.006591796875
# 0.14739990234375
# 0.008056640625
# 0.025634765625
# 0.05767822265625
# 0.06549072265625
# 0.02947998046875
# 0.0142822265625
# 0.0142822265625
# 0.0364990234375
# 0.0087890625
# 0.00762939453125
# 0.13330078125
# 0.3433837890625
# 0.3768310546875
# 0.1038818359375
# 0.051025390625
# 0.0230712890625
# 0.2010498046875
# 0.01171875
# 0.111083984375
# 0.0538330078125
# 0.034423828125
# 0.0859375
# 0.03076171875
# 0.0079345703125
# 0.01025390625
# 0.015625
# 0.0860595703125
# 0.0145263671875
# 0.028076171875
# 0.0281982421875
# 0.1953125
# 0.006591796875
# 0.0185546875
# 0.0692138671875
# 0.0091552734375
# 0.0111083984375
# 0.03955078125
# 0.0677490234375
# 0.0142822265625
# 0.0892333984375
# 0.0205078125
# 0.028564453125
# 0.2655029296875
# 0.056396484375
# 0.1248779296875
# 0.11279296875
# 0.60284423828125
# 0.30706787109375
# 0.153076171875
# 0.28326416015625
# 0.16351318359375
# 0.0443115234375
# 0.015380859375
# 0.00933837890625
# 0.31146240234375
# 0.035888671875
# 0.15106201171875
# 0.27001953125
# 0.13629150390625
# 0.0333251953125
# 0.0076904296875
# 0.09027099609375
# 0.011962890625
# 0.0380859375
# 0.16448974609375
# 0.0079345703125
# 0.0274658203125
# 0.03973388671875
# 0.0255126953125
# 0.09521484375
# 0.3076171875
# 0.0076904296875
# 0.48046875
# 0.02947998046875
# 0.0208740234375
# 0.240234375
# 0.03076171875
# 0.010986328125
# 0.04742431640625
# 0.0162353515625
# 0.0145263671875
# 0.0087890625
# 0.0145263671875
# 0.6103515625
# 0.0396728515625
# 0.01171875
# 0.0126953125
# 0.03216552734375
# 0.0230712890625
# 0.020751953125
# 0.0845947265625
# 0.0230712890625
# 0.0068359375
# 0.008544921875
# 0.0394287109375
# 0.0205078125
# 0.02783203125
# 0.03076171875
# 0.01220703125
# 0.06298828125
# 0.00872802734375
# 0.008056640625
# 0.0067138671875
# 0.12451171875
# 0.035400390625
# 0.008056640625
# 0.1083984375
# 0.03131103515625
# 0.231689453125
# 0.44091796875
# 0.0531005859375
# 0.17578125
# 0.06500244140625
# 0.015380859375
# 0.0341796875
# 0.00830078125
# 0.015380859375
# 0.00634765625
# 0.03594970703125
# 0.01904296875
# 0.008544921875
# 0.02178955078125
# 0.00732421875
# 0.4998779296875
# 0.01971435546875
# 0.04541015625
# 1.052734375
# 0.0115966796875
# 0.009765625
# 0.00640869140625
# 0.009521484375
# 0.14453125
# 0.0120849609375
# 0.0301513671875
# 0.00823974609375
# 0.6697998046875
# 0.26806640625
# 0.00933837890625
# 0.0076904296875
# 0.0146484375
# 0.0491943359375
# 0.0206298828125
# 0.008544921875
# 0.7425537109375
# 0.0087890625
# 0.0068359375
# 0.39093017578125
# 0.035888671875
# 0.01708984375
# 0.0933837890625
# 0.1204833984375
# 0.0147705078125
# 0.0745849609375
# 0.0068359375
# 0.067138671875
# 0.028076171875
# 0.0263671875
# 0.022216796875
# 0.14007568359375
# 0.0079345703125
# 0.041015625
# 0.0809326171875
# 0.10894775390625
# 0.0645751953125
# 0.1666259765625
# 0.01953125
# 0.19732666015625
# 0.0068359375
# 0.126953125
# 0.05914306640625
# 0.01318359375
# 0.090087890625
# 0.08331298828125
# 0.162353515625
# 0.43768310546875
# 0.01043701171875
# 0.08587646484375
# 0.00732421875
# 0.0126953125
# 0.0076904296875
# 0.006591796875
# 0.0091552734375
# 0.0076904296875
# 0.012451171875
# 0.06195068359375
# 0.0107421875
# 0.009521484375
# 0.029052734375
# 0.01611328125
# 0.0364990234375
# 0.01739501953125
# 0.009765625
# 0.028564453125
# 0.435791015625
# 0.01611328125
# 0.093994140625
# 0.178466796875
# 0.1571044921875
# 0.01507568359375
# 0.076904296875
# 0.0145263671875
# 0.0098876953125
# 0.03076171875
# 0.01123046875
# 0.128173828125
# 0.01220703125
# 0.0491943359375
# 0.0076904296875
# 0.71435546875
# 0.0518798828125
# 0.5635986328125
# 0.00933837890625
# 0.03216552734375
# 0.0538330078125
# 0.21917724609375
# 0.3153076171875
# 0.0208740234375
# 0.00714111328125
# 0.068115234375
# 0.0091552734375
# 0.9091796875
# 0.0230712890625
# 0.017578125
# 0.01123046875
# 0.047607421875
# 0.011962890625
# 0.0230712890625
# 0.55029296875
# 0.203369140625
# 0.01409912109375
# 0.0128173828125
# 0.0091552734375
# 0.0604248046875
# 0.0166015625
# 0.028076171875
# 0.3662109375
# 0.0166015625
# 0.0615234375
# 0.08135986328125
# 0.01922607421875
# 0.366455078125
# 0.0067138671875
# 0.041748046875
# 0.03759765625
# 0.13330078125
# 0.56097412109375
# 0.0384521484375
# 0.451171875
# 0.006103515625
# 0.0140380859375
# 0.0333251953125
# 0.01922607421875
# 0.38153076171875
# 0.3646240234375
# 0.0533447265625
# 0.02197265625
# 0.029296875
# 0.0531005859375
# 0.04742431640625
# 0.097412109375
# 0.00732421875
# 0.16351318359375
# 0.04913330078125
# 0.0281982421875
# 0.015380859375
# 2.43646240234375
# 0.02691650390625
# 0.0897216796875
# 0.0364990234375
# 0.6483154296875
# 0.008056640625
# 0.093994140625
# 0.0362548828125
# 0.44036865234375
# 0.099365234375
# 0.015380859375
# 0.015380859375
# 0.01348876953125
# 0.324951171875
# 0.0087890625
# 0.0078125
# 0.19439697265625
# 0.0087890625
# 0.00823974609375
# 0.375244140625
# 0.03228759765625
# 0.0162353515625
# 0.022216796875
# 0.01190185546875
# 0.07421875
# 0.062255859375
# 0.04058837890625
# 0.05615234375
# 0.08544921875
# 0.019775390625
# 0.08819580078125
# 0.02386474609375
# 0.01153564453125
# 0.02734375
# 0.018798828125
# 0.0084228515625
# 0.930908203125
# 0.04046630859375
# 0.02435302734375
# 0.25634765625
# 0.06622314453125
# 0.011962890625
# 0.025634765625
# 0.111083984375
# 0.0068359375
# 0.02947998046875
# 0.2808837890625
# 0.0814208984375
# 0.2025146484375
# 0.0076904296875
# 0.0281982421875
# 0.0205078125
# 0.02899169921875
# 0.178466796875
# 0.018798828125
# 0.4814453125
# 0.0186767578125
# 0.03021240234375
# 0.57373046875
# 0.157470703125
# 0.00738525390625
# 0.0111083984375
# 0.009521484375
# 0.00897216796875
# 0.0224609375
# 0.04290771484375
# 0.35760498046875
# 0.0115966796875
# 0.008544921875
# 0.0230712890625
# 0.03369140625
# 0.041015625
# 0.01263427734375
# 0.00732421875
# 0.02734375
# 0.8643798828125
# 0.03594970703125
# 0.3131103515625
# 0.03076171875
# 0.02435302734375
# 0.0587158203125
# 0.00726318359375
# 0.0281982421875
# 0.07476806640625
# 0.00732421875
# 0.0087890625
# 0.01922607421875
# 0.1851806640625
# 0.0087890625
# 0.1038818359375
# 0.02490234375
# 0.00634765625
# 0.02435302734375
# 0.00640869140625
# 0.06024169921875
# 0.00811767578125
# 0.0140380859375
# 0.0311279296875
# 0.011962890625
# 0.205078125
# 0.0126953125
# 0.0234375
# 0.0145263671875
# 0.0068359375
# 0.009765625
# 0.00897216796875
# 0.00726318359375
# 0.012451171875
# 0.01708984375
# 0.0401611328125
# 0.0523681640625
# 0.05126953125
# 0.02801513671875
# 0.039306640625
# 0.0068359375
# 0.2376708984375
# 0.01409912109375
# 0.009765625
# 0.0185546875
# 0.0230712890625
# 0.0128173828125
# 0.00732421875
# 0.0247802734375
# 0.008056640625
# 0.00872802734375
# 0.0205078125
# 0.2783203125
# 0.0162353515625
# 1.3150634765625
# 0.052734375
# 0.0087890625
# 0.0087890625
# 0.31201171875
# 0.14404296875
# 0.0302734375
# 0.1522216796875
# 0.011962890625
# 0.025390625
# 3.0625
# 0.0416259765625
# 0.04833984375
# 0.0496826171875
# 0.07049560546875
# 0.01025390625
# 0.0751953125
# 0.0067138671875
# 0.42041015625
# 0.008544921875
# 0.00738525390625
# 0.009521484375
# 1.626953125
# 1.9482421875
# 0.03125
# 0.0394287109375
# 0.063232421875
# 0.01824951171875
# 0.05438232421875
# 0.18988037109375
# 0.0076904296875
# 0.10986328125
# 0.029052734375
# 0.035400390625
# 0.0140380859375
# 0.021484375
# 0.0087890625
# 0.33880615234375
# 0.0364990234375
# 0.04486083984375
# 0.528076171875
# 0.0076904296875
# 0.05511474609375
# 0.03973388671875
# 0.0126953125
# 0.24945068359375
# 0.01171875
# 0.011962890625
# 0.09228515625
# 0.0205078125
# 0.006103515625
# 0.20050048828125
# 0.04913330078125
# 0.01318359375
# 0.1820068359375
# 0.0087890625
# 0.169189453125
# 0.0087890625
# 0.032470703125
# 0.01702880859375
# 0.018798828125
# 0.10247802734375
# 0.0604248046875
# 0.54473876953125
# 0.01025390625
# 0.037353515625
# 0.083251953125
# 0.24609375
# 0.0469970703125
# 0.16448974609375
# 0.01025390625
# 0.01739501953125
# 0.06146240234375
# 0.10467529296875
# 0.01318359375
# 0.053955078125
# 0.01171875
# 0.1922607421875
# 0.01153564453125
# 0.025390625
# 0.006103515625
# 0.01763916015625
# 0.0341796875
# 1.256103515625
# 0.093994140625
# 0.217529296875
# 0.052978515625
# 0.85235595703125
# 0.0394287109375
# 0.485595703125
# 0.035888671875
# 0.039306640625
# 0.00933837890625
# 0.0128173828125
# 0.0076904296875
# 0.0213623046875
# 0.0093994140625
# 0.03826904296875
# 0.21875
# 0.029052734375
# 0.01220703125
# 0.0079345703125
# 0.1058349609375
# 0.009521484375
# 0.00640869140625
# 0.017578125
# 0.019775390625
# 1.074951171875
# 0.01220703125
# 0.1435546875
# 0.0111083984375
# 0.03460693359375
# 0.02178955078125
# 0.02667236328125
# 0.0111083984375
# 0.056396484375
# 0.008544921875
# 0.11279296875
# 0.02691650390625
# 0.01025390625
# 0.25421142578125
# 0.040283203125
# 0.0093994140625
# 0.0076904296875
# 0.01025390625
# 0.1256103515625
# 0.011962890625
# 0.02197265625
# 0.131591796875
# 0.02618408203125
# 0.15234375
# 0.025634765625
# 0.03369140625
# 2.078125
# 0.040283203125
# 0.03424072265625
# 0.4443359375
# 0.16461181640625
# 0.03173828125
# 0.36187744140625
# 0.0301513671875
# 0.07965087890625
# 0.0640869140625
# 0.00640869140625
# 0.025634765625
# 0.01025390625
# 0.03955078125
# 0.0205078125
# 0.1396484375
# 0.0166015625
# 0.01025390625
# 0.018798828125
# 0.02197265625
# 0.01171875
# 0.098876953125
# 0.008544921875
# 0.0079345703125
# 0.2406005859375
# 0.0296630859375
# 0.0579833984375
# 0.0252685546875
# 0.24609375
# 0.02435302734375
# 0.0335693359375
# 0.056396484375
# 0.0567626953125
# 0.0174560546875
# 0.01153564453125
# 0.0966796875
# 0.0283203125
# 0.40283203125
# 0.049560546875
# 0.0068359375
# 0.01702880859375
# 0.06195068359375
# 0.22003173828125
# 0.029296875
# 0.06903076171875
# 0.8558349609375
# 0.019775390625
# 0.008544921875
# 0.0933837890625
# 0.009765625
# 0.00640869140625
# 0.1484375
# 0.056396484375
# 0.025634765625
# 0.129638671875
# 0.00714111328125
# 0.0224609375
# 0.11328125
# 0.00732421875
# 0.0640869140625
# 0.013916015625
# 0.04443359375
# 0.00933837890625
# 0.0087890625
# 0.0274658203125
# 0.46142578125
# 0.039306640625
# 0.18798828125
# 0.18646240234375
# 0.0286865234375
# 0.044921875
# 0.0174560546875
# 0.01763916015625
# 0.0098876953125
# 0.1495361328125
# 0.06243896484375
# 0.01025390625
# 0.0589599609375
# 0.09521484375
# 0.013671875
# 0.01763916015625
# 0.0224609375
# 0.01123046875
# 0.01763916015625
# 0.0145263671875
# 0.1973876953125
# 0.460205078125
# 0.03369140625
# 0.126220703125
# 0.2801513671875
# 0.0084228515625
# 0.006591796875
# 0.0213623046875
# 0.06866455078125
# 0.04486083984375
# 0.0107421875
# 0.10205078125
# 0.0098876953125
# 0.018310546875
# 0.0208740234375
# 0.008056640625
# 0.09228515625
# 0.01171875
# 0.00982666015625
# 0.0439453125
# 0.0640869140625
# 0.307861328125
# 0.77490234375
# 0.0555419921875
# 0.02178955078125
# 0.02801513671875
# 0.015869140625
# 0.1651611328125
# 0.0537109375
# 0.03204345703125
# 0.1484375
# 0.21533203125
# 0.0087890625
# 0.01025390625
# 0.08203125
# 0.0640869140625
# 0.00701904296875
# 0.01043701171875
# 0.0238037109375
# 0.02435302734375
# 0.009765625
# 0.009521484375
# 0.00933837890625
# 0.046142578125
# 0.0228271484375
# 0.0126953125
# 0.006103515625
# 0.0196533203125
# 0.0205078125
# 0.00811767578125
# 0.008544921875
# 0.02386474609375
# 0.361083984375
# 0.008544921875
# 0.5540771484375
# 0.1611328125
# 0.08758544921875
# 0.0146484375
# 0.025634765625
# 0.0146484375
# 0.0098876953125
# 0.025390625
# 1.6007080078125
# 0.07049560546875
# 0.013916015625
# 0.0308837890625
# 0.21917724609375
# 1.4765625
# 0.0555419921875
# 0.1768798828125
# 0.06243896484375
# 0.0087890625
# 0.008056640625
# 0.0067138671875
# 0.01971435546875
# 0.01007080078125
# 0.035888671875
# 0.14697265625
# 0.0068359375
# 0.010986328125
# 0.0068359375
# 0.01373291015625
# 0.04290771484375
# 0.1495361328125
# 0.07049560546875
# 0.172119140625
# 0.030517578125
# 0.07904052734375
# 0.0208740234375
# 0.543701171875
# 0.1142578125
# 0.0107421875
# 0.0264892578125
# 0.01123046875
# 0.04443359375
# 0.00726318359375
# 0.0308837890625
# 1.1568603515625
# 0.0238037109375
# 0.00927734375
# 0.1063232421875
# 0.551025390625
# 0.010986328125
# 0.02392578125
# 0.02142333984375
# 0.0228271484375
# 0.03125
# 0.013916015625
# 0.01025390625
# 0.2734375
# 0.5205078125
# 0.24005126953125
# 0.0281982421875
# 0.018310546875
# 0.008544921875
# 0.10467529296875
# 0.07476806640625
# 0.0166015625
# 0.009765625
# 0.00732421875
# 0.0390625
# 0.15576171875
# 0.083740234375
# 0.009521484375
# 0.3306884765625
# 0.10986328125
# 0.010986328125
# 0.0162353515625
# 0.02197265625
# 0.0394287109375
# 0.0264892578125
# 0.0145263671875
# 0.015625
# 0.025634765625
# 0.054931640625
# 0.015380859375
# 0.0269775390625
# 0.015380859375
# 0.030517578125
# 0.04443359375
# 0.0645751953125
# 0.39111328125
# 0.035400390625
# 0.01220703125
# 0.05914306640625
# 0.0201416015625
# 0.0537109375
# 0.0440673828125
# 0.016845703125
# 0.02178955078125
# 0.066650390625
# 0.0205078125
# 0.016845703125
# 0.78955078125
# 0.00811767578125
# 0.0146484375
# 0.0128173828125
# 0.3050537109375
# 0.729736328125
# 0.03826904296875
# 0.15484619140625
# 0.02947998046875
# 0.016845703125
# 0.064453125
# 0.011962890625
# 0.07177734375
# 0.09869384765625
# 0.013671875
# 0.04058837890625
# 0.03369140625
# 0.00732421875
# 0.09869384765625
# 0.0897216796875
# 0.01824951171875
# 0.1409912109375
# 0.01171875
# 0.07476806640625
# 0.52764892578125
# 0.1494140625
# 0.010986328125
# 0.00830078125
# 0.054931640625
# 0.15911865234375
# 0.21234130859375
# 0.05438232421875
# 0.03826904296875
# 0.0162353515625
# 0.0091552734375
# 0.0087890625
# 0.006591796875
# 0.196533203125
# 0.02105712890625
# 0.087890625
# 0.006591796875
# 0.806640625
# 0.0128173828125
# 0.0087890625
# 0.02435302734375
# 0.7587890625
# 0.0892333984375
# 0.10675048828125
# 0.025634765625
# 0.03009033203125
# 0.1021728515625
# 0.05859375
# 0.01739501953125
# 0.634033203125
# 0.15325927734375
# 0.03515625
# 0.08319091796875
# 0.051025390625
# 0.04046630859375
# 0.0518798828125
# 0.097412109375
# 0.03363037109375
# 0.01141357421875
# 0.01275634765625
# 0.015380859375
# 0.093994140625
# 0.04290771484375
# 0.08544921875
# 0.05615234375
# 0.0587158203125
# 0.083251953125
# 0.606689453125
# 0.95489501953125
# 0.06195068359375
# 0.370849609375
# 0.0067138671875
# 0.0491943359375
# 0.03826904296875
# 0.19610595703125
# 0.00933837890625
# 0.0213623046875
# 0.02392578125
# 0.0174560546875
# 0.076171875
# 0.0341796875
# 0.02178955078125
# 0.015380859375
# 0.26806640625
# 0.06982421875
# 0.0362548828125
# 0.006103515625
# 0.02081298828125
# 0.06103515625
# 0.025634765625
# 0.11328125
# 0.1099853515625
# 0.3212890625
# 0.07904052734375
# 0.013671875
# 0.09735107421875
# 0.03594970703125
# 0.29608154296875
# 0.0126953125
# 0.0093994140625
# 0.490478515625
# 0.01025390625
# 0.00640869140625
# 0.018798828125
# 0.029541015625
# 0.015380859375
# 0.00811767578125
# 0.011962890625
# 0.016845703125
# 0.0247802734375
# 0.0538330078125
# 0.00732421875
# 0.87384033203125
# 0.03662109375
# 0.056396484375
# 0.0860595703125
# 0.025634765625
# 0.05438232421875
# 0.07568359375
# 0.1090087890625
# 0.0140380859375
# 0.1087646484375
# 0.06591796875
# 0.00982666015625
# 0.032470703125
# 0.06591796875
# 0.05755615234375
# 0.008544921875
# 0.016845703125
# 0.01025390625
# 0.08258056640625
# 0.21533203125
# 0.35546875
# 0.0164794921875
# 0.05712890625
# 0.0107421875
# 0.0537109375
# 0.008056640625
# 0.30859375
# 0.011962890625
# 0.30157470703125
# 0.384521484375
# 0.0546875
# 0.0567626953125
# 0.14404296875
# 0.09613037109375
# 0.138427734375
# 0.047607421875
# 0.07904052734375
# 0.0264892578125
# 0.09912109375
# 0.05126953125
# 0.048828125
# 0.0078125
# 0.03662109375
# 0.016845703125
# 0.01409912109375
# 0.0162353515625
# 0.1451416015625
# 0.12689208984375
# 0.09613037109375
# 0.042724609375
# 0.01153564453125
# 0.142822265625
# 0.148681640625
# 0.025390625
# 0.0745849609375
# 0.009521484375
# 0.09613037109375
# 0.01171875
# 0.02691650390625
# 0.02899169921875
# 0.0185546875
# 0.06597900390625
# 0.166015625
# 0.015625
# 0.06243896484375
# 0.041015625
# 0.008544921875
# 2.47802734375
# 0.50921630859375
# 0.158203125
# 0.0487060546875
# 0.07086181640625
# 0.009765625
# 0.029296875
# 0.006591796875
# 0.05841064453125
# 0.008544921875
# 0.03204345703125
# 0.0177001953125
# 0.00823974609375
# 0.011962890625
# 0.32958984375
# 0.0093994140625
# 0.00982666015625
# 0.384033203125
# 0.017578125
# 0.00897216796875
# 0.095703125
# 0.01409912109375
# 0.106689453125
# 0.03363037109375
# 0.07421875
# 0.00640869140625
# 0.041015625
# 0.72760009765625
# 0.106201171875
# 0.53173828125
# 0.01611328125
# 0.00732421875
# 0.0213623046875
# 0.01275634765625
# 0.008056640625
# 0.0477294921875
# 0.21820068359375
# 0.05126953125
# 0.444091796875
# 0.04229736328125
# 0.2716064453125
# 0.38909912109375
# 0.032470703125
# 0.0196533203125
# 0.02459716796875
# 0.45501708984375
# 0.03973388671875
# 0.0126953125
# 0.0244140625
# 0.04046630859375
# 0.176025390625
# 0.010986328125
# 0.10223388671875
# 0.180908203125
# 0.21221923828125
# 0.18408203125
# 0.00982666015625
# 0.0111083984375
# 0.006591796875
# 0.00933837890625
# 0.0179443359375
# 0.07159423828125
# 0.017578125
# 0.0281982421875
# 0.0162353515625
# 0.03363037109375
# 0.0205078125
# 0.46142578125
# 0.05615234375
# 0.072509765625
# 0.059814453125
# 0.12603759765625
# 0.008544921875
# 0.16876220703125
# 0.022216796875
# 0.028564453125
# 0.107666015625
# 0.0308837890625
# 0.02734375
# 0.0631103515625
# 0.0228271484375
# 0.1396484375
# 0.00732421875
# 0.035888671875
# 0.02593994140625
# 0.0281982421875
# 0.11279296875
# 0.0177001953125
# 0.01141357421875
# 0.53631591796875
# 0.02435302734375
# 0.052734375
# 0.035888671875
# 0.01025390625
# 0.11328125
# 0.0205078125
# 0.0322265625
# 0.09228515625
# 0.42333984375
# 0.0078125
# 0.03631591796875
# 0.011962890625
# 0.353759765625
# 0.05615234375
# 0.02392578125
# 0.07452392578125
# 0.0362548828125
# 0.177734375
# 0.0196533203125
# 0.0224609375
# 0.08758544921875
# 0.07763671875
# 0.00701904296875
# 0.02734375
# 0.05078125
# 0.006591796875
# 0.07177734375
# 0.02734375
# 0.013916015625
# 0.0640869140625
# 0.04443359375
# 0.2159423828125
# 0.01971435546875
# 0.0111083984375
# 0.032470703125
# 1.542724609375
# 0.00640869140625
# 0.359375
# 0.05126953125
# 0.24224853515625
# 0.17645263671875
# 0.0440673828125
# 0.017578125
# 0.06103515625
# 0.0234375
# 0.01507568359375
# 0.0626220703125
# 0.013671875
# 0.019775390625
# 0.153076171875
# 0.04443359375
# 0.02392578125
# 0.02484130859375
# 0.0645751953125
# 0.034912109375
# 0.02435302734375
# 0.042724609375
# 0.02288818359375
# 0.083740234375
# 1.71826171875
# 0.02691650390625
# 0.224609375
# 0.01025390625
# 0.019775390625
# 0.00714111328125
# 0.0384521484375
# 0.01318359375
# 0.0093994140625
# 0.0068359375
# 0.006591796875
# 0.08984375
# 0.0732421875
# 0.0396728515625
# 0.07965087890625
# 0.0396728515625
# 0.28411865234375
# 0.0140380859375
# 0.00732421875
# 0.0970458984375
# 0.0238037109375
# 0.4302978515625
# 0.0164794921875
# 0.2484130859375
# 0.011962890625
# 0.13671875
# 0.04058837890625
# 0.0174560546875
# 0.019775390625
# 0.00640869140625
# 0.0269775390625
# 0.240966796875
# 0.017578125
# 0.01739501953125
# 0.052490234375
# 0.01141357421875
# 0.0166015625
# 0.013671875
# 0.011962890625
# 0.2392578125
# 0.0533447265625
# 0.01806640625
# 0.0185546875
# 0.033203125
# 0.86395263671875
# 0.0076904296875
# 0.8489990234375
# 0.0333251953125
# 0.0478515625
# 0.02203369140625
# 0.3687744140625
# 0.013671875
# 0.0968017578125
# 0.1015625
# 0.0230712890625
# 0.01666259765625
# 0.1153564453125
# 0.0308837890625
# 0.025634765625
# 0.02178955078125
# 0.009765625
# 0.401611328125
# 0.0093994140625
# 0.0301513671875
# 0.00726318359375
# 0.0205078125
# 0.00933837890625
# 0.011962890625
# 0.10162353515625
# 0.0684814453125
# 0.04742431640625
# 0.0068359375
# 0.07177734375
# 0.02435302734375
# 0.008544921875
# 0.0068359375
# 0.008544921875
# 0.06195068359375
# 0.09912109375
# 0.056396484375
# 0.016845703125
# 0.845947265625
# 0.1951904296875
# 0.0078125
# 0.017578125
# 0.01025390625
# 0.01318359375
# 0.042724609375
# 0.08544921875
# 0.54052734375
# 0.161865234375
# 0.0523681640625
# 0.0255126953125
# 0.01153564453125
# 0.02911376953125
# 0.0076904296875
# 0.032958984375
# 0.02667236328125
# 0.008056640625
# 0.024169921875
# 0.03759765625
# 0.01324462890625
# 0.12939453125
# 0.009765625
# 0.095703125
# 0.0164794921875
# 0.09228515625
# 0.02197265625
# 0.02197265625
# 0.0174560546875
# 0.02691650390625
# 0.2490234375
# 0.03173828125
# 0.01025390625
# Total area of landslides in l4s: 345.706 square kms
# Total image area in l4s: 3370.1888 square kms
